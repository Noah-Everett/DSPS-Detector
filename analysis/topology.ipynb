# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import tensorflow as tf
import ROOT
import uproot
# %jsroot on
# Out:
# Welcome to JupyROOT 6.28/04

# %%
file_input_name = '../runs/output_1.root'
file_input_pyroot = ROOT.TFile(file_input_name)
file_input_uproot = uproot.open(file_input_name)
histogram_names = uproot.open(file_input_name).keys()[3:]
tree_names = uproot.open(file_input_name).keys()[:3]

# %%
hits_list_library = {}
hits_hist_library = {}
for name in histogram_names:
    # Get the histogram from the input file
    histogram = file_input_pyroot.Get(name)

    # Get the number of bins in the X and Y directions
    n_bins_x = histogram.GetNbinsX()
    n_bins_y = histogram.GetNbinsY()

    # Create NumPy arrays to store the bin contents and edges
    values = np.zeros((n_bins_x, n_bins_y))
    hits = []
    x_edges = []
    y_edges = []

    # Extract the bin contents (values) and edges
    for i in range(1, n_bins_x + 2):
        x_edges.append(histogram.GetXaxis().GetBinLowEdge(i))
    for i in range(1, n_bins_y + 2):
        y_edges.append(histogram.GetYaxis().GetBinLowEdge(i))

    for i in range(1, n_bins_x + 1):
        for j in range(1, n_bins_y + 1):
            values[i - 1][j - 1] = histogram.GetBinContent(j, i)
            if histogram.GetBinContent(j, i) > 0:
                hits.append((y_edges[j] + (y_edges[j+1] - y_edges[j])/2, x_edges[i] + (x_edges[i+1] - x_edges[i])/2))

    print(name,hits)
    hits_list_library[name] = hits
    hits_hist_library[name] = values
# Out:
# /DSPD_+x_0_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_1_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_2_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_3_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_4_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_5_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_6_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_7_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_8_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_9_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_10_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_11_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_12_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_13_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_14_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_15_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_16_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_17_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_18_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_19_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_20_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_21_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_22_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_23_photoSensor_surface_sensitiveDetector;1 [(-28.5, 34.5)]
# /DSPD_+x_24_photoSensor_surface_sensitiveDetector;1 [(-39.5, -5.5), (-24.5, 33.5)]
# /DSPD_+x_25_photoSensor_surface_sensitiveDetector;1 [(-28.5, -26.5)]
# /DSPD_+x_26_photoSensor_surface_sensitiveDetector;1 [(-27.5, -4.5)]
# /DSPD_+x_27_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_28_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_29_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_30_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_31_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_32_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_33_photoSensor_surface_sensitiveDetector;1 [(-27.5, 3.5), (-28.5, 7.5), (-8.5, 8.5), (-36.5, 11.5), (-15.5, 16.5)]
# /DSPD_+x_34_photoSensor_surface_sensitiveDetector;1 [(-32.5, 9.5)]
# /DSPD_+x_35_photoSensor_surface_sensitiveDetector;1 [(-3.5, -24.5), (-23.5, -13.5), (-12.5, 11.5)]
# /DSPD_+x_36_photoSensor_surface_sensitiveDetector;1 [(-19.5, -30.5), (-29.5, -9.5)]
# /DSPD_+x_37_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_38_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_39_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_40_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_41_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_42_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_43_photoSensor_surface_sensitiveDetector;1 [(-8.5, 2.5), (-4.5, 6.5), (3.5, 10.5), (23.5, 16.5), (17.5, 19.5), (-13.5, 30.5)]
# /DSPD_+x_44_photoSensor_surface_sensitiveDetector;1 [(16.5, -17.5), (-15.5, -16.5), (1.5, -16.5), (14.5, -10.5), (6.5, -9.5), (-24.5, -7.5), (24.5, 4.5), (-37.5, 8.5), (-22.5, 35.5)]
# /DSPD_+x_45_photoSensor_surface_sensitiveDetector;1 [(-5.5, -12.5), (-2.5, -7.5), (21.5, -5.5), (-20.5, 5.5), (19.5, 13.5)]
# /DSPD_+x_46_photoSensor_surface_sensitiveDetector;1 [(13.5, -33.5), (0.5, -28.5), (-5.5, -19.5), (-12.5, -14.5), (-26.5, -13.5), (2.5, -7.5), (20.5, -2.5)]
# /DSPD_+x_47_photoSensor_surface_sensitiveDetector;1 [(-7.5, -39.5), (-25.5, -25.5)]
# /DSPD_+x_48_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_49_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_50_photoSensor_surface_sensitiveDetector;1 [(5.5, -30.5)]
# /DSPD_+x_51_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_52_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_53_photoSensor_surface_sensitiveDetector;1 [(35.5, 5.5), (-18.5, 12.5), (39.5, 26.5), (29.5, 39.5), (-4.5, 42.5)]
# /DSPD_+x_54_photoSensor_surface_sensitiveDetector;1 [(-4.5, -14.5), (3.5, -5.5), (3.5, 15.5), (10.5, 17.5), (13.5, 21.5), (2.5, 22.5), (-0.5, 26.5)]
# /DSPD_+x_55_photoSensor_surface_sensitiveDetector;1 [(-3.5, -32.5), (28.5, -32.5), (-0.5, -29.5), (12.5, -25.5), (31.5, -24.5), (-8.5, -14.5), (1.5, -3.5), (-10.5, -2.5), (24.5, 4.5), (25.5, 18.5)]
# /DSPD_+x_56_photoSensor_surface_sensitiveDetector;1 [(28.5, -10.5), (8.5, -5.5)]
# /DSPD_+x_57_photoSensor_surface_sensitiveDetector;1 [(-8.5, -30.5)]
# /DSPD_+x_58_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_59_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_60_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_61_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_62_photoSensor_surface_sensitiveDetector;1 [(33.5, 31.5), (28.5, 37.5)]
# /DSPD_+x_63_photoSensor_surface_sensitiveDetector;1 [(15.5, 29.5), (34.5, 38.5), (39.5, 41.5)]
# /DSPD_+x_64_photoSensor_surface_sensitiveDetector;1 [(36.5, -21.5), (28.5, -10.5), (19.5, 2.5), (7.5, 15.5), (1.5, 26.5), (21.5, 28.5), (27.5, 30.5)]
# /DSPD_+x_65_photoSensor_surface_sensitiveDetector;1 [(1.5, -32.5), (27.5, -31.5), (28.5, -13.5), (5.5, -6.5)]
# /DSPD_+x_66_photoSensor_surface_sensitiveDetector;1 [(27.5, -11.5), (34.5, -9.5), (8.5, -8.5)]
# /DSPD_+x_67_photoSensor_surface_sensitiveDetector;1 [(18.5, -36.5), (35.5, 27.5)]
# /DSPD_+x_68_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_69_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_70_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_71_photoSensor_surface_sensitiveDetector;1 [(-11.5, 17.5), (-5.5, 23.5)]
# /DSPD_+x_72_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_73_photoSensor_surface_sensitiveDetector;1 [(37.5, 12.5)]
# /DSPD_+x_74_photoSensor_surface_sensitiveDetector;1 [(28.5, -3.5), (42.5, 2.5), (29.5, 34.5)]
# /DSPD_+x_75_photoSensor_surface_sensitiveDetector;1 [(42.5, -6.5), (28.5, 9.5), (-21.5, 13.5)]
# /DSPD_+x_76_photoSensor_surface_sensitiveDetector;1 [(33.5, -24.5), (35.5, -16.5)]
# /DSPD_+x_77_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_78_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_79_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_80_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_81_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_82_photoSensor_surface_sensitiveDetector;1 [(-39.5, 40.5)]
# /DSPD_+x_83_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_84_photoSensor_surface_sensitiveDetector;1 [(-37.5, -3.5)]
# /DSPD_+x_85_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_86_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_87_photoSensor_surface_sensitiveDetector;1 [(-39.5, -41.5)]
# /DSPD_+x_88_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_89_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_90_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_91_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_92_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_93_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_94_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_95_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_96_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_97_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_98_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+x_99_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_0_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_1_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_2_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_3_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_4_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_5_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_6_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_7_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_8_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_9_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_10_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_11_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_12_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_13_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_14_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_15_photoSensor_surface_sensitiveDetector;1 [(40.5, 3.5)]
# /DSPD_-x_16_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_17_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_18_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_19_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_20_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_21_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_22_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_23_photoSensor_surface_sensitiveDetector;1 [(-30.5, 41.5)]
# /DSPD_-x_24_photoSensor_surface_sensitiveDetector;1 [(-40.5, -18.5), (-26.5, -6.5), (-36.5, 19.5), (-41.5, 26.5)]
# /DSPD_-x_25_photoSensor_surface_sensitiveDetector;1 [(-32.5, -35.5), (-31.5, -24.5), (-39.5, -3.5)]
# /DSPD_-x_26_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_27_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_28_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_29_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_30_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_31_photoSensor_surface_sensitiveDetector;1 [(-36.5, -37.5)]
# /DSPD_-x_32_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_33_photoSensor_surface_sensitiveDetector;1 [(-15.5, 22.5), (-16.5, 38.5), (-14.5, 38.5)]
# /DSPD_-x_34_photoSensor_surface_sensitiveDetector;1 [(-24.5, -9.5), (-11.5, 28.5)]
# /DSPD_-x_35_photoSensor_surface_sensitiveDetector;1 [(-35.5, 2.5), (-14.5, 12.5)]
# /DSPD_-x_36_photoSensor_surface_sensitiveDetector;1 [(-19.5, -35.5), (-29.5, -16.5)]
# /DSPD_-x_37_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_38_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_39_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_40_photoSensor_surface_sensitiveDetector;1 [(-5.5, -12.5)]
# /DSPD_-x_41_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_42_photoSensor_surface_sensitiveDetector;1 [(8.5, 31.5), (4.5, 40.5)]
# /DSPD_-x_43_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_44_photoSensor_surface_sensitiveDetector;1 [(19.5, -11.5), (20.5, -0.5), (-15.5, 3.5), (11.5, 12.5), (46.5, 15.5), (22.5, 20.5), (23.5, 20.5), (15.5, 40.5)]
# /DSPD_-x_45_photoSensor_surface_sensitiveDetector;1 [(-25.5, -36.5), (-24.5, -29.5), (-9.5, -11.5), (-35.5, 6.5)]
# /DSPD_-x_46_photoSensor_surface_sensitiveDetector;1 [(-6.5, -38.5), (17.5, -21.5), (20.5, -17.5), (10.5, -10.5), (10.5, -7.5), (0.5, 0.5)]
# /DSPD_-x_47_photoSensor_surface_sensitiveDetector;1 [(-20.5, 20.5)]
# /DSPD_-x_48_photoSensor_surface_sensitiveDetector;1 [(-25.5, 37.5)]
# /DSPD_-x_49_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_50_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_51_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_52_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_53_photoSensor_surface_sensitiveDetector;1 [(12.5, 3.5), (-9.5, 13.5), (-18.5, 20.5), (40.5, 31.5)]
# /DSPD_-x_54_photoSensor_surface_sensitiveDetector;1 [(27.5, -19.5), (19.5, -12.5), (-6.5, -7.5), (12.5, -5.5), (-9.5, 7.5), (3.5, 25.5), (10.5, 26.5), (-1.5, 30.5), (22.5, 32.5)]
# /DSPD_-x_55_photoSensor_surface_sensitiveDetector;1 [(-1.5, -32.5), (-19.5, -23.5), (28.5, -19.5), (-3.5, -13.5), (15.5, -9.5), (-17.5, -5.5), (-7.5, 13.5), (16.5, 21.5)]
# /DSPD_-x_56_photoSensor_surface_sensitiveDetector;1 [(-0.5, -30.5), (-17.5, -16.5), (-14.5, -14.5), (4.5, -0.5)]
# /DSPD_-x_57_photoSensor_surface_sensitiveDetector;1 [(12.5, -27.5)]
# /DSPD_-x_58_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_59_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_60_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_61_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_62_photoSensor_surface_sensitiveDetector;1 [(37.5, 43.5)]
# /DSPD_-x_63_photoSensor_surface_sensitiveDetector;1 [(38.5, 23.5), (40.5, 28.5)]
# /DSPD_-x_64_photoSensor_surface_sensitiveDetector;1 [(4.5, -41.5), (6.5, 6.5), (48.5, 23.5)]
# /DSPD_-x_65_photoSensor_surface_sensitiveDetector;1 [(25.5, -29.5), (42.5, -28.5), (4.5, -21.5), (37.5, -17.5), (2.5, -7.5), (23.5, 0.5)]
# /DSPD_-x_66_photoSensor_surface_sensitiveDetector;1 [(1.5, -34.5), (10.5, -11.5), (3.5, -9.5)]
# /DSPD_-x_67_photoSensor_surface_sensitiveDetector;1 [(26.5, -38.5)]
# /DSPD_-x_68_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_69_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_70_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_71_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_72_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_73_photoSensor_surface_sensitiveDetector;1 [(27.5, 6.5)]
# /DSPD_-x_74_photoSensor_surface_sensitiveDetector;1 [(-19.5, 1.5)]
# /DSPD_-x_75_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_76_photoSensor_surface_sensitiveDetector;1 [(-15.5, -13.5), (44.5, -1.5)]
# /DSPD_-x_77_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_78_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_79_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_80_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_81_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_82_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_83_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_84_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_85_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_86_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_87_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_88_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_89_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_90_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_91_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_92_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_93_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_94_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_95_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_96_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_97_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_98_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-x_99_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_0_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_1_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_2_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_3_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_4_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_5_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_6_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_7_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_8_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_9_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_10_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_11_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_12_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_13_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_14_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_15_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_16_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_17_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_18_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_19_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_20_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_21_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_22_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_23_photoSensor_surface_sensitiveDetector;1 [(32.5, -33.5), (27.5, -28.5)]
# /DSPD_+y_24_photoSensor_surface_sensitiveDetector;1 [(31.5, -19.5), (27.5, -5.5), (35.5, 22.5)]
# /DSPD_+y_25_photoSensor_surface_sensitiveDetector;1 [(37.5, 33.5)]
# /DSPD_+y_26_photoSensor_surface_sensitiveDetector;1 [(31.5, 5.5)]
# /DSPD_+y_27_photoSensor_surface_sensitiveDetector;1 [(40.5, 34.5)]
# /DSPD_+y_28_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_29_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_30_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_31_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_32_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_33_photoSensor_surface_sensitiveDetector;1 [(24.5, -31.5), (21.5, -26.5), (31.5, -20.5)]
# /DSPD_+y_34_photoSensor_surface_sensitiveDetector;1 [(25.5, -21.5), (6.5, -17.5), (17.5, -10.5), (40.5, 9.5), (31.5, 19.5)]
# /DSPD_+y_35_photoSensor_surface_sensitiveDetector;1 [(21.5, -13.5), (22.5, -3.5), (30.5, -2.5), (2.5, 9.5), (17.5, 23.5), (5.5, 31.5), (13.5, 32.5)]
# /DSPD_+y_36_photoSensor_surface_sensitiveDetector;1 [(8.5, 39.5)]
# /DSPD_+y_37_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_38_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_39_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_40_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_41_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_42_photoSensor_surface_sensitiveDetector;1 [(-8.5, -41.5)]
# /DSPD_+y_43_photoSensor_surface_sensitiveDetector;1 [(0.5, -26.5), (-0.5, -21.5), (35.5, -15.5), (22.5, -14.5), (39.5, -8.5)]
# /DSPD_+y_44_photoSensor_surface_sensitiveDetector;1 [(37.5, -35.5), (11.5, -27.5), (-20.5, -14.5), (-23.5, -9.5), (-10.5, -9.5), (-8.5, -9.5), (27.5, 1.5), (15.5, 15.5), (19.5, 17.5), (-17.5, 18.5), (30.5, 23.5), (3.5, 24.5)]
# /DSPD_+y_45_photoSensor_surface_sensitiveDetector;1 [(4.5, -5.5), (4.5, 1.5), (-3.5, 7.5), (-15.5, 16.5), (26.5, 17.5), (38.5, 31.5)]
# /DSPD_+y_46_photoSensor_surface_sensitiveDetector;1 [(38.5, 13.5), (29.5, 19.5)]
# /DSPD_+y_47_photoSensor_surface_sensitiveDetector;1 [(9.5, -20.5), (29.5, 39.5)]
# /DSPD_+y_48_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_49_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_50_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_51_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_52_photoSensor_surface_sensitiveDetector;1 [(-7.5, -41.5), (16.5, -27.5)]
# /DSPD_+y_53_photoSensor_surface_sensitiveDetector;1 [(-18.5, -39.5), (-20.5, -34.5), (6.5, -28.5), (-5.5, -23.5), (23.5, -12.5), (-17.5, -8.5), (5.5, 0.5)]
# /DSPD_+y_54_photoSensor_surface_sensitiveDetector;1 [(-28.5, -34.5), (-31.5, -32.5), (-8.5, -24.5), (-27.5, -19.5), (9.5, -19.5), (-20.5, -16.5), (13.5, -10.5), (-26.5, 19.5)]
# /DSPD_+y_55_photoSensor_surface_sensitiveDetector;1 [(-4.5, -9.5), (-37.5, -3.5), (-18.5, -3.5), (-30.5, -1.5), (-26.5, -0.5), (-38.5, 27.5), (-25.5, 29.5), (5.5, 30.5), (-28.5, 31.5), (-11.5, 32.5)]
# /DSPD_+y_56_photoSensor_surface_sensitiveDetector;1 [(-38.5, 17.5), (-26.5, 18.5)]
# /DSPD_+y_57_photoSensor_surface_sensitiveDetector;1 [(-16.5, -20.5)]
# /DSPD_+y_58_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_59_photoSensor_surface_sensitiveDetector;1 [(-9.5, 2.5)]
# /DSPD_+y_60_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_61_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_62_photoSensor_surface_sensitiveDetector;1 [(-18.5, -29.5), (-24.5, -26.5)]
# /DSPD_+y_63_photoSensor_surface_sensitiveDetector;1 [(-31.5, -4.5), (-32.5, -0.5)]
# /DSPD_+y_64_photoSensor_surface_sensitiveDetector;1 [(-15.5, -37.5), (-24.5, -14.5), (-22.5, -6.5), (-19.5, 1.5), (-15.5, 4.5)]
# /DSPD_+y_65_photoSensor_surface_sensitiveDetector;1 [(-16.5, -20.5), (-28.5, -19.5), (-23.5, -10.5), (-13.5, 15.5), (-32.5, 18.5), (-1.5, 35.5)]
# /DSPD_+y_66_photoSensor_surface_sensitiveDetector;1 [(-8.5, 19.5), (-1.5, 19.5), (-10.5, 28.5)]
# /DSPD_+y_67_photoSensor_surface_sensitiveDetector;1 [(-4.5, 34.5), (-21.5, 35.5)]
# /DSPD_+y_68_photoSensor_surface_sensitiveDetector;1 [(-24.5, -38.5)]
# /DSPD_+y_69_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_70_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_71_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_72_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_73_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_74_photoSensor_surface_sensitiveDetector;1 [(-37.5, -38.5), (-38.5, -36.5)]
# /DSPD_+y_75_photoSensor_surface_sensitiveDetector;1 [(-38.5, 31.5)]
# /DSPD_+y_76_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_77_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_78_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_79_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_80_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_81_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_82_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_83_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_84_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_85_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_86_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_87_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_88_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_89_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_90_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_91_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_92_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_93_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_94_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_95_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_96_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_97_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_98_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+y_99_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_0_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_1_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_2_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_3_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_4_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_5_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_6_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_7_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_8_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_9_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_10_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_11_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_12_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_13_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_14_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_15_photoSensor_surface_sensitiveDetector;1 [(-36.5, 26.5)]
# /DSPD_-y_16_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_17_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_18_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_19_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_20_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_21_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_22_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_23_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_24_photoSensor_surface_sensitiveDetector;1 [(40.5, -4.5), (38.5, 1.5), (38.5, 8.5)]
# /DSPD_-y_25_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_26_photoSensor_surface_sensitiveDetector;1 [(39.5, 27.5)]
# /DSPD_-y_27_photoSensor_surface_sensitiveDetector;1 [(43.5, 34.5)]
# /DSPD_-y_28_photoSensor_surface_sensitiveDetector;1 [(37.5, -41.5)]
# /DSPD_-y_29_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_30_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_31_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_32_photoSensor_surface_sensitiveDetector;1 [(19.5, -40.5), (19.5, -35.5)]
# /DSPD_-y_33_photoSensor_surface_sensitiveDetector;1 [(18.5, -37.5), (0.5, -28.5), (17.5, -21.5), (10.5, -14.5), (39.5, -13.5)]
# /DSPD_-y_34_photoSensor_surface_sensitiveDetector;1 [(15.5, -17.5), (9.5, -13.5), (5.5, 2.5), (40.5, 7.5)]
# /DSPD_-y_35_photoSensor_surface_sensitiveDetector;1 [(42.5, -11.5), (20.5, -4.5), (28.5, 22.5), (15.5, 39.5)]
# /DSPD_-y_36_photoSensor_surface_sensitiveDetector;1 [(4.5, 2.5), (36.5, 11.5), (27.5, 28.5)]
# /DSPD_-y_37_photoSensor_surface_sensitiveDetector;1 [(38.5, 29.5), (29.5, 38.5), (6.5, 43.5)]
# /DSPD_-y_38_photoSensor_surface_sensitiveDetector;1 [(33.5, -37.5)]
# /DSPD_-y_39_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_40_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_41_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_42_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_43_photoSensor_surface_sensitiveDetector;1 [(26.5, -38.5), (-20.5, -37.5), (-16.5, -36.5), (-14.5, -16.5), (35.5, 0.5)]
# /DSPD_-y_44_photoSensor_surface_sensitiveDetector;1 [(9.5, -36.5), (28.5, -34.5), (18.5, -20.5), (-11.5, -14.5)]
# /DSPD_-y_45_photoSensor_surface_sensitiveDetector;1 [(38.5, -16.5), (21.5, -2.5), (25.5, 12.5), (16.5, 14.5), (21.5, 14.5), (-21.5, 25.5), (36.5, 30.5), (-17.5, 34.5)]
# /DSPD_-y_46_photoSensor_surface_sensitiveDetector;1 [(-5.5, 6.5), (-7.5, 10.5), (16.5, 15.5), (39.5, 23.5), (-7.5, 26.5), (33.5, 40.5)]
# /DSPD_-y_47_photoSensor_surface_sensitiveDetector;1 [(2.5, 36.5)]
# /DSPD_-y_48_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_49_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_50_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_51_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_52_photoSensor_surface_sensitiveDetector;1 [(-6.5, -37.5), (11.5, -33.5)]
# /DSPD_-y_53_photoSensor_surface_sensitiveDetector;1 [(4.5, -31.5), (21.5, -27.5), (-13.5, -23.5), (21.5, -6.5), (-10.5, 1.5)]
# /DSPD_-y_54_photoSensor_surface_sensitiveDetector;1 [(11.5, -20.5), (6.5, -12.5), (13.5, -12.5), (-0.5, -11.5), (-14.5, -5.5), (20.5, -4.5), (22.5, -4.5), (12.5, 8.5)]
# /DSPD_-y_55_photoSensor_surface_sensitiveDetector;1 [(21.5, 1.5), (-35.5, 3.5)]
# /DSPD_-y_56_photoSensor_surface_sensitiveDetector;1 [(-33.5, -16.5), (-38.5, 4.5), (-36.5, 24.5), (-4.5, 32.5), (-10.5, 36.5), (14.5, 38.5)]
# /DSPD_-y_57_photoSensor_surface_sensitiveDetector;1 [(4.5, 42.5)]
# /DSPD_-y_58_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_59_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_60_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_61_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_62_photoSensor_surface_sensitiveDetector;1 [(-21.5, -32.5)]
# /DSPD_-y_63_photoSensor_surface_sensitiveDetector;1 [(-29.5, -36.5), (-16.5, -24.5)]
# /DSPD_-y_64_photoSensor_surface_sensitiveDetector;1 [(32.5, -19.5), (-23.5, -18.5)]
# /DSPD_-y_65_photoSensor_surface_sensitiveDetector;1 [(-28.5, 19.5)]
# /DSPD_-y_66_photoSensor_surface_sensitiveDetector;1 [(-36.5, 10.5), (-26.5, 14.5), (-27.5, 15.5), (-26.5, 29.5)]
# /DSPD_-y_67_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_68_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_69_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_70_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_71_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_72_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_73_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_74_photoSensor_surface_sensitiveDetector;1 [(21.5, -22.5), (-30.5, -7.5)]
# /DSPD_-y_75_photoSensor_surface_sensitiveDetector;1 [(-35.5, 8.5)]
# /DSPD_-y_76_photoSensor_surface_sensitiveDetector;1 [(-29.5, 5.5)]
# /DSPD_-y_77_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_78_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_79_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_80_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_81_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_82_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_83_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_84_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_85_photoSensor_surface_sensitiveDetector;1 [(41.5, 2.5)]
# /DSPD_-y_86_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_87_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_88_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_89_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_90_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_91_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_92_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_93_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_94_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_95_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_96_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_97_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_98_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-y_99_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_0_photoSensor_surface_sensitiveDetector;1 [(25.5, -37.5)]
# /DSPD_+z_1_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_2_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_3_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_4_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_5_photoSensor_surface_sensitiveDetector;1 [(37.5, -8.5)]
# /DSPD_+z_6_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_7_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_8_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_9_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_10_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_11_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_12_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_13_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_14_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_15_photoSensor_surface_sensitiveDetector;1 [(43.5, 3.5)]
# /DSPD_+z_16_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_17_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_18_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_19_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_20_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_21_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_22_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_23_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_24_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_25_photoSensor_surface_sensitiveDetector;1 [(27.5, 8.5)]
# /DSPD_+z_26_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_27_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_28_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_29_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_30_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_31_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_32_photoSensor_surface_sensitiveDetector;1 [(41.5, 23.5), (23.5, 30.5)]
# /DSPD_+z_33_photoSensor_surface_sensitiveDetector;1 [(16.5, -2.5), (1.5, -1.5), (23.5, -1.5), (5.5, 11.5), (0.5, 23.5)]
# /DSPD_+z_34_photoSensor_surface_sensitiveDetector;1 [(37.5, 32.5)]
# /DSPD_+z_35_photoSensor_surface_sensitiveDetector;1 [(15.5, -38.5), (39.5, -17.5), (-4.5, 2.5), (3.5, 15.5), (15.5, 15.5), (32.5, 16.5)]
# /DSPD_+z_36_photoSensor_surface_sensitiveDetector;1 [(11.5, -5.5)]
# /DSPD_+z_37_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_38_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_39_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_40_photoSensor_surface_sensitiveDetector;1 [(9.5, 20.5)]
# /DSPD_+z_41_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_42_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_43_photoSensor_surface_sensitiveDetector;1 [(36.5, 3.5), (4.5, 28.5)]
# /DSPD_+z_44_photoSensor_surface_sensitiveDetector;1 [(1.5, -24.5), (16.5, -5.5), (8.5, 19.5), (29.5, 25.5), (-12.5, 30.5), (0.5, 39.5)]
# /DSPD_+z_45_photoSensor_surface_sensitiveDetector;1 [(-9.5, -32.5), (-5.5, -32.5), (39.5, -22.5), (18.5, -9.5), (19.5, -8.5), (13.5, 10.5)]
# /DSPD_+z_46_photoSensor_surface_sensitiveDetector;1 [(18.5, -27.5), (-25.5, -15.5), (40.5, -14.5)]
# /DSPD_+z_47_photoSensor_surface_sensitiveDetector;1 [(-18.5, -33.5), (19.5, -17.5), (30.5, -17.5), (-11.5, -16.5)]
# /DSPD_+z_48_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_49_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_50_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_51_photoSensor_surface_sensitiveDetector;1 [(-20.5, 44.5)]
# /DSPD_+z_52_photoSensor_surface_sensitiveDetector;1 [(-5.5, 35.5)]
# /DSPD_+z_53_photoSensor_surface_sensitiveDetector;1 [(-35.5, 3.5), (-3.5, 12.5), (-20.5, 20.5), (7.5, 24.5), (-10.5, 27.5)]
# /DSPD_+z_54_photoSensor_surface_sensitiveDetector;1 [(10.5, -19.5), (-0.5, -11.5), (-18.5, -8.5), (13.5, -1.5), (-26.5, 14.5), (4.5, 14.5)]
# /DSPD_+z_55_photoSensor_surface_sensitiveDetector;1 [(22.5, -34.5), (-27.5, -30.5), (23.5, -27.5), (-10.5, -1.5), (-6.5, 8.5), (-37.5, 12.5), (-7.5, 17.5)]
# /DSPD_+z_56_photoSensor_surface_sensitiveDetector;1 [(-5.5, -40.5), (-0.5, -40.5), (25.5, -28.5), (-10.5, -26.5), (-11.5, -24.5), (-12.5, -17.5), (-17.5, -15.5), (-25.5, -5.5), (25.5, -0.5)]
# /DSPD_+z_57_photoSensor_surface_sensitiveDetector;1 [(6.5, -34.5), (7.5, -30.5), (-12.5, -18.5)]
# /DSPD_+z_58_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_59_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_60_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_61_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_62_photoSensor_surface_sensitiveDetector;1 [(-7.5, 26.5), (0.5, 26.5)]
# /DSPD_+z_63_photoSensor_surface_sensitiveDetector;1 [(-19.5, -0.5), (-26.5, 1.5), (-38.5, 27.5)]
# /DSPD_+z_64_photoSensor_surface_sensitiveDetector;1 [(-2.5, -20.5), (-20.5, -0.5), (-26.5, 12.5), (2.5, 25.5), (-24.5, 29.5)]
# /DSPD_+z_65_photoSensor_surface_sensitiveDetector;1 [(-39.5, -38.5), (-35.5, -24.5), (-18.5, -21.5), (-13.5, -16.5), (-14.5, -8.5), (-40.5, 1.5), (-37.5, 6.5), (-20.5, 6.5), (-1.5, 25.5)]
# /DSPD_+z_66_photoSensor_surface_sensitiveDetector;1 [(-30.5, -39.5), (-36.5, 7.5)]
# /DSPD_+z_67_photoSensor_surface_sensitiveDetector;1 [(-21.5, 24.5)]
# /DSPD_+z_68_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_69_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_70_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_71_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_72_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_73_photoSensor_surface_sensitiveDetector;1 [(-30.5, 5.5), (-26.5, 14.5), (-19.5, 27.5), (-37.5, 36.5)]
# /DSPD_+z_74_photoSensor_surface_sensitiveDetector;1 [(-35.5, -21.5)]
# /DSPD_+z_75_photoSensor_surface_sensitiveDetector;1 [(-34.5, 12.5)]
# /DSPD_+z_76_photoSensor_surface_sensitiveDetector;1 [(-35.5, -25.5), (-30.5, -10.5)]
# /DSPD_+z_77_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_78_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_79_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_80_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_81_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_82_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_83_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_84_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_85_photoSensor_surface_sensitiveDetector;1 [(-42.5, 3.5)]
# /DSPD_+z_86_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_87_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_88_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_89_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_90_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_91_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_92_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_93_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_94_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_95_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_96_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_97_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_98_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_+z_99_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_0_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_1_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_2_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_3_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_4_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_5_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_6_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_7_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_8_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_9_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_10_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_11_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_12_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_13_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_14_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_15_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_16_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_17_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_18_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_19_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_20_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_21_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_22_photoSensor_surface_sensitiveDetector;1 [(30.5, 24.5), (27.5, 28.5), (33.5, 31.5), (35.5, 36.5), (34.5, 42.5)]
# /DSPD_-z_23_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_24_photoSensor_surface_sensitiveDetector;1 [(22.5, -5.5), (20.5, 3.5), (37.5, 3.5)]
# /DSPD_-z_25_photoSensor_surface_sensitiveDetector;1 [(19.5, -10.5)]
# /DSPD_-z_26_photoSensor_surface_sensitiveDetector;1 [(27.5, -29.5)]
# /DSPD_-z_27_photoSensor_surface_sensitiveDetector;1 [(33.5, -31.5), (29.5, -28.5), (36.5, -23.5)]
# /DSPD_-z_28_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_29_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_30_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_31_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_32_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_33_photoSensor_surface_sensitiveDetector;1 [(5.5, 6.5), (25.5, 37.5), (9.5, 41.5)]
# /DSPD_-z_34_photoSensor_surface_sensitiveDetector;1 [(37.5, -13.5), (32.5, 15.5), (11.5, 30.5), (31.5, 38.5)]
# /DSPD_-z_35_photoSensor_surface_sensitiveDetector;1 [(31.5, -5.5), (20.5, 3.5)]
# /DSPD_-z_36_photoSensor_surface_sensitiveDetector;1 [(10.5, -22.5), (4.5, -13.5)]
# /DSPD_-z_37_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_38_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_39_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_40_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_41_photoSensor_surface_sensitiveDetector;1 [(26.5, 43.5)]
# /DSPD_-z_42_photoSensor_surface_sensitiveDetector;1 [(15.5, 28.5), (12.5, 37.5), (-12.5, 38.5)]
# /DSPD_-z_43_photoSensor_surface_sensitiveDetector;1 [(13.5, -4.5), (3.5, 1.5), (-17.5, 18.5), (-23.5, 23.5)]
# /DSPD_-z_44_photoSensor_surface_sensitiveDetector;1 [(15.5, -18.5), (7.5, -15.5), (18.5, -10.5), (-2.5, 14.5), (18.5, 17.5), (-10.5, 34.5)]
# /DSPD_-z_45_photoSensor_surface_sensitiveDetector;1 [(25.5, -36.5), (39.5, -21.5), (-24.5, -9.5), (-2.5, -3.5), (5.5, 0.5), (-7.5, 23.5)]
# /DSPD_-z_46_photoSensor_surface_sensitiveDetector;1 [(14.5, -29.5), (-15.5, -26.5), (-1.5, -25.5), (13.5, -19.5), (17.5, 0.5), (3.5, 3.5), (1.5, 4.5)]
# /DSPD_-z_47_photoSensor_surface_sensitiveDetector;1 [(-2.5, -41.5), (34.5, -29.5), (7.5, -22.5)]
# /DSPD_-z_48_photoSensor_surface_sensitiveDetector;1 [(20.5, -42.5)]
# /DSPD_-z_49_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_50_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_51_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_52_photoSensor_surface_sensitiveDetector;1 [(-20.5, 25.5)]
# /DSPD_-z_53_photoSensor_surface_sensitiveDetector;1 [(-6.5, 28.5), (-3.5, 40.5)]
# /DSPD_-z_54_photoSensor_surface_sensitiveDetector;1 [(25.5, -9.5), (20.5, 2.5), (7.5, 25.5), (22.5, 28.5), (8.5, 40.5)]
# /DSPD_-z_55_photoSensor_surface_sensitiveDetector;1 [(25.5, -29.5), (22.5, -26.5), (-30.5, -8.5), (18.5, -5.5), (-21.5, 10.5), (-2.5, 18.5)]
# /DSPD_-z_56_photoSensor_surface_sensitiveDetector;1 [(14.5, -36.5), (1.5, -31.5), (-4.5, -27.5), (-13.5, -20.5), (4.5, -15.5), (-24.5, -2.5), (-29.5, 3.5)]
# /DSPD_-z_57_photoSensor_surface_sensitiveDetector;1 [(0.5, -26.5), (-27.5, -17.5), (-14.5, -17.5)]
# /DSPD_-z_58_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_59_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_60_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_61_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_62_photoSensor_surface_sensitiveDetector;1 [(-36.5, 23.5), (-19.5, 42.5)]
# /DSPD_-z_63_photoSensor_surface_sensitiveDetector;1 [(-24.5, 27.5)]
# /DSPD_-z_64_photoSensor_surface_sensitiveDetector;1 [(-18.5, -9.5), (-25.5, -7.5), (3.5, -7.5), (-21.5, -3.5), (-26.5, 3.5), (-8.5, 6.5), (-10.5, 11.5), (-6.5, 28.5)]
# /DSPD_-z_65_photoSensor_surface_sensitiveDetector;1 [(-20.5, -39.5), (5.5, -14.5), (1.5, -8.5), (-6.5, 11.5), (1.5, 20.5)]
# /DSPD_-z_66_photoSensor_surface_sensitiveDetector;1 [(-20.5, -38.5), (-15.5, -36.5), (-0.5, -36.5), (-11.5, -31.5), (-36.5, -17.5)]
# /DSPD_-z_67_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_68_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_69_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_70_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_71_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_72_photoSensor_surface_sensitiveDetector;1 [(-32.5, 21.5)]
# /DSPD_-z_73_photoSensor_surface_sensitiveDetector;1 [(-18.5, 21.5)]
# /DSPD_-z_74_photoSensor_surface_sensitiveDetector;1 [(-40.5, 7.5), (-38.5, 17.5), (-19.5, 27.5), (2.5, 33.5)]
# /DSPD_-z_75_photoSensor_surface_sensitiveDetector;1 [(-37.5, -25.5), (-15.5, -24.5), (-26.5, -4.5)]
# /DSPD_-z_76_photoSensor_surface_sensitiveDetector;1 [(-26.5, -17.5)]
# /DSPD_-z_77_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_78_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_79_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_80_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_81_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_82_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_83_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_84_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_85_photoSensor_surface_sensitiveDetector;1 [(-42.5, -31.5), (-41.5, 1.5)]
# /DSPD_-z_86_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_87_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_88_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_89_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_90_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_91_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_92_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_93_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_94_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_95_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_96_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_97_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_98_photoSensor_surface_sensitiveDetector;1 []
# /DSPD_-z_99_photoSensor_surface_sensitiveDetector;1 []

# %%
# Find the entry in hits_library with the largest length
# make a list of the index and length
lengths = [(i, len(hits)) for i, hits in enumerate(hits_list_library.values())]
lengths.sort(key=lambda x: x[1])

plt.hist([lengths[i][1] for i in range(len(lengths))])
plt.xlabel("Number of hits")
plt.ylabel("")
plt.title("Number of hits per detector")
plt.grid()
plt.show()

# %%
index, length = lengths[-1]
hits = list(hits_list_library.values())[index]
values = list(hits_hist_library.values())[index]

plt.imshow(values, extent=(x_edges[0], x_edges[-1], y_edges[0], y_edges[-1]), aspect='auto', origin='lower', cmap='viridis')
plt.plot([x[0] for x in hits], [x[1] for x in hits], 'o', alpha=0.1, color='red')
plt.colorbar()
plt.xlabel("X-axis Label")
plt.ylabel("Y-axis Label")
plt.title("2D Histogram")
plt.show()

# %%
# Load the trees from the root file
tree_library = {}
tree_branch_library = {}
branch_data = {}
for name in tree_names:
    tree_library[name] = file_input_uproot[name]
    tree_branch_library[name] = tree_library[name].keys()
    for key in tree_branch_library[name]:
        branch_data[key] = tree_library[name][key].array()

# %%
# %matplotlib qt

# %%
primary_position_x  = np.array(branch_data['primary_position_x'])
primary_position_y  = np.array(branch_data['primary_position_y'])
primary_position_z  = np.array(branch_data['primary_position_z'])
primary_direction_x = np.array(branch_data['primary_direction_x'])
primary_direction_y = np.array(branch_data['primary_direction_y'])
primary_direction_z = np.array(branch_data['primary_direction_z'])

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.quiver(primary_position_x , primary_position_y , primary_position_z , 
          primary_direction_x, primary_direction_y, primary_direction_z, 
          length=0.1, color='red')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()

# %%
# %matplotlib inline

# %%
# Extract the data for photon_process and photon_volume
photon_process = branch_data['photon_process']
photon_volume = branch_data['photon_volume']

# Make a list of the unique photon_process and photon_volume values
unique_photon_process = np.unique(photon_process)
unique_photon_volume = np.unique(photon_volume)

# Make a dictionary to store the number of photons in each process and volume
photon_process_count = {}
photon_volume_count = {}

# Loop over the unique photon_process values
for process in unique_photon_process:
    # Get the indices for the current process
    indices = np.where(photon_process == process)
    # Store the number of photons in the current process
    photon_process_count[process] = len(indices[0])

# Loop over the unique photon_volume values
for volume in unique_photon_volume:
    # Get the indices for the current volume
    indices = np.where(photon_volume == volume)
    # Store the number of photons in the current volume
    photon_volume_count[volume] = len(indices[0])

# Print the photon_process_count and photon_volume_count dictionaries
print(photon_process_count)
print(photon_volume_count)

# Combine individualy named volumes into more general volumes
photon_volume_general_count = {}
for volume in photon_volume_count:
    if 'lensSystem_solid' in volume:
        photon_volume_general_count['lensSystem_solid'] = photon_volume_general_count.get('lensSystem_solid', 0) + photon_volume_count[volume]
    elif 'photoSensor_surface' in volume:
        photon_volume_general_count['photoSensor_surface'] = photon_volume_general_count.get('photoSensor_surface', 0) + photon_volume_count[volume]
    elif 'photoSensor_body' in volume:
        photon_volume_general_count['phototSensor_body'] = photon_volume_general_count.get('phototSensor_body', 0) + photon_volume_count[volume]
    elif 'calorimeter_horizontal' in volume:
        photon_volume_general_count['calorimeter_horizontal'] = photon_volume_general_count.get('calorimeter_horizontal', 0) + photon_volume_count[volume]
    elif 'calorimeter_vertical' in volume:
        photon_volume_general_count['calorimeter_vertical'] = photon_volume_general_count.get('calorimeter_vertical', 0) + photon_volume_count[volume]
    elif 'calorimeter_middle' in volume:
        photon_volume_general_count['calorimeter_middle'] = photon_volume_general_count.get('calorimeter_middle', 0) + photon_volume_count[volume]
    else:
        photon_volume_general_count[volume] = photon_volume_general_count.get(volume, 0) + photon_volume_count[volume]

# Print the photon_volume_general_count dictionary
print(photon_volume_general_count)
# Out:
# {'OpAbsorption': 28741, 'OpRayleigh': 98, 'Transportation': 15598, 'compt': 1, 'phot': 4}
# {'/DSPD_+x_10_lensSystem_solid': 2, '/DSPD_+x_11_lensSystem_solid': 2, '/DSPD_+x_12_lensSystem_solid': 7, '/DSPD_+x_13_lensSystem_solid': 4, '/DSPD_+x_14_lensSystem_solid': 11, '/DSPD_+x_15_lensSystem_solid': 10, '/DSPD_+x_15_photoSensor_body': 1, '/DSPD_+x_16_lensSystem_solid': 7, '/DSPD_+x_17_lensSystem_solid': 3, '/DSPD_+x_18_lensSystem_solid': 7, '/DSPD_+x_19_lensSystem_solid': 6, '/DSPD_+x_1_lensSystem_solid': 3, '/DSPD_+x_21_lensSystem_solid': 10, '/DSPD_+x_22_lensSystem_solid': 14, '/DSPD_+x_23_lensSystem_solid': 15, '/DSPD_+x_23_photoSensor_body': 1, '/DSPD_+x_23_photoSensor_surface': 1, '/DSPD_+x_24_lensSystem_solid': 19, '/DSPD_+x_24_photoSensor_body': 2, '/DSPD_+x_24_photoSensor_surface': 2, '/DSPD_+x_25_lensSystem_solid': 15, '/DSPD_+x_25_photoSensor_body': 1, '/DSPD_+x_25_photoSensor_surface': 1, '/DSPD_+x_26_lensSystem_solid': 14, '/DSPD_+x_26_photoSensor_body': 1, '/DSPD_+x_26_photoSensor_surface': 1, '/DSPD_+x_27_lensSystem_solid': 8, '/DSPD_+x_28_lensSystem_solid': 14, '/DSPD_+x_29_lensSystem_solid': 1, '/DSPD_+x_2_lensSystem_solid': 5, '/DSPD_+x_30_lensSystem_solid': 4, '/DSPD_+x_31_lensSystem_solid': 10, '/DSPD_+x_32_lensSystem_solid': 6, '/DSPD_+x_33_lensSystem_solid': 20, '/DSPD_+x_33_photoSensor_body': 5, '/DSPD_+x_33_photoSensor_surface': 5, '/DSPD_+x_34_lensSystem_solid': 20, '/DSPD_+x_34_photoSensor_body': 1, '/DSPD_+x_34_photoSensor_surface': 1, '/DSPD_+x_35_lensSystem_solid': 21, '/DSPD_+x_35_photoSensor_body': 3, '/DSPD_+x_35_photoSensor_surface': 3, '/DSPD_+x_36_lensSystem_solid': 17, '/DSPD_+x_36_photoSensor_body': 2, '/DSPD_+x_36_photoSensor_surface': 2, '/DSPD_+x_37_lensSystem_solid': 15, '/DSPD_+x_38_lensSystem_solid': 4, '/DSPD_+x_39_lensSystem_solid': 6, '/DSPD_+x_3_lensSystem_solid': 2, '/DSPD_+x_40_lensSystem_solid': 8, '/DSPD_+x_41_lensSystem_solid': 16, '/DSPD_+x_42_lensSystem_solid': 14, '/DSPD_+x_43_lensSystem_solid': 20, '/DSPD_+x_43_photoSensor_body': 6, '/DSPD_+x_43_photoSensor_surface': 6, '/DSPD_+x_44_lensSystem_solid': 35, '/DSPD_+x_44_photoSensor_body': 9, '/DSPD_+x_44_photoSensor_surface': 9, '/DSPD_+x_45_lensSystem_solid': 23, '/DSPD_+x_45_photoSensor_body': 5, '/DSPD_+x_45_photoSensor_surface': 5, '/DSPD_+x_46_lensSystem_solid': 34, '/DSPD_+x_46_photoSensor_body': 7, '/DSPD_+x_46_photoSensor_surface': 7, '/DSPD_+x_47_lensSystem_solid': 25, '/DSPD_+x_47_photoSensor_body': 2, '/DSPD_+x_47_photoSensor_surface': 2, '/DSPD_+x_48_lensSystem_solid': 9, '/DSPD_+x_49_lensSystem_solid': 7, '/DSPD_+x_4_lensSystem_solid': 4, '/DSPD_+x_50_lensSystem_solid': 5, '/DSPD_+x_50_photoSensor_body': 1, '/DSPD_+x_50_photoSensor_surface': 1, '/DSPD_+x_51_lensSystem_solid': 16, '/DSPD_+x_52_lensSystem_solid': 20, '/DSPD_+x_53_lensSystem_solid': 19, '/DSPD_+x_53_photoSensor_body': 5, '/DSPD_+x_53_photoSensor_surface': 5, '/DSPD_+x_54_lensSystem_solid': 30, '/DSPD_+x_54_photoSensor_body': 7, '/DSPD_+x_54_photoSensor_surface': 7, '/DSPD_+x_55_lensSystem_solid': 34, '/DSPD_+x_55_photoSensor_body': 10, '/DSPD_+x_55_photoSensor_surface': 10, '/DSPD_+x_56_lensSystem_solid': 13, '/DSPD_+x_56_photoSensor_body': 3, '/DSPD_+x_56_photoSensor_surface': 2, '/DSPD_+x_57_lensSystem_solid': 8, '/DSPD_+x_57_photoSensor_body': 1, '/DSPD_+x_57_photoSensor_surface': 1, '/DSPD_+x_58_lensSystem_solid': 8, '/DSPD_+x_59_lensSystem_solid': 9, '/DSPD_+x_60_lensSystem_solid': 2, '/DSPD_+x_61_lensSystem_solid': 3, '/DSPD_+x_62_lensSystem_solid': 14, '/DSPD_+x_62_photoSensor_body': 2, '/DSPD_+x_62_photoSensor_surface': 2, '/DSPD_+x_63_lensSystem_solid': 22, '/DSPD_+x_63_photoSensor_body': 3, '/DSPD_+x_63_photoSensor_surface': 3, '/DSPD_+x_64_lensSystem_solid': 30, '/DSPD_+x_64_photoSensor_body': 7, '/DSPD_+x_64_photoSensor_surface': 7, '/DSPD_+x_65_lensSystem_solid': 13, '/DSPD_+x_65_photoSensor_body': 4, '/DSPD_+x_65_photoSensor_surface': 4, '/DSPD_+x_66_lensSystem_solid': 26, '/DSPD_+x_66_photoSensor_body': 3, '/DSPD_+x_66_photoSensor_surface': 3, '/DSPD_+x_67_lensSystem_solid': 8, '/DSPD_+x_67_photoSensor_body': 2, '/DSPD_+x_6 ...
# {'lensSystem_solid': 5590, 'phototSensor_body': 613, 'photoSensor_surface': 611, 'calorimeter_horizontal': 2040, 'calorimeter_middle': 1, 'calorimeter_vertical': 1932, 'detector_medium': 32477, 'detector_wall': 576, 'world': 602}

# %%
photon_volume_general_count_values = list(photon_volume_general_count.values())
photon_process_count_values = list(photon_process_count.values())

print(photon_volume_general_count_values)
print(photon_process_count_values)

convolution_matrix = np.outer(photon_process_count_values, photon_volume_general_count_values)
plt.imshow(convolution_matrix, cmap='viridis')
plt.xlabel("Photon Volume General Count")
plt.ylabel("Photon Process Count")
plt.yticks(range(len(photon_process_count)), photon_process_count.keys())
plt.xticks(range(len(photon_volume_general_count)), photon_volume_general_count.keys())
plt.xticks(rotation=90)
plt.colorbar()
plt.show()
# Out:
# [5590, 613, 611, 2040, 1, 1932, 32477, 576, 602]
# [28741, 98, 15598, 1, 4]
