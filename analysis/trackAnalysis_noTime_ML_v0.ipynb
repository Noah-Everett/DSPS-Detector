# %% [markdown]
# # Initialize Notebook

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.colors import LogNorm
from matplotlib import cm
from matplotlib.animation import FuncAnimation
from matplotlib.colors import ListedColormap
import matplotlib.patheffects as pe
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.patches import PathPatch
from matplotlib.path import Path
import tensorflow as tf
import ROOT
import uproot
import os
import sys
import tqdm
import pandas as pd
import pickle as pkl
from sklearn.decomposition import PCA
from sklearn.model_selection import KFold
from scipy.spatial.distance import cdist

# %jsroot on
# %matplotlib qt
# %matplotlib inline
# Out:
# Welcome to JupyROOT 6.30/02

# %%
sys.path.append('../python/')
from filterMethods import *
from timeMethods import *
from gridMethods import *
from trackReconstructionMethods import *
from vertexReconstructionMethods import *
from hitAccuracyMethods import *
from statisticsMethods import *
from importMethods import *
from constants import *
import plotParameters

# %%
os.environ['PYDEVD_DISABLE_FILE_VALIDATION'] = '1'

# %% [markdown]
# # Load Data

# %%
# fileName = '../runs/event_2mu100MeVBackToBack_usedForTrackReconstruction.root'
# fileName = '../runs/calibration_2.42^3_10000gamma_1000events.root'
# fileName = '../runs/calibration_2.42^3_10000gamma_1000events_0cmFOVL_+-1.21randPosNoSteps_randDir.root'
# fileName = '../runs/calibration_2.42^3_10000gamma_1000events_20cmFOVL.root'
# fileName = '../build/calibration.root'
# fileName = '../build/event100.root'
# fileNames = [
#     '../build/event_1.root',
#     '../build/event_2.root'
# ]
fileNames = ['../build/multievent_{}.root'.format(i) for i in range(200)] # 100

histDir = '/photoSensor_hits_histograms'
treeName = 'photoSensor_hits;1'
    
minInitialPositions = 10
fileNames = [fileName for fileName in fileNames if len(get_photosensor_hits_position_initial(fileName, treeName)) > minInitialPositions]
print('len(fileNames):', len(fileNames))

# for fileName in tqdm.tqdm(fileNames):
    # print(get_histogram_names    (fileName, histDir))
    # print(get_histogram_titles   (fileName, histDir))
    # print(get_histogram_positions(fileName, histDir))
    # print(get_histogram_walls    (fileName, histDir))
    # print()
# Out:
# len(fileNames): 141

# %%
treeName = 'photoSensor_hits;1'
dfs_hits = []
for fileName in tqdm.tqdm(fileNames):
    df_hits = pd.DataFrame(columns=['sensor_name', 'sensor_direction', 'sensor_position', 'relativePosition', 'relativePosition_binned', 'time'])
    df_hits['sensor_name'            ] = get_photosensor_hits_photosensor_ID          (fileName, treeName)
    df_hits['sensor_direction'       ] = get_photosensor_hits_photosensor_direction   (fileName, treeName)
    df_hits['sensor_position'        ] = get_photosensor_hits_photosensor_position    (fileName, treeName)
    df_hits['sensor_wall'            ] = get_photosensor_hits_photosensor_wall        (fileName, treeName)
    df_hits['relativePosition'       ] = get_photosensor_hits_position_relative       (fileName, treeName)
    df_hits['relativePosition_binned'] = get_photosensor_hits_position_relative_binned(fileName, treeName, histDir)
    df_hits['relativePosition_nBin'  ] = get_photosensor_hits_position_relative_nBin  (fileName, treeName, histDir)
    df_hits['initialPosition'        ] = get_photosensor_hits_position_initial        (fileName, treeName)
    dfs_hits.append(df_hits)
    # print('df_hits length:', len(df_hits))
# Out:
#   0%|          | 0/141 [00:00<?, ?it/s]
# 100%|██████████| 141/141 [00:27<00:00,  5.22it/s]

# %%
treeName = 'primary;1'
dfs_primary = []
for fileName in tqdm.tqdm(fileNames):
    df_primary = pd.DataFrame(columns=['position', 'pdg'])
    df_primary['position' ] = get_primary_position(fileName, treeName)
    df_primary['pdg'      ] = get_primary_pdg     (fileName, treeName)
    df_primary = df_primary[df_primary['pdg'] == 13] # muon
    df_primary = df_primary[df_primary['position'].apply(lambda x:
        x[0] > -DETECTOR_SIZE_MM[0]/2 and x[0] < DETECTOR_SIZE_MM[0]/2 and
        x[1] > -DETECTOR_SIZE_MM[1]/2 and x[1] < DETECTOR_SIZE_MM[1]/2 and
        x[2] > -DETECTOR_SIZE_MM[2]/2 and x[2] < DETECTOR_SIZE_MM[2]/2
    )]
    dfs_primary.append(df_primary)
    # print('df_primary length:', len(df_primary))
# Out:
# 100%|██████████| 141/141 [00:01<00:00, 110.19it/s]

# %%
if len(dfs_primary) != len(dfs_hits):
    raise Exception('len(dfs_primary) != len(dfs_hits)')

# %% [markdown]
# # Filter Hits

# %%
search_radius = 0
search_number = 0

for i in tqdm.tqdm(range(len(dfs_hits))):
    dfs_hits[i] = filter_hits(dfs_hits[i], radius=search_radius, number=search_number)
# Out:
# 100%|██████████| 141/141 [00:03<00:00, 40.66it/s]

# %% [markdown]
# # Basic Hit Reco

# %%
def rToTheta(r):
    return r/(CM_PER_RAD*MM_PER_CM)
for i in tqdm.tqdm(range(len(dfs_hits))):
    dfs_hits[i] = make_r(dfs_hits[i])
    dfs_hits[i] = filter_r(dfs_hits[i], Y_LIM)
    dfs_hits[i] = make_theta(dfs_hits[i], rToTheta)
    dfs_hits[i] = make_phi(dfs_hits[i])
    dfs_hits[i] = make_reconstructedVector_direction(dfs_hits[i])
    dfs_hits[i] = make_relativeVector(dfs_hits[i])
# Out:
# 100%|██████████| 141/141 [00:04<00:00, 28.76it/s]

# %% [markdown]
# # Plotting Methods

# %%
color_oranges = cm.Blues_r  ([0.5,0.6,0.9])
color_blues   = cm.Oranges_r([0.5,0.6,0.9])
blue_1 = "#B6CEC7"
blue_2 = "#92C1A5"
blue_3 = "#889D8E"
red_1  = "#C16464"
red_2  = "#B64D4D"
red_3  = "#FBE6E5"
twilight = cm.twilight(np.linspace(0,1,40))

# %% [markdown]
# # Make or Load Grid

# %%
gridSize = (20, 20, 20)
makeErrors = False
save = False
savePlots = False
load = False
useWalls = False
plotRecoName = '{}x{}x{}_{}_{}'.format(gridSize[0], gridSize[1], gridSize[2], fileName.split('/')[-1].split('.')[0], {True:'withErrors', False:'noErrors'}[makeErrors])
print('plotRecoName:', plotRecoName)
# Out:
# plotRecoName: 20x20x20_multievent_198_noErrors

# %% [markdown]
# # Data

# %%
gridSize_input = gridSize
gridSize_output = np.array([20, 20, 20]) # 92, 92, 92

X_size = (len(dfs_hits),) + gridSize_input + (6,)
Y_size = (len(dfs_hits),) + (gridSize_output[0], gridSize_output[1], gridSize_output[2])

X = np.zeros((len(dfs_hits),) + gridSize_input + (6,))
Y = np.zeros((len(dfs_hits),) + (gridSize_output[0], gridSize_output[1], gridSize_output[2]))

for i, (df_hits, df_primary) in tqdm.tqdm(enumerate(zip(dfs_hits, dfs_primary))):
    X[i], grid_ind, grid_pos = make_voxelGrid(
        df_hits,
        shape=gridSize_input,
        detectorDimensions=DETECTOR_SIZE_MM,
        sensorPositions=np.array(df_hits['sensor_position'].to_list()).reshape(-1,3),
        recoDirections=np.array(df_hits['reconstructedVector_direction'].to_list()).reshape(-1,3),
        hitWeights=[1 for i in range(len(df_hits))],
        make_errors=makeErrors,
        useWalls=useWalls,
        sensorWalls=df_hits['sensor_wall'].to_numpy(),
        wallOperation=expNWalls,
        returnWalls=True)
    Y[i] = make_voxelGrid_truth(
        # np.array(df_hits['initialPosition'].to_list()),
        np.array(df_primary['position'].to_list()),
        shape=gridSize_output,
        detectorDimensions=DETECTOR_SIZE_MM,
        makeErrors=False)[0]*10

print('X.shape:', X.shape)
print('Y.shape:', Y.shape)
print()
print('grid_ind.shape:', grid_ind.shape)
print('grid_pos.shape:', grid_pos.shape)
# Out:
# 141it [00:06, 22.96it/s]
# X.shape: (141, 20, 20, 20, 6)
# Y.shape: (141, 20, 20, 20)
#
# grid_ind.shape: (8000, 3)
# grid_pos.shape: (8000, 3)

# %%
nTest = 20
testIndices = np.random.choice(len(dfs_hits), nTest, replace=False)

X_train = np.delete(X, testIndices, axis=0)
Y_train = np.delete(Y, testIndices, axis=0)
X_test = X[testIndices]
Y_test = Y[testIndices]

X_train_indices = np.delete(np.arange(len(dfs_hits)), testIndices)
Y_train_indices = np.delete(np.arange(len(dfs_hits)), testIndices)
X_test_indices = np.array(testIndices)
Y_test_indices = np.array(testIndices)

print('X_train.shape:', X_train.shape)
print('Y_train.shape:', Y_train.shape)
print('X_test.shape:', X_test.shape)
print('Y_test.shape:', Y_test.shape)
# Out:
# X_train.shape: (121, 20, 20, 20, 6)
# Y_train.shape: (121, 20, 20, 20)
# X_test.shape: (20, 20, 20, 20, 6)
# Y_test.shape: (20, 20, 20, 20)

# %%
# %matplotlib qt
# %matplotlib inline

from scipy.ndimage import zoom

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')

ind = 50

nonZeroInd = np.where(np.sum(X[ind], axis=-1).flatten() > 0)
ax.scatter(grid_pos[nonZeroInd, 0], grid_pos[nonZeroInd, 1], grid_pos[nonZeroInd, 2], c='r', cmap=cm.viridis, s=100, alpha=1)

nonZeroInd = np.where(Y[ind].flatten() > 0)
ax.scatter(grid_pos[nonZeroInd, 0], grid_pos[nonZeroInd, 1], grid_pos[nonZeroInd, 2], c='b', cmap=cm.viridis, s=100, alpha=1)

initialPos = np.array(dfs_hits[ind]['initialPosition'].to_list())
ax.scatter(initialPos[:, 0], initialPos[:, 1], initialPos[:, 2], c='g', cmap=cm.viridis, s=100, alpha=1)

plt.show()
# Out:
# /var/folders/mv/_50rblmd16xfrbsjpr4x2z0c0000gn/T/ipykernel_94593/2075693218.py:12: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(grid_pos[nonZeroInd, 0], grid_pos[nonZeroInd, 1], grid_pos[nonZeroInd, 2], c='r', cmap=cm.viridis, s=100, alpha=1)
# /var/folders/mv/_50rblmd16xfrbsjpr4x2z0c0000gn/T/ipykernel_94593/2075693218.py:15: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(grid_pos[nonZeroInd, 0], grid_pos[nonZeroInd, 1], grid_pos[nonZeroInd, 2], c='b', cmap=cm.viridis, s=100, alpha=1)
# /var/folders/mv/_50rblmd16xfrbsjpr4x2z0c0000gn/T/ipykernel_94593/2075693218.py:18: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(initialPos[:, 0], initialPos[:, 1], initialPos[:, 2], c='g', cmap=cm.viridis, s=100, alpha=1)

# %% [markdown]
# # Model

# %%
input_data = tf.keras.layers.Input(shape=X_size[1:])
summed_data = tf.keras.layers.Lambda(lambda x: tf.reduce_sum(x, axis=-1))(input_data)

dropoutRate = 0.2

conv_1_1 = tf.keras.layers.Conv3D(32, (3, 3, 3), activation='relu', padding='valid')(input_data)
conv_1_1_drop = tf.keras.layers.Dropout(dropoutRate)(conv_1_1)
maxPool_1_1 = tf.keras.layers.MaxPooling3D((2, 2, 2))(conv_1_1_drop)
conv_1_2 = tf.keras.layers.Conv3D(64, (3, 3, 3), activation='relu', padding='valid')(maxPool_1_1)
conv_1_2_drop = tf.keras.layers.Dropout(dropoutRate)(conv_1_2)
maxPool_1_2 = tf.keras.layers.MaxPooling3D((2, 2, 2))(conv_1_2_drop)

mlp_conv = tf.keras.layers.Flatten()(maxPool_1_2)
mlp_1 = tf.keras.layers.Dense(256, activation='relu')(mlp_conv)
mpl_1_drop = tf.keras.layers.Dropout(dropoutRate)(mlp_1)
mlp_2 = tf.keras.layers.Dense(16**3, activation='relu')(mpl_1_drop)
mlp_2_drop = tf.keras.layers.Dropout(dropoutRate)(mlp_2)
mlp_res = tf.keras.layers.Reshape((16, 16, 16, 1))(mlp_2_drop)

deconv_1_1 = tf.keras.layers.Conv3DTranspose(64, (3, 3, 3), activation='relu', padding='valid')(mlp_res)
deconv_1_1_drop = tf.keras.layers.Dropout(dropoutRate)(deconv_1_1)
deconv_1_2 = tf.keras.layers.Conv3DTranspose(32, (3, 3, 3), activation='relu', padding='valid')(deconv_1_1_drop)
deconv_1_2_drop = tf.keras.layers.Dropout(dropoutRate)(deconv_1_2)

output = tf.keras.layers.Conv3D(1, (3, 3, 3), activation='relu', padding='same')(deconv_1_2_drop)

model = tf.keras.Model(inputs=input_data, outputs=output)

# %%
def sparseLoss(true, pred): 
    # only compute loss on values greater than epsilon
    epsilon = 1 # 1e-7
    mask = tf.greater(true, epsilon)
    mask = tf.dtypes.cast(mask, tf.float32)

    loss_inMask = tf.square(tf.subtract(true, pred))
    loss_inMask = tf.multiply(loss_inMask, mask)
    loss_inMask /= tf.reduce_sum(mask)

    loss_outMask = tf.square(tf.subtract(true, pred))
    loss_outMask = tf.multiply(loss_outMask, 1-mask)
    loss_outMask /= tf.reduce_sum(1-mask)

    # return tf.reduce_mean(loss)
    return tf.reduce_sum(loss_inMask) + tf.reduce_sum(loss_outMask)

def distancesFromRecoToTrue(true, pred, eps=8, optimize=False, minEntries=20, deltaEps=0.1):
    if type(true) == np.ndarray:
        true = tf.convert_to_tensor(true, dtype=tf.float32)
    if type(pred) == np.ndarray:
        pred = tf.convert_to_tensor(pred, dtype=tf.float32)

    if optimize:
        while tf.where(tf.greater(pred, eps)).numpy().size < minEntries and eps > 0:
            # print(tf.where(tf.greater(pred, eps)).numpy().size)
            eps -= deltaEps

    mask = tf.cast(tf.greater(pred, eps), tf.float32)
    pred = pred * mask

    true = tf.reshape(true, (-1, 1))
    pred = tf.reshape(pred, (-1, 1))

    pred_ind = tf.where(tf.greater(pred, 0))
    true_ind = tf.where(tf.greater(true, 0))

    pred_ind = pred_ind[:, 0]
    true_ind = true_ind[:, 0]

    posTensor = tf.convert_to_tensor(grid_pos, dtype=tf.float32)

    pred_pos = tf.gather(posTensor, pred_ind)
    true_pos = tf.gather(posTensor, true_ind)

    pred_pos = tf.reshape(pred_pos, (-1, 3))
    true_pos = tf.reshape(true_pos, (-1, 3))

    pred_pos = tf.expand_dims(pred_pos, 1)
    true_pos = tf.expand_dims(true_pos, 0)

    distances = tf.norm(pred_pos - true_pos, axis=-1)
    minDistances = tf.reduce_min(distances, axis=1)

    return minDistances

def distancesFromTrueToReco(true, pred, eps=8, optimize=False, minEntries=20, deltaEps=0.1):
    return distancesFromRecoToTrue(pred, true, eps=eps, optimize=optimize, minEntries=minEntries, deltaEps=deltaEps)

def meanDistanceFromRecoToTrue(true, pred, eps=8, optimize=False, minEntries=20, deltaEps=0.1):
    return tf.reduce_mean(distancesFromRecoToTrue(true, pred, eps=eps, optimize=optimize, minEntries=minEntries, deltaEps=deltaEps))

def meanDistanceFromTrueToReco(true, pred, eps=8, optimize=False, minEntries=20, deltaEps=0.1):
    return tf.reduce_mean(distancesFromTrueToReco(true, pred, eps=eps, optimize=optimize, minEntries=minEntries, deltaEps=deltaEps))

def meanAndDistancesFromRecoToTrue(true, pred, eps=8, optimize=False, minEntries=20, deltaEps=0.1):
    distances = distancesFromRecoToTrue(true, pred, eps=eps, optimize=optimize, minEntries=minEntries, deltaEps=deltaEps)
    return tf.reduce_mean(distances), distances

def meanAndDistancesFromTrueToReco(true, pred, eps=8, optimize=False, minEntries=20, deltaEps=0.1):
    distances = distancesFromTrueToReco(true, pred, eps=eps, optimize=optimize, minEntries=minEntries, deltaEps=deltaEps)
    return tf.reduce_mean(distances), distances

# %%
custom_learning_rate = 0.0001  # Change this to your desired learning rate (default = 0.001)
optimizer = tf.keras.optimizers.Adam(learning_rate=custom_learning_rate)
# optimizer = tf.keras.optimizers.Adam()
model.compile(optimizer, loss=sparseLoss, 
              metrics=['accuracy', 'mean_squared_error', 
                       meanDistanceFromRecoToTrue, distancesFromTrueToReco])
model.summary()
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 20, 20, 20, 6)]   0
#
#  conv3d (Conv3D)             (None, 18, 18, 18, 32)    5216
#
#  dropout (Dropout)           (None, 18, 18, 18, 32)    0
#
#  max_pooling3d (MaxPooling3D  (None, 9, 9, 9, 32)      0
#  )
#
#  conv3d_1 (Conv3D)           (None, 7, 7, 7, 64)       55360
#
#  dropout_1 (Dropout)         (None, 7, 7, 7, 64)       0
#
#  max_pooling3d_1 (MaxPooling  (None, 3, 3, 3, 64)      0
#  3D)
#
#  flatten (Flatten)           (None, 1728)              0
#
#  dense (Dense)               (None, 256)               442624
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 4096)              1052672
#
#  dropout_3 (Dropout)         (None, 4096)              0
#
#  reshape (Reshape)           (None, 16, 16, 16, 1)     0
#
#  conv3d_transpose (Conv3DTra  (None, 18, 18, 18, 64)   1792
#  nspose)
#
#  dropout_4 (Dropout)         (None, 18, 18, 18, 64)    0
#
#  conv3d_transpose_1 (Conv3DT  (None, 20, 20, 20, 32)   55328
#  ranspose)
#
#  dropout_5 (Dropout)         (None, 20, 20, 20, 32)    0
#
#  conv3d_2 (Conv3D)           (None, 20, 20, 20, 1)     865
#
# =================================================================
# Total params: 1,613,857
# Trainable params: 1,613,857
# Non-trainable params: 0
# _________________________________________________________________

# %%
useEarlyStopping = False
k = 5
nEpochs = 30
batchSize = 1
patience = 20

kFold = KFold(n_splits=k, shuffle=True)

histories = []
for i, (train_index, val_index) in tqdm.tqdm(enumerate(kFold.split(X_train))):
    X_train_k, X_val_k = X_train[train_index], X_train[val_index]
    Y_train_k, Y_val_k = Y_train[train_index], Y_train[val_index]

    if useEarlyStopping:
        early_stopping_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience, restore_best_weights=True)
        histories.append(model.fit(X_train_k, Y_train_k, epochs=nEpochs, batch_size=batchSize, validation_data=(X_val_k, Y_val_k), callbacks=[early_stopping_callback]))
    else:
        histories.append(model.fit(X_train_k, Y_train_k, epochs=nEpochs, batch_size=batchSize, validation_data=(X_val_k, Y_val_k)))
# Out:
# 0it [00:00, ?it/s]
# Epoch 1/30
# 96/96 [==============================] - 4s 29ms/step - loss: 82.8969 - accuracy: 0.7202 - mean_squared_error: 5.0531 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 5.7066 - val_loss: 77.9639 - val_accuracy: 0.6559 - val_mean_squared_error: 2.9374 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 2/30
# 96/96 [==============================] - 3s 27ms/step - loss: 74.1756 - accuracy: 0.6747 - mean_squared_error: 5.7244 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 78.2794 - val_accuracy: 0.6934 - val_mean_squared_error: 1.5082 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 3/30
# 96/96 [==============================] - 3s 26ms/step - loss: 68.7518 - accuracy: 0.5189 - mean_squared_error: 4.9935 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 73.2743 - val_accuracy: 0.3421 - val_mean_squared_error: 2.0076 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 4/30
# 96/96 [==============================] - 3s 26ms/step - loss: 63.6296 - accuracy: 0.2301 - mean_squared_error: 4.3918 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 64.2864 - val_accuracy: 0.1281 - val_mean_squared_error: 3.8353 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 5/30
# 96/96 [==============================] - 3s 26ms/step - loss: 57.8193 - accuracy: 0.0627 - mean_squared_error: 5.9052 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 57.0179 - val_accuracy: 0.0283 - val_mean_squared_error: 5.6170 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 6/30
# 96/96 [==============================] - 3s 26ms/step - loss: 50.2003 - accuracy: 0.0193 - mean_squared_error: 8.7750 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 52.0408 - val_accuracy: 0.0084 - val_mean_squared_error: 8.5175 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 7/30
# 96/96 [==============================] - 3s 28ms/step - loss: 46.3198 - accuracy: 0.0052 - mean_squared_error: 12.5884 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 46.7708 - val_accuracy: 0.0016 - val_mean_squared_error: 14.9658 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 8/30
# 96/96 [==============================] - 3s 36ms/step - loss: 45.3741 - accuracy: 0.0020 - mean_squared_error: 15.9358 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 46.9269 - val_accuracy: 0.0014 - val_mean_squared_error: 15.7048 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 9/30
# 96/96 [==============================] - 3s 31ms/step - loss: 44.3628 - accuracy: 0.0018 - mean_squared_error: 15.9569 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 46.9479 - val_accuracy: 0.0012 - val_mean_squared_error: 15.5678 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 10/30
# 96/96 [==============================] - 3s 28ms/step - loss: 44.2074 - accuracy: 0.0016 - mean_squared_error: 16.7239 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 45.8783 - val_accuracy: 0.0011 - val_mean_squared_error: 16.0249 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 11/30
# 96/96 [==============================] - 3s 30ms/step - loss: 43.6757 - accuracy: 0.0016 - mean_squared_error: 15.9483 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 46.5768 - val_accuracy: 0.0011 - val_mean_squared_error: 16.0807 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 12/30
# 96/96 [==============================] - 3s 29ms/step - loss: 43.8161 - accuracy: 0.0015 - mean_squared_error: 16.3430 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 47.0045 - val_accuracy: 0.0011 - val_mean_squared_error: 14.9302 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 13/30
# 96/96 [==============================] - 3s 29ms/step - loss: 43.8054 - accuracy: 0.0015 - mean_squared_error: 15.6627 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 46.5169 - val_accuracy: 0.0011 - val_mean_squared_error: 15.9966 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 14/30
# 96/96 [==============================] - 3s 28ms/step - loss: 43.0739 - accuracy: 0.0015 - mean_squared_error: 16.1876 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 47.0172 - val_accuracy: 0.0011 - val_mean_squared_error: 15.4527 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 15/30
# 96/96 [==============================] - 3s 28ms/step - loss: 42.6082 - accuracy: 0.0014 - mean_squared_error: 15.8302 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 47.0305 - val_accuracy: 0.0011 - val_mean_squared_error: 15.0915 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 16/30
# 96/96 [==============================] - 3s 28ms/step - loss: 42.0857 - accuracy: 0.0012 - mean_squared_error: 16.3053 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 46.8177 - val_accuracy: 0.0012 - val_mean_squared_error: 14.9099 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 17/30
# 96/96 [==============================] - 3s 27ms/step - loss: 40.6444 - accuracy: 0.0012 - mean_squared_error: 15.3081 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 47.2151 - val_accuracy: 9.2500e-04 - val_mean_squared_error: 13.7667 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 18/30
# 96/96 [==============================] - 3s 28ms/step - loss: 37.9535 - accuracy: 0.0014 - mean_squared_error: 14.5174 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 47.2408 - val_accuracy: 0.0029 - val_mean_squared_error: 13.6172 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 19/30
# 96/96 [==============================] - 3s 28ms/step - loss: 33.3863 - accuracy: 0.0037 - mean_squared_error: 13.2609 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 45.7966 - val_accuracy: 0.0112 - val_mean_squared_error: 11.2932 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 20/30
# 96/96 [==============================] - 3s 26ms/step - loss: 28.1979 - accuracy: 0.0103 - mean_squared_error: 11.1362 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 43.5868 - val_accuracy: 0.0232 - val_mean_squared_error: 14.4083 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 21/30
# 96/96 [==============================] - 3s 27ms/step - loss: 21.3699 - accuracy: 0.0255 - mean_squared_error: 9.2919 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 39.2079 - val_accuracy: 0.0349 - val_mean_squared_error: 12.0565 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 22/30
# 96/96 [==============================] - 3s 27ms/step - loss: 18.1712 - accuracy: 0.0451 - mean_squared_error: 7.4200 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 45.3497 - val_accuracy: 0.0774 - val_mean_squared_error: 15.5929 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 1.8473
# Epoch 23/30
# 96/96 [==============================] - 2s 26ms/step - loss: 16.9758 - accuracy: 0.0668 - mean_squared_error: 6.8333 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 42.3318 - val_accuracy: 0.1184 - val_mean_squared_error: 9.5331 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 2.7710
# Epoch 24/30
# 96/96 [==============================] - 3s 26ms/step - loss: 14.8686 - accuracy: 0.1217 - mean_squared_error: 5.6843 - meanDistanceFromRecoToTrue: 223.7249 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 40.7884 - val_accuracy: 0.1073 - val_mean_squared_error: 9.5282 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 1.8473
# Epoch 25/30
# 96/96 [==============================] - 3s 27ms/step - loss: 14.2423 - accuracy: 0.1197 - mean_squared_error: 5.3119 - meanDistanceFromRecoToTrue: 214.7517 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 40.8942 - val_accuracy: 0.0986 - val_mean_squared_error: 9.7019 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 26/30
# 96/96 [==============================] - 3s 27ms/step - loss: 13.1810 - accuracy: 0.1805 - mean_squared_error: 4.7929 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 40.8920 - val_accuracy: 0.1624 - val_mean_squared_error: 8.8905 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 3.3868
# Epoch 27/30
# 96/96 [==============================] - 3s 32ms/step - loss: 14.2245 - accuracy: 0.1802 - mean_squared_error: 4.5957 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.2562 - val_loss: 46.3858 - val_accuracy: 0.2138 - val_mean_squared_error: 9.3909 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 4.3104
# Epoch 28/30
# 96/96 [==============================] - 3s 27ms/step - loss: 13.0520 - accuracy: 0.2142 - mean_squared_error: 4.4125 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 45.0256 - val_accuracy: 0.2014 - val_mean_squared_error: 9.9523 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 4.3104
# Epoch 29/30
# 96/96 [==============================] - 3s 27ms/step - loss: 11.8480 - accuracy: 0.2547 - mean_squared_error: 4.2025 - meanDistanceFromRecoToTrue: 178.3812 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 42.7636 - val_accuracy: 0.2556 - val_mean_squared_error: 9.3500 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 4.9262
# Epoch 30/30
# 96/96 [==============================] - 3s 27ms/step - loss: 11.3146 - accuracy: 0.3413 - mean_squared_error: 3.8774 - meanDistanceFromRecoToTrue: 181.5027 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 47.6784 - val_accuracy: 0.4498 - val_mean_squared_error: 4.9680 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 20.5292
# 1it [01:22, 82.40s/it]
# Epoch 1/30
# 97/97 [==============================] - 3s 27ms/step - loss: 18.8505 - accuracy: 0.2883 - mean_squared_error: 5.3730 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 2.0805 - val_loss: 22.6565 - val_accuracy: 0.3797 - val_mean_squared_error: 3.5146 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 2/30
# 97/97 [==============================] - 3s 27ms/step - loss: 15.2529 - accuracy: 0.2808 - mean_squared_error: 4.6861 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.5907 - val_loss: 15.7564 - val_accuracy: 0.3149 - val_mean_squared_error: 3.4366 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 3/30
# 97/97 [==============================] - 3s 27ms/step - loss: 13.6708 - accuracy: 0.3047 - mean_squared_error: 4.5124 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 22.2834 - val_accuracy: 0.4662 - val_mean_squared_error: 2.3474 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 4/30
# 97/97 [==============================] - 3s 27ms/step - loss: 14.8551 - accuracy: 0.3358 - mean_squared_error: 4.1628 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 23.7577 - val_accuracy: 0.3600 - val_mean_squared_error: 4.0393 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 5/30
# 97/97 [==============================] - 3s 28ms/step - loss: 13.7717 - accuracy: 0.3666 - mean_squared_error: 3.9755 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 18.8251 - val_accuracy: 0.3338 - val_mean_squared_error: 3.6561 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 6/30
# 97/97 [==============================] - 3s 26ms/step - loss: 11.2901 - accuracy: 0.3664 - mean_squared_error: 4.0528 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 20.0714 - val_accuracy: 0.4710 - val_mean_squared_error: 2.4295 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 7/30
# 97/97 [==============================] - 3s 28ms/step - loss: 10.3953 - accuracy: 0.4214 - mean_squared_error: 3.4992 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 17.6118 - val_accuracy: 0.4395 - val_mean_squared_error: 2.7068 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 8/30
# 97/97 [==============================] - 3s 27ms/step - loss: 10.5662 - accuracy: 0.4561 - mean_squared_error: 3.4747 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 21.3964 - val_accuracy: 0.5670 - val_mean_squared_error: 2.1576 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 9/30
# 97/97 [==============================] - 3s 26ms/step - loss: 9.9607 - accuracy: 0.4690 - mean_squared_error: 3.4721 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 22.8282 - val_accuracy: 0.5902 - val_mean_squared_error: 2.0758 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 10/30
# 97/97 [==============================] - 3s 27ms/step - loss: 9.4618 - accuracy: 0.5172 - mean_squared_error: 3.0961 - meanDistanceFromRecoToTrue: 168.1869 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 23.3810 - val_accuracy: 0.5907 - val_mean_squared_error: 2.3776 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 11/30
# 97/97 [==============================] - 3s 28ms/step - loss: 8.9191 - accuracy: 0.5267 - mean_squared_error: 3.0179 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 23.1033 - val_accuracy: 0.6121 - val_mean_squared_error: 2.0926 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 12/30
# 97/97 [==============================] - 3s 27ms/step - loss: 8.4658 - accuracy: 0.5581 - mean_squared_error: 2.8100 - meanDistanceFromRecoToTrue: 157.8334 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 22.5576 - val_accuracy: 0.6011 - val_mean_squared_error: 2.1903 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 13/30
# 97/97 [==============================] - 3s 27ms/step - loss: 8.0497 - accuracy: 0.5571 - mean_squared_error: 2.8681 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 25.9723 - val_accuracy: 0.6941 - val_mean_squared_error: 1.8184 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.3218
# Epoch 14/30
# 97/97 [==============================] - 3s 28ms/step - loss: 8.7689 - accuracy: 0.5712 - mean_squared_error: 2.6254 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 24.0428 - val_accuracy: 0.6413 - val_mean_squared_error: 2.0867 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 15/30
# 97/97 [==============================] - 3s 26ms/step - loss: 8.4732 - accuracy: 0.5940 - mean_squared_error: 2.6635 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 21.7587 - val_accuracy: 0.6589 - val_mean_squared_error: 1.8667 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 16/30
# 97/97 [==============================] - 3s 28ms/step - loss: 8.4323 - accuracy: 0.6168 - mean_squared_error: 2.4555 - meanDistanceFromRecoToTrue: 149.2531 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 20.4101 - val_accuracy: 0.6040 - val_mean_squared_error: 2.3765 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 17/30
# 97/97 [==============================] - 3s 27ms/step - loss: 8.5151 - accuracy: 0.6138 - mean_squared_error: 2.5725 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 21.7109 - val_accuracy: 0.6647 - val_mean_squared_error: 1.8534 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 18/30
# 97/97 [==============================] - 3s 26ms/step - loss: 7.5590 - accuracy: 0.6169 - mean_squared_error: 2.5439 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 27.6015 - val_accuracy: 0.7195 - val_mean_squared_error: 1.7998 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.6436
# Epoch 19/30
# 97/97 [==============================] - 3s 27ms/step - loss: 8.0585 - accuracy: 0.6467 - mean_squared_error: 2.2813 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 30.7091 - val_accuracy: 0.7573 - val_mean_squared_error: 1.4788 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 2.1974
# Epoch 20/30
# 97/97 [==============================] - 3s 27ms/step - loss: 8.6404 - accuracy: 0.6457 - mean_squared_error: 2.3796 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0844 - val_loss: 24.1016 - val_accuracy: 0.7366 - val_mean_squared_error: 1.5469 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.9654
# Epoch 21/30
# 97/97 [==============================] - 3s 27ms/step - loss: 7.7184 - accuracy: 0.6757 - mean_squared_error: 2.2301 - meanDistanceFromRecoToTrue: 139.6875 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 24.1452 - val_accuracy: 0.6908 - val_mean_squared_error: 2.2255 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 22/30
# 97/97 [==============================] - 3s 28ms/step - loss: 7.1745 - accuracy: 0.6594 - mean_squared_error: 2.3558 - meanDistanceFromRecoToTrue: 140.8734 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 26.0191 - val_accuracy: 0.7415 - val_mean_squared_error: 1.5657 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.9654
# Epoch 23/30
# 97/97 [==============================] - 3s 27ms/step - loss: 6.8481 - accuracy: 0.6764 - mean_squared_error: 2.1942 - meanDistanceFromRecoToTrue: 136.2955 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 28.8920 - val_accuracy: 0.7625 - val_mean_squared_error: 1.6456 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 3.1629
# Epoch 24/30
# 97/97 [==============================] - 3s 31ms/step - loss: 7.1395 - accuracy: 0.6927 - mean_squared_error: 2.1026 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0844 - val_loss: 28.2979 - val_accuracy: 0.7686 - val_mean_squared_error: 1.5826 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 2.9744
# Epoch 25/30
# 97/97 [==============================] - 3s 30ms/step - loss: 7.0017 - accuracy: 0.6984 - mean_squared_error: 2.1120 - meanDistanceFromRecoToTrue: 135.1819 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 27.7387 - val_accuracy: 0.7349 - val_mean_squared_error: 1.9916 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 2.0641
# Epoch 26/30
# 97/97 [==============================] - 3s 27ms/step - loss: 6.7584 - accuracy: 0.7119 - mean_squared_error: 2.0589 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 32.5116 - val_accuracy: 0.7833 - val_mean_squared_error: 1.5008 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 6.0510
# Epoch 27/30
# 97/97 [==============================] - 3s 28ms/step - loss: 6.8852 - accuracy: 0.7213 - mean_squared_error: 2.0199 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 28.2924 - val_accuracy: 0.7805 - val_mean_squared_error: 1.5115 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 4.2616
# Epoch 28/30
# 97/97 [==============================] - 3s 26ms/step - loss: 6.8032 - accuracy: 0.7082 - mean_squared_error: 2.0468 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 24.6404 - val_accuracy: 0.7646 - val_mean_squared_error: 1.5067 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 2.7078
# Epoch 29/30
# 97/97 [==============================] - 3s 26ms/step - loss: 6.3713 - accuracy: 0.7036 - mean_squared_error: 2.1251 - meanDistanceFromRecoToTrue: 137.2835 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 22.7097 - val_accuracy: 0.7713 - val_mean_squared_error: 1.4850 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 3.0296
# Epoch 30/30
# 97/97 [==============================] - 3s 26ms/step - loss: 6.4276 - accuracy: 0.7334 - mean_squared_error: 1.9528 - meanDistanceFromRecoToTrue: 130.2256 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 29.6588 - val_accuracy: 0.7749 - val_mean_squared_error: 1.5097 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 4.1283
# 2it [02:41, 80.61s/it]
# Epoch 1/30
# 97/97 [==============================] - 3s 28ms/step - loss: 9.7056 - accuracy: 0.6497 - mean_squared_error: 2.4659 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.4150 - val_loss: 10.6266 - val_accuracy: 0.7097 - val_mean_squared_error: 2.0421 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 2/30
# 97/97 [==============================] - 3s 29ms/step - loss: 7.9144 - accuracy: 0.6560 - mean_squared_error: 2.3971 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 8.5366 - val_accuracy: 0.7576 - val_mean_squared_error: 1.8965 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 3/30
# 97/97 [==============================] - 3s 28ms/step - loss: 7.2516 - accuracy: 0.6947 - mean_squared_error: 2.2538 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 11.4065 - val_accuracy: 0.7676 - val_mean_squared_error: 1.8950 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 4/30
# 97/97 [==============================] - 3s 28ms/step - loss: 7.0195 - accuracy: 0.7047 - mean_squared_error: 2.1906 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.2490 - val_loss: 13.9189 - val_accuracy: 0.7841 - val_mean_squared_error: 1.8233 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 5/30
# 97/97 [==============================] - 3s 29ms/step - loss: 6.5907 - accuracy: 0.7170 - mean_squared_error: 2.1009 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0830 - val_loss: 9.8583 - val_accuracy: 0.7897 - val_mean_squared_error: 1.7408 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 6/30
# 97/97 [==============================] - 3s 27ms/step - loss: 5.6100 - accuracy: 0.7439 - mean_squared_error: 1.9994 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 12.6213 - val_accuracy: 0.7992 - val_mean_squared_error: 1.9581 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 7/30
# 97/97 [==============================] - 3s 27ms/step - loss: 7.0431 - accuracy: 0.7481 - mean_squared_error: 2.0172 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 11.5588 - val_accuracy: 0.8055 - val_mean_squared_error: 1.7343 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 8/30
# 97/97 [==============================] - 3s 27ms/step - loss: 7.2647 - accuracy: 0.7501 - mean_squared_error: 2.0257 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 12.1511 - val_accuracy: 0.7543 - val_mean_squared_error: 2.2879 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 9/30
# 97/97 [==============================] - 3s 28ms/step - loss: 6.3359 - accuracy: 0.7635 - mean_squared_error: 2.0142 - meanDistanceFromRecoToTrue: 127.5088 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 12.3785 - val_accuracy: 0.8218 - val_mean_squared_error: 1.6670 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 10/30
# 97/97 [==============================] - 3s 28ms/step - loss: 6.5176 - accuracy: 0.7364 - mean_squared_error: 1.9728 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.1660 - val_loss: 10.5226 - val_accuracy: 0.8145 - val_mean_squared_error: 1.6879 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 11/30
# 97/97 [==============================] - 3s 27ms/step - loss: 5.8986 - accuracy: 0.7656 - mean_squared_error: 1.9243 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 13.0139 - val_accuracy: 0.8351 - val_mean_squared_error: 1.5380 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 12/30
# 97/97 [==============================] - 3s 27ms/step - loss: 6.1022 - accuracy: 0.7762 - mean_squared_error: 1.7997 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 12.3880 - val_accuracy: 0.8063 - val_mean_squared_error: 1.7854 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 13/30
# 97/97 [==============================] - 3s 27ms/step - loss: 6.4782 - accuracy: 0.7453 - mean_squared_error: 1.9601 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 10.6273 - val_accuracy: 0.8135 - val_mean_squared_error: 1.7256 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 14/30
# 97/97 [==============================] - 3s 29ms/step - loss: 6.0645 - accuracy: 0.7749 - mean_squared_error: 1.8851 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 13.7794 - val_accuracy: 0.8260 - val_mean_squared_error: 1.6943 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 15/30
# 97/97 [==============================] - 3s 32ms/step - loss: 5.3855 - accuracy: 0.7932 - mean_squared_error: 1.7157 - meanDistanceFromRecoToTrue: 121.5902 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 12.7510 - val_accuracy: 0.8383 - val_mean_squared_error: 1.6997 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 16/30
# 97/97 [==============================] - 3s 28ms/step - loss: 5.2060 - accuracy: 0.7938 - mean_squared_error: 1.7778 - meanDistanceFromRecoToTrue: 121.8726 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 10.7719 - val_accuracy: 0.8252 - val_mean_squared_error: 1.7969 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 17/30
# 97/97 [==============================] - 3s 29ms/step - loss: 5.4997 - accuracy: 0.8044 - mean_squared_error: 1.7423 - meanDistanceFromRecoToTrue: 123.7137 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 10.6195 - val_accuracy: 0.8574 - val_mean_squared_error: 1.4392 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 18/30
# 97/97 [==============================] - 3s 28ms/step - loss: 5.6847 - accuracy: 0.8145 - mean_squared_error: 1.6413 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 13.4043 - val_accuracy: 0.8452 - val_mean_squared_error: 1.6627 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 19/30
# 97/97 [==============================] - 3s 29ms/step - loss: 5.1747 - accuracy: 0.8222 - mean_squared_error: 1.5870 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 11.6125 - val_accuracy: 0.8544 - val_mean_squared_error: 1.5482 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 20/30
# 97/97 [==============================] - 3s 29ms/step - loss: 5.3932 - accuracy: 0.8212 - mean_squared_error: 1.6605 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 10.5109 - val_accuracy: 0.8523 - val_mean_squared_error: 1.5923 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 21/30
# 97/97 [==============================] - 3s 28ms/step - loss: 5.1011 - accuracy: 0.8166 - mean_squared_error: 1.7019 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 12.3846 - val_accuracy: 0.8764 - val_mean_squared_error: 1.3248 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 22/30
# 97/97 [==============================] - 3s 29ms/step - loss: 5.1737 - accuracy: 0.8291 - mean_squared_error: 1.5690 - meanDistanceFromRecoToTrue: 114.4628 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 10.1187 - val_accuracy: 0.8470 - val_mean_squared_error: 1.5938 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 23/30
# 97/97 [==============================] - 3s 30ms/step - loss: 5.0415 - accuracy: 0.8176 - mean_squared_error: 1.6879 - meanDistanceFromRecoToTrue: 120.9519 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 10.4519 - val_accuracy: 0.8561 - val_mean_squared_error: 1.5639 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 24/30
# 97/97 [==============================] - 3s 27ms/step - loss: 4.9185 - accuracy: 0.8301 - mean_squared_error: 1.6165 - meanDistanceFromRecoToTrue: 120.0253 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 14.6552 - val_accuracy: 0.8496 - val_mean_squared_error: 1.7755 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 25/30
# 97/97 [==============================] - 3s 27ms/step - loss: 4.8560 - accuracy: 0.8344 - mean_squared_error: 1.5569 - meanDistanceFromRecoToTrue: 115.6586 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 12.2930 - val_accuracy: 0.8513 - val_mean_squared_error: 1.7567 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 26/30
# 97/97 [==============================] - 3s 32ms/step - loss: 4.5841 - accuracy: 0.8396 - mean_squared_error: 1.5713 - meanDistanceFromRecoToTrue: 117.2260 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 9.8904 - val_accuracy: 0.8565 - val_mean_squared_error: 1.7046 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 27/30
# 97/97 [==============================] - 3s 33ms/step - loss: 5.4227 - accuracy: 0.8287 - mean_squared_error: 1.6384 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 10.5715 - val_accuracy: 0.8709 - val_mean_squared_error: 1.4147 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 28/30
# 97/97 [==============================] - 3s 28ms/step - loss: 4.5337 - accuracy: 0.8436 - mean_squared_error: 1.5313 - meanDistanceFromRecoToTrue: 113.8207 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 13.6321 - val_accuracy: 0.8611 - val_mean_squared_error: 1.6943 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 29/30
# 97/97 [==============================] - 3s 31ms/step - loss: 5.0935 - accuracy: 0.8495 - mean_squared_error: 1.5444 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 12.4164 - val_accuracy: 0.8566 - val_mean_squared_error: 1.7443 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 30/30
# 97/97 [==============================] - 3s 30ms/step - loss: 4.9231 - accuracy: 0.8403 - mean_squared_error: 1.6013 - meanDistanceFromRecoToTrue: 113.2538 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 11.4739 - val_accuracy: 0.8650 - val_mean_squared_error: 1.5733 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# 3it [04:04, 81.81s/it]
# Epoch 1/30
# 97/97 [==============================] - 3s 30ms/step - loss: 4.3795 - accuracy: 0.8525 - mean_squared_error: 1.5400 - meanDistanceFromRecoToTrue: 115.6777 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 9.8588 - val_accuracy: 0.8447 - val_mean_squared_error: 1.7687 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 2/30
# 97/97 [==============================] - 3s 28ms/step - loss: 5.7113 - accuracy: 0.8334 - mean_squared_error: 1.6341 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 8.4720 - val_accuracy: 0.8453 - val_mean_squared_error: 1.7279 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 3/30
# 97/97 [==============================] - 3s 28ms/step - loss: 5.1467 - accuracy: 0.8469 - mean_squared_error: 1.5306 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 9.8595 - val_accuracy: 0.8293 - val_mean_squared_error: 2.0389 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 4/30
# 97/97 [==============================] - 3s 28ms/step - loss: 5.2038 - accuracy: 0.8460 - mean_squared_error: 1.5943 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 11.6778 - val_accuracy: 0.8313 - val_mean_squared_error: 2.0067 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 5/30
# 97/97 [==============================] - 3s 30ms/step - loss: 4.5810 - accuracy: 0.8552 - mean_squared_error: 1.4880 - meanDistanceFromRecoToTrue: 111.0294 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 7.3953 - val_accuracy: 0.8421 - val_mean_squared_error: 1.8313 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 6/30
# 97/97 [==============================] - 3s 31ms/step - loss: 5.0869 - accuracy: 0.8595 - mean_squared_error: 1.5131 - meanDistanceFromRecoToTrue: 114.3038 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 11.0694 - val_accuracy: 0.8334 - val_mean_squared_error: 2.0449 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 7/30
# 97/97 [==============================] - 3s 35ms/step - loss: 4.4553 - accuracy: 0.8646 - mean_squared_error: 1.4494 - meanDistanceFromRecoToTrue: 114.6458 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 10.5428 - val_accuracy: 0.8304 - val_mean_squared_error: 2.0871 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 8/30
# 97/97 [==============================] - 3s 30ms/step - loss: 3.7734 - accuracy: 0.8681 - mean_squared_error: 1.4683 - meanDistanceFromRecoToTrue: 112.9033 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 9.5921 - val_accuracy: 0.8624 - val_mean_squared_error: 1.7316 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 9/30
# 97/97 [==============================] - 3s 28ms/step - loss: 4.0688 - accuracy: 0.8713 - mean_squared_error: 1.4749 - meanDistanceFromRecoToTrue: 117.1666 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 7.2389 - val_accuracy: 0.8616 - val_mean_squared_error: 1.6707 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 10/30
# 97/97 [==============================] - 3s 29ms/step - loss: 5.4795 - accuracy: 0.8747 - mean_squared_error: 1.4031 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 10.0534 - val_accuracy: 0.8565 - val_mean_squared_error: 1.7931 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 11/30
# 97/97 [==============================] - 3s 29ms/step - loss: 4.5600 - accuracy: 0.8761 - mean_squared_error: 1.4022 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 7.8859 - val_accuracy: 0.8673 - val_mean_squared_error: 1.6604 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 12/30
# 97/97 [==============================] - 3s 28ms/step - loss: 4.4610 - accuracy: 0.8789 - mean_squared_error: 1.4142 - meanDistanceFromRecoToTrue: 113.7817 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 11.2718 - val_accuracy: 0.8492 - val_mean_squared_error: 2.0028 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 13/30
# 97/97 [==============================] - 3s 28ms/step - loss: 4.6735 - accuracy: 0.8701 - mean_squared_error: 1.4919 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 9.2912 - val_accuracy: 0.8669 - val_mean_squared_error: 1.6120 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 14/30
# 97/97 [==============================] - 3s 28ms/step - loss: 4.2933 - accuracy: 0.8796 - mean_squared_error: 1.3688 - meanDistanceFromRecoToTrue: 109.7610 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 9.4610 - val_accuracy: 0.8533 - val_mean_squared_error: 1.8883 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 15/30
# 97/97 [==============================] - 3s 28ms/step - loss: 4.3648 - accuracy: 0.8790 - mean_squared_error: 1.4436 - meanDistanceFromRecoToTrue: 110.4884 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 9.5402 - val_accuracy: 0.8502 - val_mean_squared_error: 1.9401 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 16/30
# 97/97 [==============================] - 3s 29ms/step - loss: 4.0884 - accuracy: 0.8857 - mean_squared_error: 1.3793 - meanDistanceFromRecoToTrue: 108.0811 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 10.2741 - val_accuracy: 0.8692 - val_mean_squared_error: 1.7398 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 17/30
# 97/97 [==============================] - 3s 29ms/step - loss: 4.3027 - accuracy: 0.8918 - mean_squared_error: 1.3439 - meanDistanceFromRecoToTrue: 109.6279 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 10.0714 - val_accuracy: 0.8745 - val_mean_squared_error: 1.6456 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 18/30
# 97/97 [==============================] - 3s 33ms/step - loss: 4.5981 - accuracy: 0.8831 - mean_squared_error: 1.3696 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 9.3120 - val_accuracy: 0.8677 - val_mean_squared_error: 1.7134 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 19/30
# 97/97 [==============================] - 3s 29ms/step - loss: 3.7961 - accuracy: 0.8958 - mean_squared_error: 1.2998 - meanDistanceFromRecoToTrue: 108.3245 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 10.5315 - val_accuracy: 0.8615 - val_mean_squared_error: 1.9205 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 20/30
# 97/97 [==============================] - 3s 30ms/step - loss: 3.8840 - accuracy: 0.8900 - mean_squared_error: 1.3807 - meanDistanceFromRecoToTrue: 111.7323 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 7.2561 - val_accuracy: 0.8779 - val_mean_squared_error: 1.6249 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 21/30
# 97/97 [==============================] - 3s 32ms/step - loss: 4.0698 - accuracy: 0.8921 - mean_squared_error: 1.3662 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 8.9142 - val_accuracy: 0.8809 - val_mean_squared_error: 1.5742 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 22/30
# 97/97 [==============================] - 3s 28ms/step - loss: 3.5360 - accuracy: 0.9001 - mean_squared_error: 1.2932 - meanDistanceFromRecoToTrue: 106.8858 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 10.6252 - val_accuracy: 0.8865 - val_mean_squared_error: 1.6163 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.3758
# Epoch 23/30
# 97/97 [==============================] - 3s 27ms/step - loss: 4.2235 - accuracy: 0.8987 - mean_squared_error: 1.2892 - meanDistanceFromRecoToTrue: 106.5041 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 8.9383 - val_accuracy: 0.8730 - val_mean_squared_error: 1.7581 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 24/30
# 97/97 [==============================] - 3s 27ms/step - loss: 3.7771 - accuracy: 0.9021 - mean_squared_error: 1.2756 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 11.6650 - val_accuracy: 0.8856 - val_mean_squared_error: 1.6763 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 25/30
# 97/97 [==============================] - 3s 31ms/step - loss: 4.3652 - accuracy: 0.8987 - mean_squared_error: 1.3269 - meanDistanceFromRecoToTrue: 107.8907 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 9.3853 - val_accuracy: 0.8797 - val_mean_squared_error: 1.6852 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 26/30
# 97/97 [==============================] - 3s 27ms/step - loss: 4.8177 - accuracy: 0.8961 - mean_squared_error: 1.3176 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 10.3102 - val_accuracy: 0.8718 - val_mean_squared_error: 1.7446 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 27/30
# 97/97 [==============================] - 50s 519ms/step - loss: 4.0927 - accuracy: 0.8996 - mean_squared_error: 1.3111 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 9.0547 - val_accuracy: 0.8908 - val_mean_squared_error: 1.4741 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 28/30
# 97/97 [==============================] - 4s 36ms/step - loss: 3.7602 - accuracy: 0.9034 - mean_squared_error: 1.2541 - meanDistanceFromRecoToTrue: 107.9744 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 10.1259 - val_accuracy: 0.8922 - val_mean_squared_error: 1.5719 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 29/30
# 97/97 [==============================] - 3s 33ms/step - loss: 3.5540 - accuracy: 0.9081 - mean_squared_error: 1.2228 - meanDistanceFromRecoToTrue: 103.1115 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 11.3467 - val_accuracy: 0.8772 - val_mean_squared_error: 1.8697 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 30/30
# 97/97 [==============================] - 3s 32ms/step - loss: 3.9752 - accuracy: 0.9063 - mean_squared_error: 1.2881 - meanDistanceFromRecoToTrue: 107.4720 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 13.0166 - val_accuracy: 0.8917 - val_mean_squared_error: 1.6329 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.7516
# 4it [06:18, 102.23s/it]
# Epoch 1/30
# 97/97 [==============================] - 3s 30ms/step - loss: 4.5247 - accuracy: 0.8967 - mean_squared_error: 1.3653 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 11.3876 - val_accuracy: 0.9204 - val_mean_squared_error: 1.2062 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 2/30
# 97/97 [==============================] - 3s 29ms/step - loss: 4.1979 - accuracy: 0.8960 - mean_squared_error: 1.3906 - meanDistanceFromRecoToTrue: 110.4661 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 17.0248 - val_accuracy: 0.9187 - val_mean_squared_error: 1.3270 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 3/30
# 97/97 [==============================] - 3s 31ms/step - loss: 4.3572 - accuracy: 0.9018 - mean_squared_error: 1.3217 - meanDistanceFromRecoToTrue: 104.8215 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 14.6492 - val_accuracy: 0.9307 - val_mean_squared_error: 1.1202 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 4/30
# 97/97 [==============================] - 3s 34ms/step - loss: 3.9796 - accuracy: 0.9093 - mean_squared_error: 1.2461 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 13.2444 - val_accuracy: 0.9245 - val_mean_squared_error: 1.2592 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 5/30
# 97/97 [==============================] - 3s 31ms/step - loss: 3.4689 - accuracy: 0.9030 - mean_squared_error: 1.3483 - meanDistanceFromRecoToTrue: 107.0752 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 12.0390 - val_accuracy: 0.9394 - val_mean_squared_error: 1.0143 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 6/30
# 97/97 [==============================] - 3s 32ms/step - loss: 5.2277 - accuracy: 0.9069 - mean_squared_error: 1.3085 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 18.1690 - val_accuracy: 0.9329 - val_mean_squared_error: 1.0685 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 7/30
# 97/97 [==============================] - 3s 32ms/step - loss: 4.6938 - accuracy: 0.9061 - mean_squared_error: 1.3076 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 15.9352 - val_accuracy: 0.9296 - val_mean_squared_error: 1.2190 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 8/30
# 97/97 [==============================] - 3s 30ms/step - loss: 4.1211 - accuracy: 0.9074 - mean_squared_error: 1.3334 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 14.6103 - val_accuracy: 0.9347 - val_mean_squared_error: 1.1398 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 9/30
# 97/97 [==============================] - 3s 30ms/step - loss: 3.8373 - accuracy: 0.9135 - mean_squared_error: 1.2656 - meanDistanceFromRecoToTrue: 108.8370 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 12.4605 - val_accuracy: 0.9374 - val_mean_squared_error: 1.0966 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 10/30
# 97/97 [==============================] - 3s 33ms/step - loss: 4.0840 - accuracy: 0.9155 - mean_squared_error: 1.2726 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 12.9127 - val_accuracy: 0.9396 - val_mean_squared_error: 1.0109 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 11/30
# 97/97 [==============================] - 3s 35ms/step - loss: 3.9224 - accuracy: 0.9170 - mean_squared_error: 1.2535 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 16.9104 - val_accuracy: 0.9431 - val_mean_squared_error: 1.0156 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 12/30
# 97/97 [==============================] - 3s 28ms/step - loss: 3.3129 - accuracy: 0.9201 - mean_squared_error: 1.2143 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 14.0637 - val_accuracy: 0.9461 - val_mean_squared_error: 0.9483 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 13/30
# 97/97 [==============================] - 3s 29ms/step - loss: 3.6360 - accuracy: 0.9234 - mean_squared_error: 1.1917 - meanDistanceFromRecoToTrue: 103.1209 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 13.7901 - val_accuracy: 0.9446 - val_mean_squared_error: 0.9913 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 14/30
# 97/97 [==============================] - 3s 32ms/step - loss: 3.2296 - accuracy: 0.9265 - mean_squared_error: 1.1512 - meanDistanceFromRecoToTrue: 102.8706 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 15.5414 - val_accuracy: 0.9412 - val_mean_squared_error: 1.0946 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 15/30
# 97/97 [==============================] - 3s 29ms/step - loss: 3.5887 - accuracy: 0.9255 - mean_squared_error: 1.1580 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 12.0656 - val_accuracy: 0.9408 - val_mean_squared_error: 1.0977 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 16/30
# 97/97 [==============================] - 3s 28ms/step - loss: 3.2564 - accuracy: 0.9252 - mean_squared_error: 1.1522 - meanDistanceFromRecoToTrue: 103.0586 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 13.6172 - val_accuracy: 0.9417 - val_mean_squared_error: 1.0801 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 17/30
# 97/97 [==============================] - 3s 28ms/step - loss: 3.3838 - accuracy: 0.9277 - mean_squared_error: 1.1706 - meanDistanceFromRecoToTrue: 102.5055 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 17.5806 - val_accuracy: 0.9469 - val_mean_squared_error: 0.9782 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 18/30
# 97/97 [==============================] - 3s 29ms/step - loss: 3.3059 - accuracy: 0.9281 - mean_squared_error: 1.1300 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 13.2044 - val_accuracy: 0.9431 - val_mean_squared_error: 1.0894 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 19/30
# 97/97 [==============================] - 3s 28ms/step - loss: 3.4599 - accuracy: 0.9298 - mean_squared_error: 1.1461 - meanDistanceFromRecoToTrue: 101.1132 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 15.1795 - val_accuracy: 0.9478 - val_mean_squared_error: 0.9734 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 20/30
# 97/97 [==============================] - 3s 28ms/step - loss: 3.3400 - accuracy: 0.9344 - mean_squared_error: 1.0905 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 14.6221 - val_accuracy: 0.9463 - val_mean_squared_error: 0.9677 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 21/30
# 97/97 [==============================] - 3s 30ms/step - loss: 2.9777 - accuracy: 0.9289 - mean_squared_error: 1.1455 - meanDistanceFromRecoToTrue: 103.2779 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 13.0370 - val_accuracy: 0.9459 - val_mean_squared_error: 0.9980 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 22/30
# 97/97 [==============================] - 3s 27ms/step - loss: 3.4672 - accuracy: 0.9318 - mean_squared_error: 1.1045 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 14.2782 - val_accuracy: 0.9424 - val_mean_squared_error: 1.0315 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 23/30
# 97/97 [==============================] - 3s 28ms/step - loss: 3.8338 - accuracy: 0.9292 - mean_squared_error: 1.1563 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 16.1092 - val_accuracy: 0.9462 - val_mean_squared_error: 0.9797 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 24/30
# 97/97 [==============================] - 3s 28ms/step - loss: 3.4834 - accuracy: 0.9332 - mean_squared_error: 1.0899 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 16.3329 - val_accuracy: 0.9439 - val_mean_squared_error: 1.0544 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 25/30
# 97/97 [==============================] - 3s 30ms/step - loss: 3.7198 - accuracy: 0.9314 - mean_squared_error: 1.1169 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 11.7532 - val_accuracy: 0.9430 - val_mean_squared_error: 1.1083 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 26/30
# 97/97 [==============================] - 3s 28ms/step - loss: 3.4979 - accuracy: 0.9312 - mean_squared_error: 1.1636 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 16.3989 - val_accuracy: 0.9512 - val_mean_squared_error: 0.8922 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 27/30
# 97/97 [==============================] - 3s 28ms/step - loss: 2.8848 - accuracy: 0.9328 - mean_squared_error: 1.1217 - meanDistanceFromRecoToTrue: 101.2129 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 14.4171 - val_accuracy: 0.9518 - val_mean_squared_error: 0.9043 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 28/30
# 97/97 [==============================] - 3s 28ms/step - loss: 3.5160 - accuracy: 0.9378 - mean_squared_error: 1.0792 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 14.9927 - val_accuracy: 0.9517 - val_mean_squared_error: 0.9236 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.3297
# Epoch 29/30
# 97/97 [==============================] - 3s 28ms/step - loss: 3.0037 - accuracy: 0.9365 - mean_squared_error: 1.0712 - meanDistanceFromRecoToTrue: 98.7700 - distancesFromTrueToReco: 0.0000e+00 - val_loss: 14.1802 - val_accuracy: 0.9498 - val_mean_squared_error: 0.9901 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# Epoch 30/30
# 97/97 [==============================] - 3s 27ms/step - loss: 3.3616 - accuracy: 0.9391 - mean_squared_error: 1.0810 - meanDistanceFromRecoToTrue: nan - distancesFromTrueToReco: 0.0000e+00 - val_loss: 16.0441 - val_accuracy: 0.9511 - val_mean_squared_error: 0.9484 - val_meanDistanceFromRecoToTrue: nan - val_distancesFromTrueToReco: 0.0000e+00
# 5it [07:44, 92.93s/it]
# 2024-03-24 15:43:02.254941: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz

# %%
# %matplotlib inline

fig, ax1 = plt.subplots(1, 1, figsize=(5, 5))
# ax2 = ax1.twinx()

total_loss = np.concatenate([history.history['loss'] for history in histories])
total_val_loss = np.concatenate([history.history['val_loss'] for history in histories])
total_mse = np.concatenate([history.history['mean_squared_error'] for history in histories])
total_val_mse = np.concatenate([history.history['val_mean_squared_error'] for history in histories])
nEpochs = [len(history.history['loss']) for history in histories]

maxY = max(np.max(total_loss), np.max(total_val_loss))

ax1.plot(total_loss, label='Training SL', color=twilight[5,:])
ax1.plot(total_val_loss, label='Validation SL', color=twilight[40-5,:])

ax1.plot(total_mse, label='Training MSE', color=twilight[7,:], linestyle='--')
ax1.plot(total_val_mse, label='Validation MSE', color=twilight[40-7,:] , linestyle='--')

ax1.vlines(np.cumsum(nEpochs)-1, 0, maxY, color='k', linestyle=':', alpha=0.5)

# ax2.plot(history.history['accuracy'], label='Training Accuracy', color=twilight[9,:], linestyle=':')
# ax2.plot(history.history['val_accuracy'], label='Validation Accuracy', color=twilight[40-9,:], linestyle=':')
# ax1.plot([], [], label='Training Accuracy', color=twilight[9,:], linestyle=':')
# ax1.plot([], [], label='Validation Accuracy', color=twilight[40-9,:], linestyle=':')

ax1.set_xlabel('Epoch')

ax1.set_ylabel('Loss Metrics')
# ax2.set_ylabel('Accuracy Metrics')

# ax1.set_yscale('log')
# ax2.set_yscale('log')

ax1.set_xlim(0, len(total_loss)-1)
# ax2.set_xlim(0, len(history.history['loss'])-1)
ax1.set_ylim(0, maxY)
# ax2.set_ylim(ymin=0, ymax=1)

ax1.grid()
# ax2.grid()

# ax1.set_title('Training history')
ax1.legend()
plt.show()

# %%
saveModel = False
loadModel = False

# fileName = 'models/model_{}_{}.h5'.format(plotRecoName, {True:'withErrors', False:'noErrors'}[makeErrors])
fileName = 'models/model_200multievent_20x20x20_5kFold_30epochs_primaryLabels.h5'
if saveModel:
    model.save(fileName)
    print('Saved model to', fileName)
if loadModel:
    model = tf.keras.models.load_model(fileName, custom_objects={'sparseLoss': sparseLoss})
    print('Loaded model from', fileName)

# %%
nBins = 50
xmax = 200
# xmax = None
lw = 2
colors = [twilight[5,:], twilight[40-5,:], twilight[12,:], twilight[40-12,:]]
density = False
plots = [True, False]

meanDistanceFromTrueToReco_test = []
meanDistanceFromRecoToTrue_test = []
meanDistanceFromTrueToReco_train = []
meanDistanceFromRecoToTrue_train = []
distancesFromTrueToReco_test = []
distancesFromRecoToTrue_test = []
distancesFromTrueToReco_train = []
distancesFromRecoToTrue_train = []

for i in tqdm.tqdm(range(len(X_test))):
    mean, distances = meanAndDistancesFromTrueToReco(Y_test[i], model.predict(X_test[i:i+1], verbose=0)[0], eps=12, optimize=True, minEntries=20, deltaEps=0.1)
    meanDistanceFromTrueToReco_test.append(mean)
    distancesFromTrueToReco_test.append(distances.numpy())

    mean, distances = meanAndDistancesFromRecoToTrue(Y_test[i], model.predict(X_test[i:i+1], verbose=0)[0], eps=12, optimize=True, minEntries=20, deltaEps=0.1)
    meanDistanceFromRecoToTrue_test.append(mean)
    distancesFromRecoToTrue_test.append(distances.numpy())
for i in tqdm.tqdm(range(len(X_train))):
    mean, distances = meanAndDistancesFromTrueToReco(Y_train[i], model.predict(X_train[i:i+1], verbose=0)[0], eps=12, optimize=True, minEntries=20, deltaEps=0.1)
    meanDistanceFromTrueToReco_train.append(mean)
    distancesFromTrueToReco_train.append(distances.numpy())

    mean, distances = meanAndDistancesFromRecoToTrue(Y_train[i], model.predict(X_train[i:i+1], verbose=0)[0], eps=12, optimize=True, minEntries=20, deltaEps=0.1)
    meanDistanceFromRecoToTrue_train.append(mean)
    distancesFromRecoToTrue_train.append(distances.numpy())

print(distancesFromRecoToTrue_test[0].shape)
print(distancesFromRecoToTrue_test[0])
print(distancesFromTrueToReco_test[0].shape)
print(distancesFromTrueToReco_test[0])

meanDistanceFromTrueToReco_test = np.array(meanDistanceFromTrueToReco_test)
meanDistanceFromRecoToTrue_test = np.array(meanDistanceFromRecoToTrue_test)
meanDistanceFromTrueToReco_train = np.array(meanDistanceFromTrueToReco_train)
meanDistanceFromRecoToTrue_train = np.array(meanDistanceFromRecoToTrue_train)

meanDistanceFromTrueToReco_test = meanDistanceFromTrueToReco_test[~np.isnan(meanDistanceFromTrueToReco_test)]
meanDistanceFromRecoToTrue_test = meanDistanceFromRecoToTrue_test[~np.isnan(meanDistanceFromRecoToTrue_test)]
meanDistanceFromTrueToReco_train = meanDistanceFromTrueToReco_train[~np.isnan(meanDistanceFromTrueToReco_train)]
meanDistanceFromRecoToTrue_train = meanDistanceFromRecoToTrue_train[~np.isnan(meanDistanceFromRecoToTrue_train)]

for i in range(len(distancesFromRecoToTrue_test)):
    distancesFromRecoToTrue_test[i] = distancesFromRecoToTrue_test[i][~np.isnan(distancesFromRecoToTrue_test[i])]
for i in range(len(distancesFromTrueToReco_test)):
    distancesFromTrueToReco_test[i] = distancesFromTrueToReco_test[i][~np.isnan(distancesFromTrueToReco_test[i])]
for i in range(len(distancesFromRecoToTrue_train)):
    distancesFromRecoToTrue_train[i] = distancesFromRecoToTrue_train[i][~np.isnan(distancesFromRecoToTrue_train[i])]
for i in range(len(distancesFromTrueToReco_train)):
    distancesFromTrueToReco_train[i] = distancesFromTrueToReco_train[i][~np.isnan(distancesFromTrueToReco_train[i])]

##################################################################################################################
##################################################################################################################
##################################################################################################################

if plots[0] and plots[1]:
    fig, ax = plt.subplots(1, 2, figsize=(11, 5))
elif plots[0] or plots[1]:
    fig, ax = plt.subplots(1, 1, figsize=(5, 5))
    ax = [ax, ax]

if plots[0]:
    if xmax is None:
        xmax = np.max([np.max(meanDistanceFromRecoToTrue_test), np.max(meanDistanceFromTrueToReco_test), np.max(meanDistanceFromTrueToReco_train), np.max(meanDistanceFromTrueToReco_train)])


    bins_TR_train, edges_TR_train, _ = ax[0].hist(meanDistanceFromTrueToReco_train, bins=nBins, range=(0, xmax), histtype='step', color=colors[2], linewidth=lw, density=density)
    bins_RT_train, edges_RT_train, _ = ax[0].hist(meanDistanceFromRecoToTrue_train, bins=nBins, range=(0, xmax), histtype='step', color=colors[3], linewidth=lw, density=density)
    bins_TR_test, edges_TR_test, _ = ax[0].hist(meanDistanceFromTrueToReco_test, bins=nBins, range=(0, xmax), histtype='step', color=colors[0], linewidth=lw, density=density)
    bins_RT_test, edges_RT_test, _ = ax[0].hist(meanDistanceFromRecoToTrue_test, bins=nBins, range=(0, xmax), histtype='step', color=colors[1], linewidth=lw, density=density)

    bins_TR_train_step = np.insert(bins_TR_train.repeat(2), [0, len(bins_TR_train)*2], 0)
    bins_RT_train_step = np.insert(bins_RT_train.repeat(2), [0, len(bins_RT_train)*2], 0)
    bins_TR_test_step = np.insert(bins_TR_test.repeat(2), [0, len(bins_TR_test)*2], 0)
    bins_RT_test_step = np.insert(bins_RT_test.repeat(2), [0, len(bins_RT_test)*2], 0)

    edges_TR_train_step = np.array(edges_TR_train).repeat(2)
    edges_RT_train_step = np.array(edges_RT_train).repeat(2)
    edges_TR_test_step = np.array(edges_TR_test).repeat(2)
    edges_RT_test_step = np.array(edges_RT_test).repeat(2)

    path_TR_train = Path(np.array([edges_TR_train_step, bins_TR_train_step]).T)
    path_RT_train = Path(np.array([edges_RT_train_step, bins_RT_train_step]).T)
    path_TR_test = Path(np.array([edges_TR_test_step, bins_TR_test_step]).T)
    path_RT_test = Path(np.array([edges_RT_test_step, bins_RT_test_step]).T)

    patch_TR_train = PathPatch(path_TR_train, facecolor='None', edgecolor=colors[2], alpha=1, hatch=r'\\', label=r'Train True $\to$ Reco')
    patch_RT_train = PathPatch(path_RT_train, facecolor='None', edgecolor=colors[3], alpha=1, hatch=r'\\', label=r'Train Reco $\to$ True')
    patch_TR_test = PathPatch(path_TR_test, facecolor='None', edgecolor=colors[0], alpha=1, hatch='//', label=r'Test True $\to$ Reco')
    patch_RT_test = PathPatch(path_RT_test, facecolor='None', edgecolor=colors[1], alpha=1, hatch='//', label=r'Test Reco $\to$ True')

    ax[0].add_patch(patch_TR_train)
    ax[0].add_patch(patch_RT_train)
    ax[0].add_patch(patch_TR_test)
    ax[0].add_patch(patch_RT_test)

    ax[0].set_yscale('log')
    ax[0].set_xlabel('Mean Distance [mm]')
    ax[0].set_ylabel('Density')
    ax[0].set_xlim(0, xmax)
    ax[0].legend()
    ax[0].grid()

##################################################################################################################
##################################################################################################################
##################################################################################################################

if plots[1]:
    if xmax is None:
        xmax = np.max([np.max(np.concatenate(distancesFromRecoToTrue_train)), np.max(np.concatenate(distancesFromTrueToReco_train)), np.max(np.concatenate(distancesFromRecoToTrue_test)), np.max(np.concatenate(distancesFromTrueToReco_test))])

    bins_TR_train, edges_TR_train, _ = ax[1].hist(np.concatenate(distancesFromTrueToReco_train), bins=nBins, range=(0, xmax), histtype='step', color=colors[2], linewidth=lw, density=density)
    bins_RT_train, edges_RT_train, _ = ax[1].hist(np.concatenate(distancesFromRecoToTrue_train), bins=nBins, range=(0, xmax), histtype='step', color=colors[3], linewidth=lw, density=density)
    bins_TR_test, edges_TR_test, _ = ax[1].hist(np.concatenate(distancesFromTrueToReco_test), bins=nBins, range=(0, xmax), histtype='step', color=colors[0], linewidth=lw, density=density)
    bins_RT_test, edges_RT_test, _ = ax[1].hist(np.concatenate(distancesFromRecoToTrue_test), bins=nBins, range=(0, xmax), histtype='step', color=colors[1], linewidth=lw, density=density)

    bins_TR_train_step = np.insert(bins_TR_train.repeat(2), [0, len(bins_TR_train)*2], 0)
    bins_RT_train_step = np.insert(bins_RT_train.repeat(2), [0, len(bins_RT_train)*2], 0)
    bins_TR_test_step = np.insert(bins_TR_test.repeat(2), [0, len(bins_TR_test)*2], 0)
    bins_RT_test_step = np.insert(bins_RT_test.repeat(2), [0, len(bins_RT_test)*2], 0)

    edges_TR_train_step = np.array(edges_TR_train).repeat(2)
    edges_RT_train_step = np.array(edges_RT_train).repeat(2)
    edges_TR_test_step = np.array(edges_TR_test).repeat(2)
    edges_RT_test_step = np.array(edges_RT_test).repeat(2)

    path_TR_train = Path(np.array([edges_TR_train_step, bins_TR_train_step]).T)
    path_RT_train = Path(np.array([edges_RT_train_step, bins_RT_train_step]).T)
    path_TR_test = Path(np.array([edges_TR_test_step, bins_TR_test_step]).T)
    path_RT_test = Path(np.array([edges_RT_test_step, bins_RT_test_step]).T)

    patch_TR_train = PathPatch(path_TR_train, facecolor='None', edgecolor=colors[2], alpha=1, hatch=r'\\', label=r'Train True $\to$ Reco')
    patch_RT_train = PathPatch(path_RT_train, facecolor='None', edgecolor=colors[3], alpha=1, hatch=r'\\', label=r'Train Reco $\to$ True')
    patch_TR_test = PathPatch(path_TR_test, facecolor='None', edgecolor=colors[0], alpha=1, hatch='//', label=r'Test True $\to$ Reco')
    patch_RT_test = PathPatch(path_RT_test, facecolor='None', edgecolor=colors[1], alpha=1, hatch='//', label=r'Test Reco $\to$ True')

    ax[1].add_patch(patch_TR_train)
    ax[1].add_patch(patch_RT_train)
    ax[1].add_patch(patch_TR_test)
    ax[1].add_patch(patch_RT_test)

    ax[1].set_yscale('log')
    ax[1].set_xlabel('Distance [mm]')
    ax[1].set_ylabel('Density')
    ax[1].set_xlim(0, xmax)
    ax[1].legend()
    ax[1].grid()

plt.show()
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# 100%|██████████| 20/20 [00:01<00:00, 11.91it/s]
# 100%|██████████| 121/121 [00:08<00:00, 14.39it/s]
# (7,)
# [  0.   0. 121.   0. 121.   0. 121.]
# (6,)
# [0. 0. 0. 0. 0. 0.]

# %%
# %matplotlib qt
# %matplotlib inline

inds = range(len(X_test))
# inds = [2]
epsInit = 12 # 0.2
minNshown = 20

for ind in tqdm.tqdm(inds):
    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(111, projection='3d')

    trueGrid = Y_test[ind]
    # trueGrid = zoom(Y_test[ind], [
    #     gridSize_input[0]/gridSize_output[0], 
    #     gridSize_input[1]/gridSize_output[1], 
    #     gridSize_input[2]/gridSize_output[2]])
    predGrid = model.predict(X_test[ind].reshape(1, 
                                            gridSize_input[0], 
                                            gridSize_input[1], 
                                            gridSize_input[2], 
                                            6)).reshape(gridSize_output)
    # predGrid = zoom(predGrid, [
    #     gridSize_input[0]/gridSize_output[0], 
    #     gridSize_input[1]/gridSize_output[1], 
    #     gridSize_input[2]/gridSize_output[2]])
    truePos  = np.array(dfs_hits[ind]['initialPosition'].to_list())

    eps = epsInit
    while True:
        nonZeroInd = np.where(predGrid.flatten()>eps)
        if len(nonZeroInd[0]) > minNshown:
            break
        elif eps < 0:
            break
        eps -= 0.1
    scatter = ax.scatter(grid_pos[nonZeroInd,0], grid_pos[nonZeroInd,1], grid_pos[nonZeroInd,2], c=predGrid.flatten()[nonZeroInd], cmap=cm.viridis, s=100, alpha=0.2, marker='s')
    plt.colorbar(scatter)
    
    nonZeroInd = np.where(trueGrid.flatten()>0)
    ax.scatter(grid_pos[nonZeroInd,0], grid_pos[nonZeroInd,1], grid_pos[nonZeroInd,2], c='k', cmap=cm.viridis, s=30, alpha=0.8, marker='o')

    # ax.scatter(truePos[:,0], truePos[:,1], truePos[:,2], c='g', cmap=cm.viridis, s=100, alpha=1)

    ax.set_xlim(-DETECTOR_SIZE_MM[0]/2, DETECTOR_SIZE_MM[0]/2)
    ax.set_ylim(-DETECTOR_SIZE_MM[1]/2, DETECTOR_SIZE_MM[1]/2)
    ax.set_zlim(-DETECTOR_SIZE_MM[2]/2, DETECTOR_SIZE_MM[2]/2)

    plt.show()
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 22ms/step
# /var/folders/mv/_50rblmd16xfrbsjpr4x2z0c0000gn/T/ipykernel_94593/381091056.py:41: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(grid_pos[nonZeroInd,0], grid_pos[nonZeroInd,1], grid_pos[nonZeroInd,2], c='k', cmap=cm.viridis, s=30, alpha=0.8, marker='o')
#   5%|▌         | 1/20 [00:00<00:02,  6.80it/s]
# 1/1 [==============================] - 0s 20ms/step
#  10%|█         | 2/20 [00:00<00:02,  7.16it/s]
# 1/1 [==============================] - 0s 21ms/step
#  15%|█▌        | 3/20 [00:00<00:02,  7.48it/s]
# 1/1 [==============================] - 0s 21ms/step
#  20%|██        | 4/20 [00:00<00:02,  7.45it/s]
# 1/1 [==============================] - 0s 20ms/step
#  25%|██▌       | 5/20 [00:00<00:01,  7.53it/s]
# 1/1 [==============================] - 0s 20ms/step
#  30%|███       | 6/20 [00:00<00:01,  7.72it/s]
# 1/1 [==============================] - 0s 21ms/step
#  35%|███▌      | 7/20 [00:00<00:01,  7.80it/s]
# 1/1 [==============================] - 0s 20ms/step
#  40%|████      | 8/20 [00:01<00:01,  7.80it/s]
# 1/1 [==============================] - 0s 20ms/step
#  45%|████▌     | 9/20 [00:01<00:01,  7.66it/s]
# 1/1 [==============================] - 0s 21ms/step
#  50%|█████     | 10/20 [00:01<00:01,  7.75it/s]
# 1/1 [==============================] - 0s 23ms/step
#  55%|█████▌    | 11/20 [00:01<00:02,  3.38it/s]
# 1/1 [==============================] - 0s 47ms/step
# /var/folders/mv/_50rblmd16xfrbsjpr4x2z0c0000gn/T/ipykernel_94593/381091056.py:41: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(grid_pos[nonZeroInd,0], grid_pos[nonZeroInd,1], grid_pos[nonZeroInd,2], c='k', cmap=cm.viridis, s=30, alpha=0.8, marker='o')
#  60%|██████    | 12/20 [00:02<00:02,  3.60it/s]
# 1/1 [==============================] - 0s 20ms/step
#  65%|██████▌   | 13/20 [00:02<00:01,  4.24it/s]
# 1/1 [==============================] - 0s 20ms/step
#  70%|███████   | 14/20 [00:02<00:01,  4.92it/s]
# 1/1 [==============================] - 0s 26ms/step
#  75%|███████▌  | 15/20 [00:02<00:00,  5.57it/s]
# 1/1 [==============================] - 0s 20ms/step
#  80%|████████  | 16/20 [00:03<00:01,  2.34it/s]
# 1/1 [==============================] - 0s 101ms/step
# /var/folders/mv/_50rblmd16xfrbsjpr4x2z0c0000gn/T/ipykernel_94593/381091056.py:41: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(grid_pos[nonZeroInd,0], grid_pos[nonZeroInd,1], grid_pos[nonZeroInd,2], c='k', cmap=cm.viridis, s=30, alpha=0.8, marker='o')
#  85%|████████▌ | 17/20 [00:04<00:02,  1.49it/s]
# 1/1 [==============================] - 0s 36ms/step
# /var/folders/mv/_50rblmd16xfrbsjpr4x2z0c0000gn/T/ipykernel_94593/381091056.py:41: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(grid_pos[nonZeroInd,0], grid_pos[nonZeroInd,1], grid_pos[nonZeroInd,2], c='k', cmap=cm.viridis, s=30, alpha=0.8, marker='o')
#  90%|█████████ | 18/20 [00:05<00:01,  1.78it/s]
# 1/1 [==============================] - 0s 20ms/step
#  95%|█████████▌| 19/20 [00:05<00:00,  2.34it/s]
# 1/1 [==============================] - 0s 19ms/step
# 100%|██████████| 20/20 [00:05<00:00,  3.69it/s]
