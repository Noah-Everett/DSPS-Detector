# %% [markdown]
# # Initialize Notebook

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.colors import LogNorm
from matplotlib import cm
from matplotlib.animation import FuncAnimation
from matplotlib.colors import ListedColormap
import matplotlib.patheffects as pe
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.patches import PathPatch
from matplotlib.path import Path
import tensorflow as tf
import ROOT
import uproot
import os
import sys
import tqdm
import pandas as pd
import pickle as pkl
from sklearn.decomposition import PCA
from sklearn.model_selection import KFold
from scipy.spatial.distance import cdist

# %jsroot on
# %matplotlib qt
# %matplotlib inline

# %%
sys.path.append('../python/')
from filterMethods import *
from timeMethods import *
from gridMethods import *
from trackReconstructionMethods import *
from vertexReconstructionMethods import *
from hitAccuracyMethods import *
from statisticsMethods import *
from importMethods import *
from constants import *
import plotParameters

# %%
os.environ['PYDEVD_DISABLE_FILE_VALIDATION'] = '1'

# %% [markdown]
# # Load Data

# %%
useHistograms = True

checkFiles = False

splitDataIntoFiles = True # for big data

saveData_hits    = True
saveData_primary = True
loadData_hits    = False
loadData_primary = False
saveData_hits_path    = 'data/MLdata/MLtrainData_hits.pkl'
saveData_primary_path = 'data/MLdata/MLtrainData_primary.pkl'

# %%
# fileName = '../runs/event_2mu100MeVBackToBack_usedForTrackReconstruction.root'
# fileName = '../runs/calibration_2.42^3_10000gamma_1000events.root'
# fileName = '../runs/calibration_2.42^3_10000gamma_1000events_0cmFOVL_+-1.21randPosNoSteps_randDir.root'
# fileName = '../runs/calibration_2.42^3_10000gamma_1000events_20cmFOVL.root'
# fileName = '../build/calibration.root'
# fileName = '../build/event100.root'
# fileNames = [
#     '../build/event_1.root',
#     '../build/event_2.root'
# ]

if not loadData_hits:
    histDir = '/photoSensor_hits_histograms'
    treeName = 'photoSensor_hits;1'
    minInitialPositions = 20
    minWalls = 2

    # fileNames = ['../build/multievent_{}.root'.format(i) for i in range(75)] # 100
    # fileNames = [fileName for fileName in tqdm.tqdm(fileNames) if len(get_photosensor_hits_position_initial(fileName, treeName)) >= minInitialPositions]
    # fileNames = [fileName for fileName in tqdm.tqdm(fileNames) if len(np.unique([x[1] for x in get_photosensor_hits_photosensor_wall(fileName, treeName)])) >= minWalls]

    fileNames = ['../runs/MLtrainData/multievent_{}.root'.format(i) for i in tqdm.tqdm(range(1138))] # 1138

    if checkFiles:
        sizes = [get_histogram_sizes(fileName, histDir) for fileName in tqdm.tqdm(fileNames)]
        if len(np.unique(np.array(sizes).reshape(-1, 2))) > 1:
            raise Exception('Different sizes:', np.unique(sizes))
        fileNames = [fileName for fileName in tqdm.tqdm(fileNames) if get_histogram_nHits_total(fileName, histDir) >= minInitialPositions]

    print('len(fileNames):', len(fileNames))

    # for fileName in tqdm.tqdm(fileNames)
        # print(get_histogram_names    (fileName, histDir))
        # print(get_histogram_titles   (fileName, histDir))
        # print(get_histogram_positions(fileName, histDir))
        # print(get_histogram_walls    (fileName, histDir))
        # print()
# Out:
# 100%|██████████| 1138/1138 [00:00<00:00, 3142276.47it/s]
# len(fileNames): 1138

# %%
treeName = 'photoSensor_hits;1'
dfs_hits = []

if loadData_hits:
    with open(saveData_hits_path, 'rb') as f:
        dfs_hits = pkl.load(f)
    print('df_hits length:', len(dfs_hits))
    print('df_hits[0].head():\n', dfs_hits[0].head())
else:
    for fileName in tqdm.tqdm(fileNames):
        df_hits = pd.DataFrame(columns=['sensor_name', 'sensor_direction', 'sensor_position', 'sensor_wall', 'relativePosition_binned', 'relativePosition_nBin'])
        if useHistograms:
            photosensor_IDs, photosensor_directions, photosensor_positions, photosensor_walls, position_relative_binned, position_relative_nBin = get_histogram_hits_tuple(fileName, histDir, True)
            df_hits['sensor_name'            ] = photosensor_IDs
            df_hits['sensor_direction'       ] = photosensor_directions
            df_hits['sensor_position'        ] = photosensor_positions
            df_hits['sensor_wall'            ] = photosensor_walls
            df_hits['relativePosition_binned'] = position_relative_binned
            df_hits['relativePosition_nBin'  ] = position_relative_nBin
        else:
            df_hits['sensor_name'            ] = get_photosensor_hits_photosensor_ID          (fileName, treeName, histDir, verbose=False)
            df_hits['sensor_direction'       ] = get_photosensor_hits_photosensor_direction   (fileName, treeName, histDir, verbose=False)
            df_hits['sensor_position'        ] = get_photosensor_hits_photosensor_position    (fileName, treeName, histDir, verbose=False)
            df_hits['sensor_wall'            ] = get_photosensor_hits_photosensor_wall        (fileName, treeName, histDir, verbose=False)
            # df_hits['relativePosition'       ] = get_photosensor_hits_position_relative       (fileName, treeName, histDir, verbose=False)
            df_hits['relativePosition_binned'] = get_photosensor_hits_position_relative_binned(fileName, treeName, histDir, verbose=False)
            # df_hits['relativePosition_nBin'  ] = get_photosensor_hits_position_relative_nBin  (fileName, treeName, histDir, verbose=False)
            # df_hits['initialPosition'        ] = get_photosensor_hits_position_initial        (fileName, treeName,          verbose=False)
        dfs_hits.append(df_hits)
    print('df_hits length:', len(dfs_hits))
    print('df_hits[0].head():\n', dfs_hits[0].head())

    if saveData_hits:
        with open(saveData_hits_path, 'wb') as f:
            pkl.dump(dfs_hits, f)
        print('Data saved to', saveData_hits_path)
# Out:
#  13%|█▎        | 150/1138 [05:15<34:37,  2.10s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 13
#      11 df_hits = pd.DataFrame(columns=['sensor_name', 'sensor_direction', 'sensor_position', 'sensor_wall', 'relativePosition_binned', 'relativePosition_nBin'])
#      12 if useHistograms:
# ---> 13     photosensor_IDs, photosensor_directions, photosensor_positions, photosensor_walls, position_relative_binned, position_relative_nBin = get_histogram_hits_tuple(fileName, histDir, True)
#      14     df_hits['sensor_name'            ] = photosensor_IDs
#      15     df_hits['sensor_direction'       ] = photosensor_directions
#
# File ~/Documents/FNAL/Geant4/USSD_Geant4/analysis/../python/importMethods.py:176, in get_histogram_hits_tuple(fileName, directoryName, numpy, photosensor_ID, photosensor_direction, photosensor_position, photosensor_wall, position_relative_binned, position_relative_nBin)
#     174             pos = np.array([x.flatten()[ind], y.flatten()[ind]]).T
#     175             for v_i, pos_i in zip(v, pos):
# --> 176                 position_relative_binneds.extend([pos_i] * int(v_i))
#     178 file.close()
#     180 if numpy:
#
# KeyboardInterrupt:

# %%
treeName = 'primary;1'
dfs_primary = []

if loadData_primary:
    with open(saveData_primary_path, 'rb') as f:
        dfs_primary = pkl.load(f)
    print('df_primary length:', len(dfs_primary))
    print('df_primary[0].head():\n', dfs_primary[0].head())
else:
    for fileName in tqdm.tqdm(fileNames):
        df_primary = pd.DataFrame(columns=['position', 'pdg'])
        df_primary['position' ] = get_primary_position(fileName, treeName)
        df_primary['pdg'      ] = get_primary_pdg     (fileName, treeName)
        df_primary = df_primary[df_primary['pdg'] == 13] # muon
        df_primary = df_primary[df_primary['position'].apply(lambda x:
            x[0] > -DETECTOR_SIZE_MM[0]/2 and x[0] < DETECTOR_SIZE_MM[0]/2 and
            x[1] > -DETECTOR_SIZE_MM[1]/2 and x[1] < DETECTOR_SIZE_MM[1]/2 and
            x[2] > -DETECTOR_SIZE_MM[2]/2 and x[2] < DETECTOR_SIZE_MM[2]/2
        )]
        dfs_primary.append(df_primary)
    print('df_primary length:', len(dfs_primary))
    print('df_primary[0].head():\n', dfs_primary[0].head())

    if saveData_primary:
        with open(saveData_primary_path, 'wb') as f:
            pkl.dump(dfs_primary, f)
        print('Data saved to', saveData_primary_path)
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 40.93it/s]
# df_primary length: 3
# df_primary[0].head():
#                                              position  pdg
# 0  (-86.26307828444254, 451.1131641000807, 812.89...   13
# 1  (-86.29582587532713, 450.5539990621913, 812.75...   13
# 2  (-86.32926652713361, 449.9946140973119, 812.61...   13
# 3  (-86.36331401096261, 449.43518004193965, 812.4...   13
# 4  (-86.39892018162553, 448.87597406971213, 812.3...   13
# Data saved to data/MLdata/MLtrainData_primary.pkl

# %%
if len(dfs_primary) != len(dfs_hits):
    raise Exception('len(dfs_primary) != len(dfs_hits)')

# %% [markdown]
# # Filter Hits

# %%
search_radius = 0
search_number = 0

if search_radius > 0 or search_number > 0:
    for i in tqdm.tqdm(range(len(dfs_hits))):
        dfs_hits[i] = filter_hits(dfs_hits[i], radius=search_radius, number=search_number)

# %% [markdown]
# # Basic Hit Reco

# %%
def rToTheta(r):
    return r/(CM_PER_RAD*MM_PER_CM)
for i in tqdm.tqdm(range(len(dfs_hits))):
    dfs_hits[i] = make_r(dfs_hits[i])
    dfs_hits[i] = filter_r(dfs_hits[i], Y_LIM)
    dfs_hits[i] = make_theta(dfs_hits[i], rToTheta)
    dfs_hits[i] = make_phi(dfs_hits[i])
    dfs_hits[i] = make_reconstructedVector_direction(dfs_hits[i])
    if 'initialPosition' in dfs_hits[i].columns:
        dfs_hits[i] = make_relativeVector(dfs_hits[i])
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# # Plotting Methods

# %%
color_oranges = cm.Blues_r  ([0.5,0.6,0.9])
color_blues   = cm.Oranges_r([0.5,0.6,0.9])
blue_1 = "#B6CEC7"
blue_2 = "#92C1A5"
blue_3 = "#889D8E"
red_1  = "#C16464"
red_2  = "#B64D4D"
red_3  = "#FBE6E5"
twilight = cm.twilight(np.linspace(0,1,40))

# %% [markdown]
# # Make or Load Grid

# %%
gridSize = (20, 20, 20)
makeErrors = False
save = False
savePlots = False
load = False
useWalls = False
plotRecoName = '{}x{}x{}_{}_{}'.format(gridSize[0], gridSize[1], gridSize[2], fileName.split('/')[-1].split('.')[0], {True:'withErrors', False:'noErrors'}[makeErrors])
print('plotRecoName:', plotRecoName)
# Out:
# plotRecoName: 20x20x20_multievent_2_noErrors

# %% [markdown]
# # Data

# %%
gridSize_input = gridSize
gridSize_output = np.array([20, 20, 20]) # 92, 92, 92

X_size = (len(dfs_hits),) + gridSize_input + (6,)
Y_size = (len(dfs_hits),) + (gridSize_output[0], gridSize_output[1], gridSize_output[2])

X = np.zeros((len(dfs_hits),) + gridSize_input + (6,))
Y = np.zeros((len(dfs_hits),) + (gridSize_output[0], gridSize_output[1], gridSize_output[2]))

for i, (df_hits, df_primary) in tqdm.tqdm(enumerate(zip(dfs_hits, dfs_primary))):
    X[i], grid_ind, grid_pos = make_voxelGrid(
        df_hits,
        shape=gridSize_input,
        detectorDimensions=DETECTOR_SIZE_MM,
        sensorPositions=np.array(df_hits['sensor_position'].to_list()).reshape(-1,3),
        recoDirections=np.array(df_hits['reconstructedVector_direction'].to_list()).reshape(-1,3),
        hitWeights=[1 for i in range(len(df_hits))],
        make_errors=makeErrors,
        useWalls=useWalls,
        sensorWalls=df_hits['sensor_wall'].to_numpy(),
        wallOperation=expNWalls,
        returnWalls=True)
    Y[i] = make_voxelGrid_truth(
        # np.array(df_hits['initialPosition'].to_list()),
        np.array(df_primary['position'].to_list()),
        shape=gridSize_output,
        detectorDimensions=DETECTOR_SIZE_MM,
        makeErrors=False)[0]*10

print('X.shape:', X.shape)
print('Y.shape:', Y.shape)
print()
print('grid_ind.shape:', grid_ind.shape)
print('grid_pos.shape:', grid_pos.shape)
# Out:
# 3it [00:29,  9.77s/it]
# X.shape: (3, 20, 20, 20, 6)
# Y.shape: (3, 20, 20, 20)
#
# grid_ind.shape: (8000, 3)
# grid_pos.shape: (8000, 3)

# %%
nTest = 20
np.random.seed(42)
testIndices = np.random.choice(len(dfs_hits), nTest, replace=False)

X_train = np.delete(X, testIndices, axis=0)
Y_train = np.delete(Y, testIndices, axis=0)
X_test = X[testIndices]
Y_test = Y[testIndices]

X_train_indices = np.delete(np.arange(len(dfs_hits)), testIndices)
Y_train_indices = np.delete(np.arange(len(dfs_hits)), testIndices)
X_test_indices = np.array(testIndices)
Y_test_indices = np.array(testIndices)

print('X_train.shape:', X_train.shape)
print('Y_train.shape:', Y_train.shape)
print('X_test.shape:', X_test.shape)
print('Y_test.shape:', Y_test.shape)
print()
print('X_train_indices:', X_train_indices)
print('X_test_indices:', X_test_indices)
# Out:
# X_train.shape: (3, 20, 20, 20, 6)
# Y_train.shape: (3, 20, 20, 20)
# X_test.shape: (0, 20, 20, 20, 6)
# Y_test.shape: (0, 20, 20, 20)
#
# X_train_indices: [0 1 2]
# X_test_indices: []

# %%
# %matplotlib qt
# %matplotlib inline

indices = [46, 51, 52]
# indices = X_train_indices

plots = [False, False, False]
format = 'pdf'
resolution = 300

xEdges = np.linspace(-DETECTOR_SIZE_MM[0]/2, DETECTOR_SIZE_MM[0]/2, gridSize[0] + 1)
yEdges = np.linspace(-DETECTOR_SIZE_MM[1]/2, DETECTOR_SIZE_MM[1]/2, gridSize[1] + 1)
zEdges = np.linspace(-DETECTOR_SIZE_MM[2]/2, DETECTOR_SIZE_MM[2]/2, gridSize[2] + 1)

yEdges, xEdges, zEdges = np.meshgrid(xEdges, yEdges, zEdges)

# globalColorNorm = cm.colors.Normalize(vmin=0, vmax=np.max([X_train[ind].sum(axis=-1).max()]))
globalColorNorm = cm.colors.Normalize(vmin=0, vmax=25)

alpha_empty = 0.45
alpha_filled = 0.45
alpha_true = 0.3

##################################################################################################
##################################################################################################
##################################################################################################

for ind in tqdm.tqdm(indices):
    colors = cm.viridis(globalColorNorm(X_train[ind].sum(axis=-1)))

##################################################################################################
##################################################################################################
##################################################################################################

    if plots[0]:
        fig = plt.figure(figsize=(10,10))
        ax = fig.add_subplot(111, projection='3d')

        ax.voxels(xEdges,
                yEdges,
                zEdges,
                X_train[ind].sum(axis=-1),
                facecolors=colors,
                edgecolors=np.clip(colors*2-0.5, 0, 1),
                linewidth=0.5,
                alpha=alpha_filled)

        ax.voxels(xEdges,
                yEdges,
                zEdges,
                np.ones(gridSize),
                facecolors='lightgray',
                edgecolor='gray',
                linewidth=0.5,
                alpha=alpha_empty)
        
        cbar = plt.colorbar(cm.ScalarMappable(norm=globalColorNorm, cmap=cm.viridis), ax=ax, shrink=0.6)

        ax.set_axis_off()
        ax.set_aspect('equal')
        plt.savefig('../figures/voxelGrid_{}.{}'.format(ind, format), bbox_inches='tight', transparent=True, dpi=resolution)
        plt.show()

    ##################################################################################################
    ##################################################################################################
    ##################################################################################################

    if plots[1]:
        fig = plt.figure(figsize=(5,5))
        ax = fig.add_subplot(111, projection='3d')

        nonZeroInd = np.where(Y_train[ind].flatten() > 0)
        ax.voxels(xEdges,
                yEdges,
                zEdges,
                Y_train[ind],
                facecolors='r',
                edgecolors='k',
                linewidth=0.5,
                alpha=alpha_true)

        ax.voxels(xEdges,
                yEdges,
                zEdges,
                np.ones(gridSize),
                facecolors='lightgray',
                edgecolor='gray',
                linewidth=0.5,
                alpha=alpha_empty)

        primary = np.array(dfs_primary[X_train_indices[ind]]['position'].to_list())
        ax.scatter(primary[:,0], primary[:,1], primary[:,2], c='b', s=10)

        ax.set_axis_off()
        ax.set_aspect('equal')
        plt.savefig('../figures/voxelGrid_truth_{}.{}'.format(ind, format), bbox_inches='tight', transparent=True, dpi=resolution)
        plt.show()

    ##################################################################################################
    ##################################################################################################
    ##################################################################################################
    ##################################################################################################

    if plots[2]:
        fig = plt.figure(figsize=(10,10))
        ax = fig.add_subplot(111, projection='3d')

        ax.voxels(xEdges,
                yEdges,
                zEdges,
                X_train[ind].sum(axis=-1),
                facecolors=colors,
                edgecolors=np.clip(colors*2-0.5, 0, 1),
                linewidth=0.5,
                alpha=alpha_filled)

        nonZeroInd = np.where(Y_train[ind].flatten() > 0)
        ax.voxels(xEdges,
                yEdges,
                zEdges,
                Y_train[ind],
                facecolors='r',
                edgecolors='k',
                linewidth=0.5,
                alpha=alpha_true)

        ax.voxels(xEdges,
                yEdges,
                zEdges,
                np.ones(gridSize),
                facecolors='lightgray',
                edgecolor='gray',
                linewidth=0.5,
                alpha=alpha_empty)
        
        cbar = plt.colorbar(cm.ScalarMappable(norm=globalColorNorm, cmap=cm.viridis), ax=ax, shrink=0.6)

        ax.set_axis_off()
        ax.set_aspect('equal')
        plt.savefig('../figures/voxelGrid_both_{}.{}'.format(ind, format), bbox_inches='tight', transparent=True, dpi=resolution)
        plt.show()
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[25], line 29
#      24 ##################################################################################################
#      25 ##################################################################################################
#      26 ##################################################################################################
#      28 for ind in tqdm.tqdm(indices):
# ---> 29     colors = cm.viridis(globalColorNorm(X_train[ind].sum(axis=-1)))
#      31 ##################################################################################################
#      32 ##################################################################################################
#      33 ##################################################################################################
#      35     if plots[0]:
#
# IndexError: index 46 is out of bounds for axis 0 with size 3

# %% [markdown]
# # Model

# %%
input_data = tf.keras.layers.Input(shape=X_size[1:])
summed_data = tf.keras.layers.Lambda(lambda x: tf.reduce_sum(x, axis=-1))(input_data)

dropoutRate = 0.2

conv_1_1 = tf.keras.layers.Conv3D(32, (3, 3, 3), activation='relu', padding='valid')(input_data)
conv_1_1_drop = tf.keras.layers.Dropout(dropoutRate)(conv_1_1)
maxPool_1_1 = tf.keras.layers.MaxPooling3D((2, 2, 2))(conv_1_1_drop)
conv_1_2 = tf.keras.layers.Conv3D(64, (3, 3, 3), activation='relu', padding='valid')(maxPool_1_1)
conv_1_2_drop = tf.keras.layers.Dropout(dropoutRate)(conv_1_2)
maxPool_1_2 = tf.keras.layers.MaxPooling3D((2, 2, 2))(conv_1_2_drop)

mlp_conv = tf.keras.layers.Flatten()(maxPool_1_2)
mlp_1 = tf.keras.layers.Dense(256, activation='relu')(mlp_conv)
mpl_1_drop = tf.keras.layers.Dropout(dropoutRate)(mlp_1)
mlp_2 = tf.keras.layers.Dense(16**3, activation='relu')(mpl_1_drop)
mlp_2_drop = tf.keras.layers.Dropout(dropoutRate)(mlp_2)
mlp_res = tf.keras.layers.Reshape((16, 16, 16, 1))(mlp_2_drop)

deconv_1_1 = tf.keras.layers.Conv3DTranspose(64, (3, 3, 3), activation='relu', padding='valid')(mlp_res)
deconv_1_1_drop = tf.keras.layers.Dropout(dropoutRate)(deconv_1_1)
deconv_1_2 = tf.keras.layers.Conv3DTranspose(32, (3, 3, 3), activation='relu', padding='valid')(deconv_1_1_drop)
deconv_1_2_drop = tf.keras.layers.Dropout(dropoutRate)(deconv_1_2)

output = tf.keras.layers.Conv3D(1, (3, 3, 3), activation='relu', padding='same')(deconv_1_2_drop)

model = tf.keras.Model(inputs=input_data, outputs=output)

# %%
def sparseLoss(true, pred): 
    epsilon = 1 # 1e-7
    mask = tf.greater(true, epsilon)
    mask = tf.dtypes.cast(mask, tf.float32)

    loss_inMask = tf.square(tf.subtract(true, pred))
    loss_inMask = tf.multiply(loss_inMask, mask)
    loss_inMask /= tf.reduce_sum(mask)

    loss_outMask = tf.square(tf.subtract(true, pred))
    loss_outMask = tf.multiply(loss_outMask, 1-mask)
    loss_outMask /= tf.reduce_sum(1-mask)

    # return tf.reduce_mean(loss)
    return tf.reduce_sum(loss_inMask) + tf.reduce_sum(loss_outMask)

def distancesFromRecoToTrue(true, pred, eps=8, optimize=False, minEntries=20, deltaEps=0.1):
    if type(true) == np.ndarray:
        true = tf.convert_to_tensor(true, dtype=tf.float32)
    if type(pred) == np.ndarray:
        pred = tf.convert_to_tensor(pred, dtype=tf.float32)

    pred = tf.cast(pred, tf.float32)
    true = tf.cast(true, tf.float32)
    deltaEps = tf.constant(deltaEps, dtype=tf.float32)
    eps = tf.constant(eps, dtype=tf.float32)

    if optimize:
        # while tf.where(tf.greater(pred, eps)).numpy().size < minEntries and eps > 0:
        while tf.size(tf.where(tf.greater(pred, eps))) < minEntries and eps > 0.0:
            # print(tf.where(tf.greater(pred, eps)).numpy().size)
            eps -= deltaEps

    mask = tf.cast(tf.greater(pred, eps), tf.float32)
    pred = pred * mask

    true = tf.reshape(true, (-1, 1))
    pred = tf.reshape(pred, (-1, 1))

    pred_ind = tf.where(tf.greater(pred, 0))
    true_ind = tf.where(tf.greater(true, 0))

    pred_ind = pred_ind[:, 0]
    true_ind = true_ind[:, 0]

    posTensor = tf.convert_to_tensor(grid_pos, dtype=tf.float32)

    pred_pos = tf.gather(posTensor, pred_ind)
    true_pos = tf.gather(posTensor, true_ind)

    pred_pos = tf.reshape(pred_pos, (-1, 3))
    true_pos = tf.reshape(true_pos, (-1, 3))

    pred_pos = tf.expand_dims(pred_pos, 1)
    true_pos = tf.expand_dims(true_pos, 0)

    distances = tf.norm(pred_pos - true_pos, axis=-1)
    minDistances = tf.reduce_min(distances, axis=1)

    return minDistances

def distancesFromTrueToReco(true, pred, eps=8, optimize=False, minEntries=20, deltaEps=0.1):
    return distancesFromRecoToTrue(pred, true, eps=eps, optimize=optimize, minEntries=minEntries, deltaEps=deltaEps)

def meanDistanceFromRecoToTrue(true, pred, eps=8, optimize=False, minEntries=20, deltaEps=0.1):
    return tf.reduce_mean(distancesFromRecoToTrue(true, pred, eps=eps, optimize=optimize, minEntries=minEntries, deltaEps=deltaEps))

def meanDistanceFromTrueToReco(true, pred, eps=8, optimize=False, minEntries=20, deltaEps=0.1):
    return tf.reduce_mean(distancesFromTrueToReco(true, pred, eps=eps, optimize=optimize, minEntries=minEntries, deltaEps=deltaEps))

def meanAndDistancesFromRecoToTrue(true, pred, eps=8, optimize=False, minEntries=20, deltaEps=0.1):
    distances = distancesFromRecoToTrue(true, pred, eps=eps, optimize=optimize, minEntries=minEntries, deltaEps=deltaEps)
    return tf.reduce_mean(distances), distances

def meanAndDistancesFromTrueToReco(true, pred, eps=8, optimize=False, minEntries=20, deltaEps=0.1):
    distances = distancesFromTrueToReco(true, pred, eps=eps, optimize=optimize, minEntries=minEntries, deltaEps=deltaEps)
    return tf.reduce_mean(distances), distances

def totalLoss(true, pred, eps=15, optimize=True, minEntries=15, deltaEps=0.1, alpha=0.10, beta=0.10):
    return sparseLoss(true, pred) \
         + alpha * meanDistanceFromRecoToTrue(true, pred, eps=eps, optimize=optimize, minEntries=minEntries, deltaEps=deltaEps) \
         + beta  * meanDistanceFromTrueToReco(true, pred, eps=eps, optimize=optimize, minEntries=minEntries, deltaEps=deltaEps)

# %%
custom_learning_rate = 0.0001  # Change this to your desired learning rate (default = 0.001)
optimizer = tf.keras.optimizers.Adam(learning_rate=custom_learning_rate)
# optimizer = tf.keras.optimizers.Adam()
model.compile(optimizer, loss=sparseLoss,
              metrics=['accuracy', 'mean_squared_error', 'mean_absolute_error', 'mean_absolute_percentage_error', 'mean_squared_logarithmic_error', 'cosine_similarity',
                       sparseLoss, totalLoss,
                       meanDistanceFromRecoToTrue, meanDistanceFromTrueToReco])
model.summary()
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 20, 20, 20, 6)]   0
#
#  conv3d_6 (Conv3D)           (None, 18, 18, 18, 32)    5216
#
#  dropout_12 (Dropout)        (None, 18, 18, 18, 32)    0
#
#  max_pooling3d_4 (MaxPooling  (None, 9, 9, 9, 32)      0
#  3D)
#
#  conv3d_7 (Conv3D)           (None, 7, 7, 7, 64)       55360
#
#  dropout_13 (Dropout)        (None, 7, 7, 7, 64)       0
#
#  max_pooling3d_5 (MaxPooling  (None, 3, 3, 3, 64)      0
#  3D)
#
#  flatten_2 (Flatten)         (None, 1728)              0
#
#  dense_4 (Dense)             (None, 256)               442624
#
#  dropout_14 (Dropout)        (None, 256)               0
#
#  dense_5 (Dense)             (None, 4096)              1052672
#
#  dropout_15 (Dropout)        (None, 4096)              0
#
#  reshape_2 (Reshape)         (None, 16, 16, 16, 1)     0
#
#  conv3d_transpose_4 (Conv3DT  (None, 18, 18, 18, 64)   1792
#  ranspose)
#
#  dropout_16 (Dropout)        (None, 18, 18, 18, 64)    0
#
#  conv3d_transpose_5 (Conv3DT  (None, 20, 20, 20, 32)   55328
#  ranspose)
#
#  dropout_17 (Dropout)        (None, 20, 20, 20, 32)    0
#
#  conv3d_8 (Conv3D)           (None, 20, 20, 20, 1)     865
#
# =================================================================
# Total params: 1,613,857
# Trainable params: 1,613,857
# Non-trainable params: 0
# _________________________________________________________________

# %%
useEarlyStopping = False
k = 5
nEpochs = 30
batchSize = 1
patience = 20

kFold = KFold(n_splits=k, shuffle=True)

histories = []
for i, (train_index, val_index) in tqdm.tqdm(enumerate(kFold.split(X_train))):
    X_train_k, X_val_k = X_train[train_index], X_train[val_index]
    Y_train_k, Y_val_k = Y_train[train_index], Y_train[val_index]

    if useEarlyStopping:
        early_stopping_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience, restore_best_weights=True)
        histories.append(model.fit(X_train_k, Y_train_k, epochs=nEpochs, batch_size=batchSize, validation_data=(X_val_k, Y_val_k), callbacks=[early_stopping_callback]))
    else:
        histories.append(model.fit(X_train_k, Y_train_k, epochs=nEpochs, batch_size=batchSize, validation_data=(X_val_k, Y_val_k)))
# Out:
# 0it [00:00, ?it/s]
# Epoch 1/30
# 132/132 [==============================] - 5s 31ms/step - loss: 79.0715 - accuracy: 0.6822 - mean_squared_error: 5.4269 - mean_absolute_error: 1.1251 - mean_absolute_percentage_error: 1110664064.0000 - mean_squared_logarithmic_error: 0.6389 - cosine_similarity: 0.0078 - sparseLoss: 79.0715 - totalLoss: 169.1789 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 1.0943 - val_loss: 69.5531 - val_accuracy: 0.5948 - val_mean_squared_error: 2.1185 - val_mean_absolute_error: 0.8997 - val_mean_absolute_percentage_error: 884559552.0000 - val_mean_squared_logarithmic_error: 0.4792 - val_cosine_similarity: 0.0098 - val_sparseLoss: 69.5531 - val_totalLoss: 140.3521 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 2/30
# 132/132 [==============================] - 4s 27ms/step - loss: 70.1700 - accuracy: 0.6025 - mean_squared_error: 4.9934 - mean_absolute_error: 1.2264 - mean_absolute_percentage_error: 1213506560.0000 - mean_squared_logarithmic_error: 0.6705 - cosine_similarity: 0.0089 - sparseLoss: 70.1700 - totalLoss: 143.9388 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 58.1933 - val_accuracy: 0.2850 - val_mean_squared_error: 4.1471 - val_mean_absolute_error: 1.3317 - val_mean_absolute_percentage_error: 1319681152.0000 - val_mean_squared_logarithmic_error: 0.7287 - val_cosine_similarity: 0.0103 - val_sparseLoss: 58.1933 - val_totalLoss: 121.7094 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 3/30
# 132/132 [==============================] - 4s 27ms/step - loss: 63.9086 - accuracy: 0.2140 - mean_squared_error: 5.4921 - mean_absolute_error: 1.5011 - mean_absolute_percentage_error: 1489233536.0000 - mean_squared_logarithmic_error: 0.8246 - cosine_similarity: 0.0091 - sparseLoss: 63.9086 - totalLoss: 142.7900 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 61.5646 - val_accuracy: 0.1023 - val_mean_squared_error: 2.4189 - val_mean_absolute_error: 1.3168 - val_mean_absolute_percentage_error: 1302209536.0000 - val_mean_squared_logarithmic_error: 0.7124 - val_cosine_similarity: 0.0100 - val_sparseLoss: 61.5646 - val_totalLoss: 118.7993 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 4/30
# 132/132 [==============================] - 4s 27ms/step - loss: 52.6907 - accuracy: 0.0400 - mean_squared_error: 7.4472 - mean_absolute_error: 2.2142 - mean_absolute_percentage_error: 2204167168.0000 - mean_squared_logarithmic_error: 1.3229 - cosine_similarity: 0.0091 - sparseLoss: 52.6907 - totalLoss: 133.5234 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 46.6168 - val_accuracy: 0.0152 - val_mean_squared_error: 8.3646 - val_mean_absolute_error: 2.6230 - val_mean_absolute_percentage_error: 2611665920.0000 - val_mean_squared_logarithmic_error: 1.6274 - val_cosine_similarity: 0.0094 - val_sparseLoss: 46.6168 - val_totalLoss: 113.6794 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 5/30
# 132/132 [==============================] - 4s 27ms/step - loss: 46.2445 - accuracy: 0.0090 - mean_squared_error: 12.1869 - mean_absolute_error: 3.1218 - mean_absolute_percentage_error: 3112987904.0000 - mean_squared_logarithmic_error: 1.9530 - cosine_similarity: 0.0089 - sparseLoss: 46.2445 - totalLoss: 126.3202 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 43.4806 - val_accuracy: 0.0022 - val_mean_squared_error: 13.9144 - val_mean_absolute_error: 3.4577 - val_mean_absolute_percentage_error: 3447759872.0000 - val_mean_squared_logarithmic_error: 2.1866 - val_cosine_similarity: 0.0090 - val_sparseLoss: 43.4806 - val_totalLoss: 106.3762 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 6/30
# 132/132 [==============================] - 4s 27ms/step - loss: 45.0751 - accuracy: 0.0033 - mean_squared_error: 16.0653 - mean_absolute_error: 3.6661 - mean_absolute_percentage_error: 3657886464.0000 - mean_squared_logarithmic_error: 2.3118 - cosine_similarity: 0.0088 - sparseLoss: 45.0751 - totalLoss: 125.2577 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 42.5626 - val_accuracy: 0.0018 - val_mean_squared_error: 15.1137 - val_mean_absolute_error: 3.6092 - val_mean_absolute_percentage_error: 3599689216.0000 - val_mean_squared_logarithmic_error: 2.2840 - val_cosine_similarity: 0.0090 - val_sparseLoss: 42.5626 - val_totalLoss: 106.5803 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 7/30
# 132/132 [==============================] - 4s 27ms/step - loss: 44.1212 - accuracy: 0.0030 - mean_squared_error: 16.5957 - mean_absolute_error: 3.7384 - mean_absolute_percentage_error: 3730616064.0000 - mean_squared_logarithmic_error: 2.3591 - cosine_similarity: 0.0089 - sparseLoss: 44.1212 - totalLoss: 123.8378 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 43.5118 - val_accuracy: 0.0017 - val_mean_squared_error: 14.7139 - val_mean_absolute_error: 3.5680 - val_mean_absolute_percentage_error: 3558058240.0000 - val_mean_squared_logarithmic_error: 2.2588 - val_cosine_similarity: 0.0089 - val_sparseLoss: 43.5118 - val_totalLoss: 105.6068 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 8/30
# 132/132 [==============================] - 4s 27ms/step - loss: 43.4927 - accuracy: 0.0030 - mean_squared_error: 16.1766 - mean_absolute_error: 3.6945 - mean_absolute_percentage_error: 3686766080.0000 - mean_squared_logarithmic_error: 2.3324 - cosine_similarity: 0.0090 - sparseLoss: 43.4927 - totalLoss: 119.2329 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 44.6263 - val_accuracy: 0.0020 - val_mean_squared_error: 14.2524 - val_mean_absolute_error: 3.5162 - val_mean_absolute_percentage_error: 3505792512.0000 - val_mean_squared_logarithmic_error: 2.2264 - val_cosine_similarity: 0.0087 - val_sparseLoss: 44.6263 - val_totalLoss: 110.9315 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 9/30
# 132/132 [==============================] - 4s 27ms/step - loss: 43.3101 - accuracy: 0.0029 - mean_squared_error: 16.0157 - mean_absolute_error: 3.6823 - mean_absolute_percentage_error: 3674531840.0000 - mean_squared_logarithmic_error: 2.3258 - cosine_similarity: 0.0090 - sparseLoss: 43.3101 - totalLoss: 121.8102 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 42.2618 - val_accuracy: 0.0016 - val_mean_squared_error: 15.1951 - val_mean_absolute_error: 3.6271 - val_mean_absolute_percentage_error: 3617605632.0000 - val_mean_squared_logarithmic_error: 2.2967 - val_cosine_similarity: 0.0090 - val_sparseLoss: 42.2618 - val_totalLoss: 106.8182 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 10/30
# 132/132 [==============================] - 4s 27ms/step - loss: 43.0330 - accuracy: 0.0025 - mean_squared_error: 16.4236 - mean_absolute_error: 3.7331 - mean_absolute_percentage_error: 3725534720.0000 - mean_squared_logarithmic_error: 2.3584 - cosine_similarity: 0.0090 - sparseLoss: 43.0330 - totalLoss: 120.4838 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 41.7067 - val_accuracy: 0.0015 - val_mean_squared_error: 15.4849 - val_mean_absolute_error: 3.6632 - val_mean_absolute_percentage_error: 3653918720.0000 - val_mean_squared_logarithmic_error: 2.3199 - val_cosine_similarity: 0.0091 - val_sparseLoss: 41.7067 - val_totalLoss: 98.4467 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 11/30
# 132/132 [==============================] - 4s 27ms/step - loss: 42.8880 - accuracy: 0.0034 - mean_squared_error: 15.4145 - mean_absolute_error: 3.6094 - mean_absolute_percentage_error: 3601654528.0000 - mean_squared_logarithmic_error: 2.2797 - cosine_similarity: 0.0092 - sparseLoss: 42.8880 - totalLoss: 122.2361 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 42.7149 - val_accuracy: 0.0032 - val_mean_squared_error: 14.2457 - val_mean_absolute_error: 3.5177 - val_mean_absolute_percentage_error: 3507905536.0000 - val_mean_squared_logarithmic_error: 2.2281 - val_cosine_similarity: 0.0091 - val_sparseLoss: 42.7149 - val_totalLoss: 108.1879 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 12/30
# 132/132 [==============================] - 4s 27ms/step - loss: 43.1299 - accuracy: 0.0031 - mean_squared_error: 15.4799 - mean_absolute_error: 3.6216 - mean_absolute_percentage_error: 3613607168.0000 - mean_squared_logarithmic_error: 2.2878 - cosine_similarity: 0.0091 - sparseLoss: 43.1299 - totalLoss: 119.9756 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 43.4111 - val_accuracy: 0.0017 - val_mean_squared_error: 14.5110 - val_mean_absolute_error: 3.5553 - val_mean_absolute_percentage_error: 3545203456.0000 - val_mean_squared_logarithmic_error: 2.2527 - val_cosine_similarity: 0.0089 - val_sparseLoss: 43.4111 - val_totalLoss: 105.0359 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 13/30
# 132/132 [==============================] - 4s 27ms/step - loss: 42.2454 - accuracy: 0.0028 - mean_squared_error: 15.7917 - mean_absolute_error: 3.6679 - mean_absolute_percentage_error: 3660366848.0000 - mean_squared_logarithmic_error: 2.3190 - cosine_similarity: 0.0092 - sparseLoss: 42.2454 - totalLoss: 120.1017 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 43.3964 - val_accuracy: 0.0016 - val_mean_squared_error: 14.9914 - val_mean_absolute_error: 3.6152 - val_mean_absolute_percentage_error: 3605206016.0000 - val_mean_squared_logarithmic_error: 2.2912 - val_cosine_similarity: 0.0088 - val_sparseLoss: 43.3964 - val_totalLoss: 107.5199 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 14/30
# 132/132 [==============================] - 4s 27ms/step - loss: 42.1967 - accuracy: 0.0027 - mean_squared_error: 15.6216 - mean_absolute_error: 3.6509 - mean_absolute_percentage_error: 3643236864.0000 - mean_squared_logarithmic_error: 2.3087 - cosine_similarity: 0.0092 - sparseLoss: 42.1967 - totalLoss: 118.9470 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 41.1692 - val_accuracy: 0.0013 - val_mean_squared_error: 15.8128 - val_mean_absolute_error: 3.7125 - val_mean_absolute_percentage_error: 3703373312.0000 - val_mean_squared_logarithmic_error: 2.3529 - val_cosine_similarity: 0.0091 - val_sparseLoss: 41.1692 - val_totalLoss: 100.5843 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 15/30
# 132/132 [==============================] - 4s 27ms/step - loss: 41.7519 - accuracy: 0.0026 - mean_squared_error: 15.6362 - mean_absolute_error: 3.6582 - mean_absolute_percentage_error: 3650670336.0000 - mean_squared_logarithmic_error: 2.3143 - cosine_similarity: 0.0093 - sparseLoss: 41.7519 - totalLoss: 118.5333 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 41.1945 - val_accuracy: 0.0011 - val_mean_squared_error: 15.6288 - val_mean_absolute_error: 3.6936 - val_mean_absolute_percentage_error: 3684343040.0000 - val_mean_squared_logarithmic_error: 2.3415 - val_cosine_similarity: 0.0091 - val_sparseLoss: 41.1945 - val_totalLoss: 98.8179 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 16/30
# 132/132 [==============================] - 4s 27ms/step - loss: 40.7556 - accuracy: 0.0022 - mean_squared_error: 16.0605 - mean_absolute_error: 3.7136 - mean_absolute_percentage_error: 3706348544.0000 - mean_squared_logarithmic_error: 2.3503 - cosine_similarity: 0.0094 - sparseLoss: 40.7556 - totalLoss: 111.8388 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 40.4677 - val_accuracy: 0.0030 - val_mean_squared_error: 14.5858 - val_mean_absolute_error: 3.5665 - val_mean_absolute_percentage_error: 3557295104.0000 - val_mean_squared_logarithmic_error: 2.2607 - val_cosine_similarity: 0.0094 - val_sparseLoss: 40.4677 - val_totalLoss: 97.6560 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 17/30
# 132/132 [==============================] - 4s 27ms/step - loss: 39.5012 - accuracy: 0.0025 - mean_squared_error: 15.0371 - mean_absolute_error: 3.5969 - mean_absolute_percentage_error: 3589550592.0000 - mean_squared_logarithmic_error: 2.2772 - cosine_similarity: 0.0095 - sparseLoss: 39.5012 - totalLoss: 102.4594 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 40.0194 - val_accuracy: 0.0013 - val_mean_squared_error: 16.1669 - val_mean_absolute_error: 3.7323 - val_mean_absolute_percentage_error: 3723412736.0000 - val_mean_squared_logarithmic_error: 2.3624 - val_cosine_similarity: 0.0093 - val_sparseLoss: 40.0194 - val_totalLoss: 111.6969 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 18/30
# 132/132 [==============================] - 4s 29ms/step - loss: 36.3076 - accuracy: 0.0019 - mean_squared_error: 13.9444 - mean_absolute_error: 3.4492 - mean_absolute_percentage_error: 3441916416.0000 - mean_squared_logarithmic_error: 2.1797 - cosine_similarity: 0.0100 - sparseLoss: 36.3076 - totalLoss: 92.7780 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 39.3996 - val_accuracy: 0.0013 - val_mean_squared_error: 16.0507 - val_mean_absolute_error: 3.6949 - val_mean_absolute_percentage_error: 3685725696.0000 - val_mean_squared_logarithmic_error: 2.3349 - val_cosine_similarity: 0.0093 - val_sparseLoss: 39.3996 - val_totalLoss: 102.3821 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 19/30
# 132/132 [==============================] - 3s 26ms/step - loss: 30.4608 - accuracy: 0.0026 - mean_squared_error: 13.1137 - mean_absolute_error: 3.2537 - mean_absolute_percentage_error: 3247338240.0000 - mean_squared_logarithmic_error: 2.0382 - cosine_similarity: 0.0108 - sparseLoss: 30.4608 - totalLoss: 80.1981 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 35.8090 - val_accuracy: 0.0046 - val_mean_squared_error: 13.5040 - val_mean_absolute_error: 3.2253 - val_mean_absolute_percentage_error: 3216237824.0000 - val_mean_squared_logarithmic_error: 2.0073 - val_cosine_similarity: 0.0103 - val_sparseLoss: 35.8090 - val_totalLoss: 90.1386 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 20/30
# 132/132 [==============================] - 4s 27ms/step - loss: 23.6217 - accuracy: 0.0096 - mean_squared_error: 10.5481 - mean_absolute_error: 2.7865 - mean_absolute_percentage_error: 2780964864.0000 - mean_squared_logarithmic_error: 1.7158 - cosine_similarity: 0.0119 - sparseLoss: 23.6217 - totalLoss: 59.9353 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 36.1772 - val_accuracy: 0.0182 - val_mean_squared_error: 9.2667 - val_mean_absolute_error: 2.4975 - val_mean_absolute_percentage_error: 2487295232.0000 - val_mean_squared_logarithmic_error: 1.5104 - val_cosine_similarity: 0.0108 - val_sparseLoss: 36.1772 - val_totalLoss: 89.7997 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 21/30
# 132/132 [==============================] - 4s 27ms/step - loss: 19.6016 - accuracy: 0.0614 - mean_squared_error: 8.1089 - mean_absolute_error: 2.2921 - mean_absolute_percentage_error: 2286984704.0000 - mean_squared_logarithmic_error: 1.3790 - cosine_similarity: 0.0128 - sparseLoss: 19.6016 - totalLoss: 43.3001 - meanDistanceFromRecoToTrue: 339.4130 - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 30.9777 - val_accuracy: 0.0460 - val_mean_squared_error: 8.0473 - val_mean_absolute_error: 2.1864 - val_mean_absolute_percentage_error: 2177346816.0000 - val_mean_squared_logarithmic_error: 1.2927 - val_cosine_similarity: 0.0123 - val_sparseLoss: 30.9777 - val_totalLoss: 68.5500 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 22/30
# 132/132 [==============================] - 4s 27ms/step - loss: 16.9813 - accuracy: 0.0925 - mean_squared_error: 6.6664 - mean_absolute_error: 2.0015 - mean_absolute_percentage_error: 1996628736.0000 - mean_squared_logarithmic_error: 1.1816 - cosine_similarity: 0.0135 - sparseLoss: 16.9813 - totalLoss: 33.8215 - meanDistanceFromRecoToTrue: 261.4720 - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 30.2180 - val_accuracy: 0.1210 - val_mean_squared_error: 6.4953 - val_mean_absolute_error: 1.8813 - val_mean_absolute_percentage_error: 1872082176.0000 - val_mean_squared_logarithmic_error: 1.0924 - val_cosine_similarity: 0.0128 - val_sparseLoss: 30.2180 - val_totalLoss: 71.9987 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 23/30
# 132/132 [==============================] - 4s 27ms/step - loss: 14.4329 - accuracy: 0.1647 - mean_squared_error: 5.4365 - mean_absolute_error: 1.7270 - mean_absolute_percentage_error: 1722549504.0000 - mean_squared_logarithmic_error: 0.9991 - cosine_similarity: 0.0142 - sparseLoss: 14.4329 - totalLoss: 30.9021 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 33.7286 - val_accuracy: 0.2302 - val_mean_squared_error: 5.0491 - val_mean_absolute_error: 1.5422 - val_mean_absolute_percentage_error: 1531801472.0000 - val_mean_squared_logarithmic_error: 0.8712 - val_cosine_similarity: 0.0132 - val_sparseLoss: 33.7286 - val_totalLoss: 74.5275 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.5789
# Epoch 24/30
# 132/132 [==============================] - 4s 27ms/step - loss: 13.4872 - accuracy: 0.2072 - mean_squared_error: 4.9423 - mean_absolute_error: 1.5961 - mean_absolute_percentage_error: 1591719168.0000 - mean_squared_logarithmic_error: 0.9136 - cosine_similarity: 0.0145 - sparseLoss: 13.4872 - totalLoss: 28.0072 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 34.4000 - val_accuracy: 0.3097 - val_mean_squared_error: 5.4391 - val_mean_absolute_error: 1.4738 - val_mean_absolute_percentage_error: 1463183744.0000 - val_mean_squared_logarithmic_error: 0.8273 - val_cosine_similarity: 0.0137 - val_sparseLoss: 34.4000 - val_totalLoss: 64.9018 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 1.1579
# Epoch 25/30
# 132/132 [==============================] - 4s 27ms/step - loss: 12.9288 - accuracy: 0.2711 - mean_squared_error: 4.0812 - mean_absolute_error: 1.3925 - mean_absolute_percentage_error: 1387975424.0000 - mean_squared_logarithmic_error: 0.7807 - cosine_similarity: 0.0149 - sparseLoss: 12.9288 - totalLoss: 26.2782 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 32.5179 - val_accuracy: 0.3199 - val_mean_squared_error: 4.6267 - val_mean_absolute_error: 1.3718 - val_mean_absolute_percentage_error: 1361421696.0000 - val_mean_squared_logarithmic_error: 0.7640 - val_cosine_similarity: 0.0138 - val_sparseLoss: 32.5179 - val_totalLoss: 63.5566 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 1.7368
# Epoch 26/30
# 132/132 [==============================] - 4s 27ms/step - loss: 11.6462 - accuracy: 0.3039 - mean_squared_error: 3.8964 - mean_absolute_error: 1.3315 - mean_absolute_percentage_error: 1327352704.0000 - mean_squared_logarithmic_error: 0.7428 - cosine_similarity: 0.0151 - sparseLoss: 11.6462 - totalLoss: 24.7295 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 32.6511 - val_accuracy: 0.3936 - val_mean_squared_error: 3.5776 - val_mean_absolute_error: 1.1455 - val_mean_absolute_percentage_error: 1134913152.0000 - val_mean_squared_logarithmic_error: 0.6218 - val_cosine_similarity: 0.0143 - val_sparseLoss: 32.6511 - val_totalLoss: 64.4248 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 2.9493
# Epoch 27/30
# 132/132 [==============================] - 4s 27ms/step - loss: 11.3561 - accuracy: 0.3413 - mean_squared_error: 3.5781 - mean_absolute_error: 1.2343 - mean_absolute_percentage_error: 1230074240.0000 - mean_squared_logarithmic_error: 0.6820 - cosine_similarity: 0.0154 - sparseLoss: 11.3561 - totalLoss: 21.7735 - meanDistanceFromRecoToTrue: 167.9507 - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 33.0496 - val_accuracy: 0.4479 - val_mean_squared_error: 2.7466 - val_mean_absolute_error: 0.9856 - val_mean_absolute_percentage_error: 974789440.0000 - val_mean_squared_logarithmic_error: 0.5247 - val_cosine_similarity: 0.0143 - val_sparseLoss: 33.0496 - val_totalLoss: 72.8300 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 2.4757
# Epoch 28/30
# 132/132 [==============================] - 4s 27ms/step - loss: 11.3405 - accuracy: 0.3951 - mean_squared_error: 3.3263 - mean_absolute_error: 1.1433 - mean_absolute_percentage_error: 1138940160.0000 - mean_squared_logarithmic_error: 0.6294 - cosine_similarity: 0.0155 - sparseLoss: 11.3405 - totalLoss: 21.4015 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 37.1989 - val_accuracy: 0.4661 - val_mean_squared_error: 4.9134 - val_mean_absolute_error: 1.2281 - val_mean_absolute_percentage_error: 1216725760.0000 - val_mean_squared_logarithmic_error: 0.6874 - val_cosine_similarity: 0.0142 - val_sparseLoss: 37.1989 - val_totalLoss: 68.4924 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 4.9911
# Epoch 29/30
# 132/132 [==============================] - 4s 27ms/step - loss: 10.1275 - accuracy: 0.4282 - mean_squared_error: 3.2110 - mean_absolute_error: 1.0884 - mean_absolute_percentage_error: 1084509056.0000 - mean_squared_logarithmic_error: 0.5978 - cosine_similarity: 0.0156 - sparseLoss: 10.1275 - totalLoss: 19.8921 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 29.7608 - val_accuracy: 0.5125 - val_mean_squared_error: 2.9322 - val_mean_absolute_error: 0.9349 - val_mean_absolute_percentage_error: 925134272.0000 - val_mean_squared_logarithmic_error: 0.5076 - val_cosine_similarity: 0.0149 - val_sparseLoss: 29.7608 - val_totalLoss: 61.7924 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 8.4703
# Epoch 30/30
# 132/132 [==============================] - 4s 27ms/step - loss: 8.9209 - accuracy: 0.4792 - mean_squared_error: 2.7931 - mean_absolute_error: 0.9741 - mean_absolute_percentage_error: 970447488.0000 - mean_squared_logarithmic_error: 0.5289 - cosine_similarity: 0.0161 - sparseLoss: 8.9209 - totalLoss: 18.2406 - meanDistanceFromRecoToTrue: 147.1077 - meanDistanceFromTrueToReco: 0.0482 - val_loss: 34.8777 - val_accuracy: 0.5618 - val_mean_squared_error: 2.8015 - val_mean_absolute_error: 0.8622 - val_mean_absolute_percentage_error: 851106560.0000 - val_mean_squared_logarithmic_error: 0.4654 - val_cosine_similarity: 0.0146 - val_sparseLoss: 34.8777 - val_totalLoss: 64.0889 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 10.6863
# 1it [01:48, 108.31s/it]
# Epoch 1/30
# 132/132 [==============================] - 4s 27ms/step - loss: 12.5334 - accuracy: 0.4144 - mean_squared_error: 3.3094 - mean_absolute_error: 1.1030 - mean_absolute_percentage_error: 1098493568.0000 - mean_squared_logarithmic_error: 0.6026 - cosine_similarity: 0.0157 - sparseLoss: 12.5334 - totalLoss: 25.3150 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.7121 - val_loss: 14.3380 - val_accuracy: 0.4622 - val_mean_squared_error: 2.9525 - val_mean_absolute_error: 0.9958 - val_mean_absolute_percentage_error: 989992000.0000 - val_mean_squared_logarithmic_error: 0.5276 - val_cosine_similarity: 0.0148 - val_sparseLoss: 14.3380 - val_totalLoss: 23.8769 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 2/30
# 132/132 [==============================] - 4s 27ms/step - loss: 10.9150 - accuracy: 0.4033 - mean_squared_error: 3.2713 - mean_absolute_error: 1.1238 - mean_absolute_percentage_error: 1119688320.0000 - mean_squared_logarithmic_error: 0.6156 - cosine_similarity: 0.0158 - sparseLoss: 10.9150 - totalLoss: 21.5391 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.1447 - val_loss: 15.5069 - val_accuracy: 0.5831 - val_mean_squared_error: 2.3641 - val_mean_absolute_error: 0.7920 - val_mean_absolute_percentage_error: 785559296.0000 - val_mean_squared_logarithmic_error: 0.4169 - val_cosine_similarity: 0.0153 - val_sparseLoss: 15.5069 - val_totalLoss: 25.0250 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 3/30
# 132/132 [==============================] - 4s 27ms/step - loss: 10.4671 - accuracy: 0.4605 - mean_squared_error: 3.0455 - mean_absolute_error: 1.0249 - mean_absolute_percentage_error: 1020738048.0000 - mean_squared_logarithmic_error: 0.5575 - cosine_similarity: 0.0160 - sparseLoss: 10.4671 - totalLoss: 21.7899 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0899 - val_loss: 17.5311 - val_accuracy: 0.5632 - val_mean_squared_error: 2.8650 - val_mean_absolute_error: 0.8733 - val_mean_absolute_percentage_error: 866244608.0000 - val_mean_squared_logarithmic_error: 0.4672 - val_cosine_similarity: 0.0151 - val_sparseLoss: 17.5311 - val_totalLoss: 26.6592 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 4/30
# 132/132 [==============================] - 4s 27ms/step - loss: 9.2783 - accuracy: 0.5214 - mean_squared_error: 2.6771 - mean_absolute_error: 0.9098 - mean_absolute_percentage_error: 905870784.0000 - mean_squared_logarithmic_error: 0.4914 - cosine_similarity: 0.0163 - sparseLoss: 9.2783 - totalLoss: 19.0955 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0482 - val_loss: 12.3635 - val_accuracy: 0.5418 - val_mean_squared_error: 2.6390 - val_mean_absolute_error: 0.8683 - val_mean_absolute_percentage_error: 862732800.0000 - val_mean_squared_logarithmic_error: 0.4629 - val_cosine_similarity: 0.0152 - val_sparseLoss: 12.3635 - val_totalLoss: 20.5707 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 5/30
# 132/132 [==============================] - 4s 27ms/step - loss: 9.8006 - accuracy: 0.5503 - mean_squared_error: 2.5429 - mean_absolute_error: 0.8567 - mean_absolute_percentage_error: 852491968.0000 - mean_squared_logarithmic_error: 0.4605 - cosine_similarity: 0.0166 - sparseLoss: 9.8006 - totalLoss: 18.5871 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0482 - val_loss: 16.2678 - val_accuracy: 0.6246 - val_mean_squared_error: 2.2849 - val_mean_absolute_error: 0.7306 - val_mean_absolute_percentage_error: 723821376.0000 - val_mean_squared_logarithmic_error: 0.3836 - val_cosine_similarity: 0.0154 - val_sparseLoss: 16.2678 - val_totalLoss: 24.9385 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 6/30
# 132/132 [==============================] - 4s 27ms/step - loss: 9.2888 - accuracy: 0.5575 - mean_squared_error: 2.5667 - mean_absolute_error: 0.8579 - mean_absolute_percentage_error: 853792448.0000 - mean_squared_logarithmic_error: 0.4631 - cosine_similarity: 0.0165 - sparseLoss: 9.2888 - totalLoss: 19.2018 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 11.8832 - val_accuracy: 0.6099 - val_mean_squared_error: 2.3226 - val_mean_absolute_error: 0.7572 - val_mean_absolute_percentage_error: 751687040.0000 - val_mean_squared_logarithmic_error: 0.4007 - val_cosine_similarity: 0.0153 - val_sparseLoss: 11.8832 - val_totalLoss: 23.0835 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 7/30
# 132/132 [==============================] - 4s 27ms/step - loss: 8.4983 - accuracy: 0.5993 - mean_squared_error: 2.3862 - mean_absolute_error: 0.7822 - mean_absolute_percentage_error: 778378368.0000 - mean_squared_logarithmic_error: 0.4203 - cosine_similarity: 0.0167 - sparseLoss: 8.4983 - totalLoss: 17.0996 - meanDistanceFromRecoToTrue: 141.0149 - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 14.7721 - val_accuracy: 0.6611 - val_mean_squared_error: 2.3055 - val_mean_absolute_error: 0.6910 - val_mean_absolute_percentage_error: 684716096.0000 - val_mean_squared_logarithmic_error: 0.3703 - val_cosine_similarity: 0.0156 - val_sparseLoss: 14.7721 - val_totalLoss: 23.3209 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 8/30
# 132/132 [==============================] - 4s 27ms/step - loss: 8.1879 - accuracy: 0.6559 - mean_squared_error: 2.1248 - mean_absolute_error: 0.6843 - mean_absolute_percentage_error: 680555840.0000 - mean_squared_logarithmic_error: 0.3676 - cosine_similarity: 0.0170 - sparseLoss: 8.1879 - totalLoss: 18.0885 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 11.6074 - val_accuracy: 0.6311 - val_mean_squared_error: 2.2575 - val_mean_absolute_error: 0.7206 - val_mean_absolute_percentage_error: 715192640.0000 - val_mean_squared_logarithmic_error: 0.3818 - val_cosine_similarity: 0.0154 - val_sparseLoss: 11.6074 - val_totalLoss: 20.8805 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 9/30
# 132/132 [==============================] - 4s 27ms/step - loss: 7.4912 - accuracy: 0.6292 - mean_squared_error: 2.2589 - mean_absolute_error: 0.7333 - mean_absolute_percentage_error: 729840576.0000 - mean_squared_logarithmic_error: 0.3950 - cosine_similarity: 0.0169 - sparseLoss: 7.4912 - totalLoss: 16.1992 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 16.3338 - val_accuracy: 0.6595 - val_mean_squared_error: 2.6218 - val_mean_absolute_error: 0.7249 - val_mean_absolute_percentage_error: 718053568.0000 - val_mean_squared_logarithmic_error: 0.3919 - val_cosine_similarity: 0.0155 - val_sparseLoss: 16.3338 - val_totalLoss: 26.0292 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 10/30
# 132/132 [==============================] - 4s 27ms/step - loss: 7.9520 - accuracy: 0.6988 - mean_squared_error: 2.0357 - mean_absolute_error: 0.6196 - mean_absolute_percentage_error: 615736896.0000 - mean_squared_logarithmic_error: 0.3349 - cosine_similarity: 0.0172 - sparseLoss: 7.9520 - totalLoss: 16.9157 - meanDistanceFromRecoToTrue: 153.6053 - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 16.2304 - val_accuracy: 0.7074 - val_mean_squared_error: 2.2144 - val_mean_absolute_error: 0.6193 - val_mean_absolute_percentage_error: 612598336.0000 - val_mean_squared_logarithmic_error: 0.3329 - val_cosine_similarity: 0.0159 - val_sparseLoss: 16.2304 - val_totalLoss: 26.1712 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 11/30
# 132/132 [==============================] - 4s 27ms/step - loss: 7.9392 - accuracy: 0.6955 - mean_squared_error: 2.0043 - mean_absolute_error: 0.6207 - mean_absolute_percentage_error: 616841216.0000 - mean_squared_logarithmic_error: 0.3337 - cosine_similarity: 0.0171 - sparseLoss: 7.9392 - totalLoss: 16.3518 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 16.0682 - val_accuracy: 0.6990 - val_mean_squared_error: 2.2093 - val_mean_absolute_error: 0.6317 - val_mean_absolute_percentage_error: 624933888.0000 - val_mean_squared_logarithmic_error: 0.3397 - val_cosine_similarity: 0.0157 - val_sparseLoss: 16.0682 - val_totalLoss: 28.3191 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 12/30
# 132/132 [==============================] - 4s 27ms/step - loss: 7.2963 - accuracy: 0.7008 - mean_squared_error: 2.0095 - mean_absolute_error: 0.6150 - mean_absolute_percentage_error: 611498112.0000 - mean_squared_logarithmic_error: 0.3318 - cosine_similarity: 0.0171 - sparseLoss: 7.2963 - totalLoss: 16.9310 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 15.3310 - val_accuracy: 0.7326 - val_mean_squared_error: 1.7700 - val_mean_absolute_error: 0.5406 - val_mean_absolute_percentage_error: 534184416.0000 - val_mean_squared_logarithmic_error: 0.2848 - val_cosine_similarity: 0.0157 - val_sparseLoss: 15.3310 - val_totalLoss: 26.0878 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 13/30
# 132/132 [==============================] - 4s 27ms/step - loss: 7.1730 - accuracy: 0.6817 - mean_squared_error: 2.0011 - mean_absolute_error: 0.6337 - mean_absolute_percentage_error: 630152576.0000 - mean_squared_logarithmic_error: 0.3392 - cosine_similarity: 0.0170 - sparseLoss: 7.1730 - totalLoss: 15.8373 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 15.0505 - val_accuracy: 0.7351 - val_mean_squared_error: 1.9825 - val_mean_absolute_error: 0.5558 - val_mean_absolute_percentage_error: 549343040.0000 - val_mean_squared_logarithmic_error: 0.2977 - val_cosine_similarity: 0.0159 - val_sparseLoss: 15.0505 - val_totalLoss: 24.4902 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 14/30
# 132/132 [==============================] - 4s 28ms/step - loss: 7.5286 - accuracy: 0.7233 - mean_squared_error: 1.8735 - mean_absolute_error: 0.5712 - mean_absolute_percentage_error: 567452864.0000 - mean_squared_logarithmic_error: 0.3075 - cosine_similarity: 0.0172 - sparseLoss: 7.5286 - totalLoss: 16.3085 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 16.2539 - val_accuracy: 0.7309 - val_mean_squared_error: 1.9078 - val_mean_absolute_error: 0.5547 - val_mean_absolute_percentage_error: 547894912.0000 - val_mean_squared_logarithmic_error: 0.2949 - val_cosine_similarity: 0.0158 - val_sparseLoss: 16.2539 - val_totalLoss: 26.5106 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 15/30
# 132/132 [==============================] - 4s 27ms/step - loss: 7.6521 - accuracy: 0.7287 - mean_squared_error: 1.9047 - mean_absolute_error: 0.5653 - mean_absolute_percentage_error: 561427648.0000 - mean_squared_logarithmic_error: 0.3039 - cosine_similarity: 0.0171 - sparseLoss: 7.6521 - totalLoss: 15.8341 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 17.7906 - val_accuracy: 0.7237 - val_mean_squared_error: 2.2665 - val_mean_absolute_error: 0.6003 - val_mean_absolute_percentage_error: 593124096.0000 - val_mean_squared_logarithmic_error: 0.3251 - val_cosine_similarity: 0.0156 - val_sparseLoss: 17.7906 - val_totalLoss: 27.4662 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 16/30
# 132/132 [==============================] - 4s 27ms/step - loss: 7.1802 - accuracy: 0.7341 - mean_squared_error: 1.8312 - mean_absolute_error: 0.5521 - mean_absolute_percentage_error: 548393600.0000 - mean_squared_logarithmic_error: 0.2976 - cosine_similarity: 0.0172 - sparseLoss: 7.1802 - totalLoss: 14.5127 - meanDistanceFromRecoToTrue: 121.7651 - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 16.6273 - val_accuracy: 0.7640 - val_mean_squared_error: 1.7577 - val_mean_absolute_error: 0.4967 - val_mean_absolute_percentage_error: 489914752.0000 - val_mean_squared_logarithmic_error: 0.2659 - val_cosine_similarity: 0.0159 - val_sparseLoss: 16.6273 - val_totalLoss: 26.4392 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.3261
# Epoch 17/30
# 132/132 [==============================] - 4s 27ms/step - loss: 6.8821 - accuracy: 0.7542 - mean_squared_error: 1.7798 - mean_absolute_error: 0.5204 - mean_absolute_percentage_error: 516908256.0000 - mean_squared_logarithmic_error: 0.2814 - cosine_similarity: 0.0173 - sparseLoss: 6.8821 - totalLoss: 14.7270 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 15.8247 - val_accuracy: 0.7263 - val_mean_squared_error: 2.1736 - val_mean_absolute_error: 0.5901 - val_mean_absolute_percentage_error: 583357056.0000 - val_mean_squared_logarithmic_error: 0.3199 - val_cosine_similarity: 0.0156 - val_sparseLoss: 15.8247 - val_totalLoss: 24.1248 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 18/30
# 132/132 [==============================] - 4s 27ms/step - loss: 6.6041 - accuracy: 0.7508 - mean_squared_error: 1.7689 - mean_absolute_error: 0.5212 - mean_absolute_percentage_error: 517771264.0000 - mean_squared_logarithmic_error: 0.2821 - cosine_similarity: 0.0173 - sparseLoss: 6.6041 - totalLoss: 13.2325 - meanDistanceFromRecoToTrue: 117.1454 - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 16.0956 - val_accuracy: 0.7570 - val_mean_squared_error: 1.9116 - val_mean_absolute_error: 0.5206 - val_mean_absolute_percentage_error: 513927168.0000 - val_mean_squared_logarithmic_error: 0.2813 - val_cosine_similarity: 0.0158 - val_sparseLoss: 16.0956 - val_totalLoss: 26.2144 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 19/30
# 132/132 [==============================] - 4s 27ms/step - loss: 6.4612 - accuracy: 0.7840 - mean_squared_error: 1.6451 - mean_absolute_error: 0.4665 - mean_absolute_percentage_error: 463093184.0000 - mean_squared_logarithmic_error: 0.2540 - cosine_similarity: 0.0175 - sparseLoss: 6.4612 - totalLoss: 13.6322 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 17.7440 - val_accuracy: 0.7473 - val_mean_squared_error: 2.1852 - val_mean_absolute_error: 0.5574 - val_mean_absolute_percentage_error: 550534400.0000 - val_mean_squared_logarithmic_error: 0.3033 - val_cosine_similarity: 0.0157 - val_sparseLoss: 17.7440 - val_totalLoss: 27.1207 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.1594
# Epoch 20/30
# 132/132 [==============================] - 4s 27ms/step - loss: 6.1786 - accuracy: 0.7876 - mean_squared_error: 1.6782 - mean_absolute_error: 0.4650 - mean_absolute_percentage_error: 461615552.0000 - mean_squared_logarithmic_error: 0.2530 - cosine_similarity: 0.0175 - sparseLoss: 6.1786 - totalLoss: 13.7239 - meanDistanceFromRecoToTrue: 116.8374 - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 18.5107 - val_accuracy: 0.8154 - val_mean_squared_error: 1.5004 - val_mean_absolute_error: 0.4011 - val_mean_absolute_percentage_error: 393964288.0000 - val_mean_squared_logarithmic_error: 0.2160 - val_cosine_similarity: 0.0160 - val_sparseLoss: 18.5107 - val_totalLoss: 27.9096 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.6522
# Epoch 21/30
# 132/132 [==============================] - 4s 27ms/step - loss: 6.2993 - accuracy: 0.7745 - mean_squared_error: 1.6565 - mean_absolute_error: 0.4781 - mean_absolute_percentage_error: 474779776.0000 - mean_squared_logarithmic_error: 0.2590 - cosine_similarity: 0.0174 - sparseLoss: 6.2993 - totalLoss: 13.4627 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 15.2058 - val_accuracy: 0.7489 - val_mean_squared_error: 2.1319 - val_mean_absolute_error: 0.5491 - val_mean_absolute_percentage_error: 542588032.0000 - val_mean_squared_logarithmic_error: 0.2980 - val_cosine_similarity: 0.0156 - val_sparseLoss: 15.2058 - val_totalLoss: 24.7311 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 22/30
# 132/132 [==============================] - 4s 28ms/step - loss: 6.2919 - accuracy: 0.7970 - mean_squared_error: 1.6145 - mean_absolute_error: 0.4452 - mean_absolute_percentage_error: 441806880.0000 - mean_squared_logarithmic_error: 0.2430 - cosine_similarity: 0.0176 - sparseLoss: 6.2919 - totalLoss: 12.9427 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 15.8650 - val_accuracy: 0.7871 - val_mean_squared_error: 1.7507 - val_mean_absolute_error: 0.4621 - val_mean_absolute_percentage_error: 455653152.0000 - val_mean_squared_logarithmic_error: 0.2504 - val_cosine_similarity: 0.0157 - val_sparseLoss: 15.8650 - val_totalLoss: 25.5135 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.6449
# Epoch 23/30
# 132/132 [==============================] - 4s 27ms/step - loss: 6.0756 - accuracy: 0.7910 - mean_squared_error: 1.6400 - mean_absolute_error: 0.4560 - mean_absolute_percentage_error: 452678688.0000 - mean_squared_logarithmic_error: 0.2494 - cosine_similarity: 0.0175 - sparseLoss: 6.0756 - totalLoss: 12.9650 - meanDistanceFromRecoToTrue: 116.4292 - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 14.1570 - val_accuracy: 0.7829 - val_mean_squared_error: 1.7945 - val_mean_absolute_error: 0.4756 - val_mean_absolute_percentage_error: 469509120.0000 - val_mean_squared_logarithmic_error: 0.2587 - val_cosine_similarity: 0.0155 - val_sparseLoss: 14.1570 - val_totalLoss: 27.9760 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.6449
# Epoch 24/30
# 132/132 [==============================] - 4s 27ms/step - loss: 5.6708 - accuracy: 0.8088 - mean_squared_error: 1.6062 - mean_absolute_error: 0.4299 - mean_absolute_percentage_error: 426735648.0000 - mean_squared_logarithmic_error: 0.2366 - cosine_similarity: 0.0176 - sparseLoss: 5.6708 - totalLoss: 12.2562 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 19.6514 - val_accuracy: 0.8263 - val_mean_squared_error: 1.4755 - val_mean_absolute_error: 0.3846 - val_mean_absolute_percentage_error: 377064160.0000 - val_mean_squared_logarithmic_error: 0.2085 - val_cosine_similarity: 0.0157 - val_sparseLoss: 19.6514 - val_totalLoss: 30.9331 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 3.5430
# Epoch 25/30
# 132/132 [==============================] - 4s 27ms/step - loss: 5.7366 - accuracy: 0.8142 - mean_squared_error: 1.5718 - mean_absolute_error: 0.4183 - mean_absolute_percentage_error: 415079520.0000 - mean_squared_logarithmic_error: 0.2301 - cosine_similarity: 0.0175 - sparseLoss: 5.7366 - totalLoss: 13.1378 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 18.9638 - val_accuracy: 0.8216 - val_mean_squared_error: 1.6587 - val_mean_absolute_error: 0.4066 - val_mean_absolute_percentage_error: 399256320.0000 - val_mean_squared_logarithmic_error: 0.2216 - val_cosine_similarity: 0.0157 - val_sparseLoss: 18.9638 - val_totalLoss: 30.4916 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 2.6103
# Epoch 26/30
# 132/132 [==============================] - 4s 27ms/step - loss: 4.8712 - accuracy: 0.8403 - mean_squared_error: 1.4188 - mean_absolute_error: 0.3673 - mean_absolute_percentage_error: 364376192.0000 - mean_squared_logarithmic_error: 0.2028 - cosine_similarity: 0.0178 - sparseLoss: 4.8712 - totalLoss: 10.8470 - meanDistanceFromRecoToTrue: 108.5786 - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 19.0576 - val_accuracy: 0.8165 - val_mean_squared_error: 1.7883 - val_mean_absolute_error: 0.4270 - val_mean_absolute_percentage_error: 419733216.0000 - val_mean_squared_logarithmic_error: 0.2347 - val_cosine_similarity: 0.0158 - val_sparseLoss: 19.0576 - val_totalLoss: 32.5258 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 3.7494
# Epoch 27/30
# 132/132 [==============================] - 4s 27ms/step - loss: 5.2908 - accuracy: 0.8313 - mean_squared_error: 1.4592 - mean_absolute_error: 0.3836 - mean_absolute_percentage_error: 380627488.0000 - mean_squared_logarithmic_error: 0.2115 - cosine_similarity: 0.0179 - sparseLoss: 5.2908 - totalLoss: 11.7955 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 18.6124 - val_accuracy: 0.8242 - val_mean_squared_error: 1.6438 - val_mean_absolute_error: 0.4036 - val_mean_absolute_percentage_error: 396356928.0000 - val_mean_squared_logarithmic_error: 0.2206 - val_cosine_similarity: 0.0157 - val_sparseLoss: 18.6124 - val_totalLoss: 34.2374 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 3.6249
# Epoch 28/30
# 132/132 [==============================] - 4s 27ms/step - loss: 5.1133 - accuracy: 0.8339 - mean_squared_error: 1.4800 - mean_absolute_error: 0.3828 - mean_absolute_percentage_error: 379839936.0000 - mean_squared_logarithmic_error: 0.2118 - cosine_similarity: 0.0178 - sparseLoss: 5.1133 - totalLoss: 11.9314 - meanDistanceFromRecoToTrue: 112.2889 - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 20.1192 - val_accuracy: 0.8412 - val_mean_squared_error: 1.5758 - val_mean_absolute_error: 0.3723 - val_mean_absolute_percentage_error: 364821184.0000 - val_mean_squared_logarithmic_error: 0.2038 - val_cosine_similarity: 0.0158 - val_sparseLoss: 20.1192 - val_totalLoss: 36.2234 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 4.3670
# Epoch 29/30
# 132/132 [==============================] - 4s 27ms/step - loss: 5.6998 - accuracy: 0.8387 - mean_squared_error: 1.4643 - mean_absolute_error: 0.3749 - mean_absolute_percentage_error: 371637152.0000 - mean_squared_logarithmic_error: 0.2075 - cosine_similarity: 0.0178 - sparseLoss: 5.6998 - totalLoss: 12.8077 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 20.2279 - val_accuracy: 0.8398 - val_mean_squared_error: 1.5074 - val_mean_absolute_error: 0.3700 - val_mean_absolute_percentage_error: 362400416.0000 - val_mean_squared_logarithmic_error: 0.2026 - val_cosine_similarity: 0.0158 - val_sparseLoss: 20.2279 - val_totalLoss: 35.5499 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 5.7679
# Epoch 30/30
# 132/132 [==============================] - 4s 27ms/step - loss: 4.9901 - accuracy: 0.8306 - mean_squared_error: 1.4982 - mean_absolute_error: 0.3888 - mean_absolute_percentage_error: 385924320.0000 - mean_squared_logarithmic_error: 0.2155 - cosine_similarity: 0.0177 - sparseLoss: 4.9901 - totalLoss: 11.7450 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 16.3366 - val_accuracy: 0.8423 - val_mean_squared_error: 1.5011 - val_mean_absolute_error: 0.3657 - val_mean_absolute_percentage_error: 359071936.0000 - val_mean_squared_logarithmic_error: 0.2000 - val_cosine_similarity: 0.0160 - val_sparseLoss: 16.3366 - val_totalLoss: 32.5723 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 2.6032
# 2it [03:35, 107.63s/it]
# Epoch 1/30
# 132/132 [==============================] - 4s 27ms/step - loss: 7.6961 - accuracy: 0.7738 - mean_squared_error: 1.8205 - mean_absolute_error: 0.4956 - mean_absolute_percentage_error: 491837248.0000 - mean_squared_logarithmic_error: 0.2718 - cosine_similarity: 0.0170 - sparseLoss: 7.6961 - totalLoss: 17.0008 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.2485 - val_loss: 16.1635 - val_accuracy: 0.8313 - val_mean_squared_error: 1.3117 - val_mean_absolute_error: 0.3619 - val_mean_absolute_percentage_error: 354653120.0000 - val_mean_squared_logarithmic_error: 0.1931 - val_cosine_similarity: 0.0156 - val_sparseLoss: 16.1635 - val_totalLoss: 21.8682 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 2/30
# 132/132 [==============================] - 4s 27ms/step - loss: 5.6057 - accuracy: 0.7883 - mean_squared_error: 1.7337 - mean_absolute_error: 0.4709 - mean_absolute_percentage_error: 467890528.0000 - mean_squared_logarithmic_error: 0.2602 - cosine_similarity: 0.0171 - sparseLoss: 5.6057 - totalLoss: 12.7550 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 9.1421 - val_accuracy: 0.8563 - val_mean_squared_error: 1.2645 - val_mean_absolute_error: 0.3285 - val_mean_absolute_percentage_error: 323404928.0000 - val_mean_squared_logarithmic_error: 0.1801 - val_cosine_similarity: 0.0159 - val_sparseLoss: 9.1421 - val_totalLoss: 14.7920 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 3/30
# ...
# Epoch 11/30
# 132/132 [==============================] - 4s 28ms/step - loss: 2.3585 - accuracy: 0.9594 - mean_squared_error: 0.8394 - mean_absolute_error: 0.1489 - mean_absolute_percentage_error: 146921232.0000 - mean_squared_logarithmic_error: 0.0883 - cosine_similarity: 0.0193 - sparseLoss: 2.3585 - totalLoss: 6.9719 - meanDistanceFromRecoToTrue: 90.5219 - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 7.6683 - val_accuracy: 0.9657 - val_mean_squared_error: 0.7953 - val_mean_absolute_error: 0.1360 - val_mean_absolute_percentage_error: 131465800.0000 - val_mean_squared_logarithmic_error: 0.0794 - val_cosine_similarity: 0.0200 - val_sparseLoss: 7.6683 - val_totalLoss: 10.5254 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 12/30
# 132/132 [==============================] - 4s 31ms/step - loss: 2.6130 - accuracy: 0.9598 - mean_squared_error: 0.8375 - mean_absolute_error: 0.1477 - mean_absolute_percentage_error: 145540048.0000 - mean_squared_logarithmic_error: 0.0874 - cosine_similarity: 0.0192 - sparseLoss: 2.6130 - totalLoss: 7.4441 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 7.2196 - val_accuracy: 0.9672 - val_mean_squared_error: 0.7579 - val_mean_absolute_error: 0.1310 - val_mean_absolute_percentage_error: 126730456.0000 - val_mean_squared_logarithmic_error: 0.0768 - val_cosine_similarity: 0.0199 - val_sparseLoss: 7.2196 - val_totalLoss: 10.1211 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 13/30
# 132/132 [==============================] - 3s 26ms/step - loss: 2.5926 - accuracy: 0.9582 - mean_squared_error: 0.8465 - mean_absolute_error: 0.1519 - mean_absolute_percentage_error: 149761184.0000 - mean_squared_logarithmic_error: 0.0900 - cosine_similarity: 0.0192 - sparseLoss: 2.5926 - totalLoss: 6.9479 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 6.6368 - val_accuracy: 0.9647 - val_mean_squared_error: 0.8503 - val_mean_absolute_error: 0.1430 - val_mean_absolute_percentage_error: 138710256.0000 - val_mean_squared_logarithmic_error: 0.0837 - val_cosine_similarity: 0.0198 - val_sparseLoss: 6.6368 - val_totalLoss: 9.4286 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 14/30
# 132/132 [==============================] - 4s 27ms/step - loss: 2.4209 - accuracy: 0.9576 - mean_squared_error: 0.8606 - mean_absolute_error: 0.1537 - mean_absolute_percentage_error: 151732128.0000 - mean_squared_logarithmic_error: 0.0911 - cosine_similarity: 0.0191 - sparseLoss: 2.4209 - totalLoss: 6.7821 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 7.3776 - val_accuracy: 0.9674 - val_mean_squared_error: 0.7447 - val_mean_absolute_error: 0.1292 - val_mean_absolute_percentage_error: 124902896.0000 - val_mean_squared_logarithmic_error: 0.0757 - val_cosine_similarity: 0.0200 - val_sparseLoss: 7.3776 - val_totalLoss: 10.0506 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 15/30
# 132/132 [==============================] - 4s 27ms/step - loss: 2.1708 - accuracy: 0.9600 - mean_squared_error: 0.8077 - mean_absolute_error: 0.1446 - mean_absolute_percentage_error: 142700160.0000 - mean_squared_logarithmic_error: 0.0858 - cosine_similarity: 0.0194 - sparseLoss: 2.1708 - totalLoss: 6.5999 - meanDistanceFromRecoToTrue: 87.5557 - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 4.9305 - val_accuracy: 0.9675 - val_mean_squared_error: 0.7386 - val_mean_absolute_error: 0.1284 - val_mean_absolute_percentage_error: 125035952.0000 - val_mean_squared_logarithmic_error: 0.0758 - val_cosine_similarity: 0.0199 - val_sparseLoss: 4.9305 - val_totalLoss: 7.7626 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 16/30
# 132/132 [==============================] - 4s 27ms/step - loss: 2.5501 - accuracy: 0.9600 - mean_squared_error: 0.8320 - mean_absolute_error: 0.1468 - mean_absolute_percentage_error: 144670400.0000 - mean_squared_logarithmic_error: 0.0869 - cosine_similarity: 0.0194 - sparseLoss: 2.5501 - totalLoss: 7.1756 - meanDistanceFromRecoToTrue: 90.3659 - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 8.2410 - val_accuracy: 0.9677 - val_mean_squared_error: 0.7741 - val_mean_absolute_error: 0.1307 - val_mean_absolute_percentage_error: 126111360.0000 - val_mean_squared_logarithmic_error: 0.0764 - val_cosine_similarity: 0.0201 - val_sparseLoss: 8.2410 - val_totalLoss: 10.7723 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 17/30
# 132/132 [==============================] - 4s 27ms/step - loss: 2.3028 - accuracy: 0.9620 - mean_squared_error: 0.7843 - mean_absolute_error: 0.1395 - mean_absolute_percentage_error: 137580800.0000 - mean_squared_logarithmic_error: 0.0828 - cosine_similarity: 0.0195 - sparseLoss: 2.3028 - totalLoss: 6.3735 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 5.6844 - val_accuracy: 0.9687 - val_mean_squared_error: 0.7030 - val_mean_absolute_error: 0.1233 - val_mean_absolute_percentage_error: 119689104.0000 - val_mean_squared_logarithmic_error: 0.0727 - val_cosine_similarity: 0.0201 - val_sparseLoss: 5.6844 - val_totalLoss: 8.4112 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 18/30
# 132/132 [==============================] - 3s 26ms/step - loss: 2.3570 - accuracy: 0.9614 - mean_squared_error: 0.8081 - mean_absolute_error: 0.1425 - mean_absolute_percentage_error: 140469920.0000 - mean_squared_logarithmic_error: 0.0845 - cosine_similarity: 0.0194 - sparseLoss: 2.3570 - totalLoss: 6.8520 - meanDistanceFromRecoToTrue: 90.8067 - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 6.1348 - val_accuracy: 0.9660 - val_mean_squared_error: 0.7817 - val_mean_absolute_error: 0.1348 - val_mean_absolute_percentage_error: 130934592.0000 - val_mean_squared_logarithmic_error: 0.0793 - val_cosine_similarity: 0.0198 - val_sparseLoss: 6.1348 - val_totalLoss: 8.8309 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 19/30
# 132/132 [==============================] - 3s 26ms/step - loss: 2.0505 - accuracy: 0.9620 - mean_squared_error: 0.7946 - mean_absolute_error: 0.1407 - mean_absolute_percentage_error: 138926304.0000 - mean_squared_logarithmic_error: 0.0837 - cosine_similarity: 0.0195 - sparseLoss: 2.0505 - totalLoss: 6.1112 - meanDistanceFromRecoToTrue: 86.7665 - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 5.9029 - val_accuracy: 0.9695 - val_mean_squared_error: 0.7247 - val_mean_absolute_error: 0.1236 - val_mean_absolute_percentage_error: 119837280.0000 - val_mean_squared_logarithmic_error: 0.0728 - val_cosine_similarity: 0.0202 - val_sparseLoss: 5.9029 - val_totalLoss: 8.4152 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 20/30
# 132/132 [==============================] - 4s 27ms/step - loss: 2.1085 - accuracy: 0.9638 - mean_squared_error: 0.7619 - mean_absolute_error: 0.1340 - mean_absolute_percentage_error: 132189544.0000 - mean_squared_logarithmic_error: 0.0795 - cosine_similarity: 0.0197 - sparseLoss: 2.1085 - totalLoss: 6.0877 - meanDistanceFromRecoToTrue: 84.5343 - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 7.2933 - val_accuracy: 0.9727 - val_mean_squared_error: 0.6600 - val_mean_absolute_error: 0.1123 - val_mean_absolute_percentage_error: 108110024.0000 - val_mean_squared_logarithmic_error: 0.0658 - val_cosine_similarity: 0.0208 - val_sparseLoss: 7.2933 - val_totalLoss: 9.8203 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 21/30
# 132/132 [==============================] - 3s 26ms/step - loss: 2.5674 - accuracy: 0.9630 - mean_squared_error: 0.7958 - mean_absolute_error: 0.1386 - mean_absolute_percentage_error: 136483856.0000 - mean_squared_logarithmic_error: 0.0821 - cosine_similarity: 0.0197 - sparseLoss: 2.5674 - totalLoss: 6.7338 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 5.3189 - val_accuracy: 0.9663 - val_mean_squared_error: 0.7656 - val_mean_absolute_error: 0.1336 - val_mean_absolute_percentage_error: 130187976.0000 - val_mean_squared_logarithmic_error: 0.0791 - val_cosine_similarity: 0.0197 - val_sparseLoss: 5.3189 - val_totalLoss: 8.2968 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 22/30
# 132/132 [==============================] - 4s 27ms/step - loss: 2.2845 - accuracy: 0.9600 - mean_squared_error: 0.8269 - mean_absolute_error: 0.1466 - mean_absolute_percentage_error: 144707184.0000 - mean_squared_logarithmic_error: 0.0870 - cosine_similarity: 0.0193 - sparseLoss: 2.2845 - totalLoss: 6.6094 - meanDistanceFromRecoToTrue: 88.0312 - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 6.5896 - val_accuracy: 0.9696 - val_mean_squared_error: 0.7420 - val_mean_absolute_error: 0.1247 - val_mean_absolute_percentage_error: 120723720.0000 - val_mean_squared_logarithmic_error: 0.0732 - val_cosine_similarity: 0.0203 - val_sparseLoss: 6.5896 - val_totalLoss: 9.2418 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 23/30
# 132/132 [==============================] - 3s 26ms/step - loss: 2.3408 - accuracy: 0.9620 - mean_squared_error: 0.8092 - mean_absolute_error: 0.1419 - mean_absolute_percentage_error: 139957776.0000 - mean_squared_logarithmic_error: 0.0843 - cosine_similarity: 0.0195 - sparseLoss: 2.3408 - totalLoss: 6.9017 - meanDistanceFromRecoToTrue: 89.2274 - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 6.4319 - val_accuracy: 0.9707 - val_mean_squared_error: 0.7243 - val_mean_absolute_error: 0.1217 - val_mean_absolute_percentage_error: 117745752.0000 - val_mean_squared_logarithmic_error: 0.0715 - val_cosine_similarity: 0.0203 - val_sparseLoss: 6.4319 - val_totalLoss: 9.2786 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 24/30
# 132/132 [==============================] - 4s 27ms/step - loss: 2.2258 - accuracy: 0.9643 - mean_squared_error: 0.7636 - mean_absolute_error: 0.1338 - mean_absolute_percentage_error: 131834664.0000 - mean_squared_logarithmic_error: 0.0795 - cosine_similarity: 0.0197 - sparseLoss: 2.2258 - totalLoss: 6.4012 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 7.1551 - val_accuracy: 0.9708 - val_mean_squared_error: 0.7087 - val_mean_absolute_error: 0.1199 - val_mean_absolute_percentage_error: 115700432.0000 - val_mean_squared_logarithmic_error: 0.0703 - val_cosine_similarity: 0.0203 - val_sparseLoss: 7.1551 - val_totalLoss: 9.3796 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 25/30
# 132/132 [==============================] - 3s 27ms/step - loss: 2.0275 - accuracy: 0.9661 - mean_squared_error: 0.7361 - mean_absolute_error: 0.1283 - mean_absolute_percentage_error: 126444880.0000 - mean_squared_logarithmic_error: 0.0763 - cosine_similarity: 0.0197 - sparseLoss: 2.0275 - totalLoss: 5.8266 - meanDistanceFromRecoToTrue: 84.4791 - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 6.4617 - val_accuracy: 0.9720 - val_mean_squared_error: 0.6897 - val_mean_absolute_error: 0.1164 - val_mean_absolute_percentage_error: 112403136.0000 - val_mean_squared_logarithmic_error: 0.0684 - val_cosine_similarity: 0.0204 - val_sparseLoss: 6.4617 - val_totalLoss: 8.8299 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 26/30
# 132/132 [==============================] - 4s 27ms/step - loss: 1.8603 - accuracy: 0.9669 - mean_squared_error: 0.7359 - mean_absolute_error: 0.1269 - mean_absolute_percentage_error: 125237768.0000 - mean_squared_logarithmic_error: 0.0756 - cosine_similarity: 0.0197 - sparseLoss: 1.8603 - totalLoss: 5.5970 - meanDistanceFromRecoToTrue: 84.7542 - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 7.3534 - val_accuracy: 0.9728 - val_mean_squared_error: 0.7013 - val_mean_absolute_error: 0.1155 - val_mean_absolute_percentage_error: 111073800.0000 - val_mean_squared_logarithmic_error: 0.0674 - val_cosine_similarity: 0.0207 - val_sparseLoss: 7.3534 - val_totalLoss: 9.7571 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 27/30
# 132/132 [==============================] - 4s 27ms/step - loss: 1.9642 - accuracy: 0.9663 - mean_squared_error: 0.7254 - mean_absolute_error: 0.1264 - mean_absolute_percentage_error: 124617952.0000 - mean_squared_logarithmic_error: 0.0751 - cosine_similarity: 0.0199 - sparseLoss: 1.9642 - totalLoss: 6.0962 - meanDistanceFromRecoToTrue: 85.6862 - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 5.1765 - val_accuracy: 0.9712 - val_mean_squared_error: 0.7452 - val_mean_absolute_error: 0.1223 - val_mean_absolute_percentage_error: 118673152.0000 - val_mean_squared_logarithmic_error: 0.0719 - val_cosine_similarity: 0.0204 - val_sparseLoss: 5.1765 - val_totalLoss: 7.4257 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 28/30
# 132/132 [==============================] - 3s 26ms/step - loss: 2.2859 - accuracy: 0.9662 - mean_squared_error: 0.7499 - mean_absolute_error: 0.1299 - mean_absolute_percentage_error: 127877240.0000 - mean_squared_logarithmic_error: 0.0772 - cosine_similarity: 0.0198 - sparseLoss: 2.2859 - totalLoss: 6.2998 - meanDistanceFromRecoToTrue: nan - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 6.5650 - val_accuracy: 0.9713 - val_mean_squared_error: 0.7081 - val_mean_absolute_error: 0.1192 - val_mean_absolute_percentage_error: 115373536.0000 - val_mean_squared_logarithmic_error: 0.0702 - val_cosine_similarity: 0.0205 - val_sparseLoss: 6.5650 - val_totalLoss: 8.9390 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 29/30
# 132/132 [==============================] - 4s 27ms/step - loss: 2.2482 - accuracy: 0.9639 - mean_squared_error: 0.7745 - mean_absolute_error: 0.1358 - mean_absolute_percentage_error: 133796032.0000 - mean_squared_logarithmic_error: 0.0807 - cosine_similarity: 0.0196 - sparseLoss: 2.2482 - totalLoss: 6.2036 - meanDistanceFromRecoToTrue: 86.6188 - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 5.4005 - val_accuracy: 0.9721 - val_mean_squared_error: 0.6945 - val_mean_absolute_error: 0.1164 - val_mean_absolute_percentage_error: 112776256.0000 - val_mean_squared_logarithmic_error: 0.0686 - val_cosine_similarity: 0.0205 - val_sparseLoss: 5.4005 - val_totalLoss: 7.4550 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# Epoch 30/30
# 132/132 [==============================] - 4s 27ms/step - loss: 1.9479 - accuracy: 0.9663 - mean_squared_error: 0.7541 - mean_absolute_error: 0.1296 - mean_absolute_percentage_error: 127824392.0000 - mean_squared_logarithmic_error: 0.0771 - cosine_similarity: 0.0198 - sparseLoss: 1.9479 - totalLoss: 5.6866 - meanDistanceFromRecoToTrue: 87.2631 - meanDistanceFromTrueToReco: 0.0000e+00 - val_loss: 5.4992 - val_accuracy: 0.9712 - val_mean_squared_error: 0.7603 - val_mean_absolute_error: 0.1236 - val_mean_absolute_percentage_error: 119798696.0000 - val_mean_squared_logarithmic_error: 0.0726 - val_cosine_similarity: 0.0205 - val_sparseLoss: 5.4992 - val_totalLoss: 7.3537 - val_meanDistanceFromRecoToTrue: nan - val_meanDistanceFromTrueToReco: 0.0000e+00
# 5it [08:57, 107.44s/it]

# %%
# %matplotlib inline

fig, ax1 = plt.subplots(1, 1, figsize=(5, 5))
# ax2 = ax1.twinx()

total_loss = np.concatenate([history.history['loss'] for history in histories])
total_val_loss = np.concatenate([history.history['val_loss'] for history in histories])
total_mse = np.concatenate([history.history['mean_squared_error'] for history in histories])
total_val_mse = np.concatenate([history.history['val_mean_squared_error'] for history in histories])
total_mae = np.concatenate([history.history['mean_absolute_error'] for history in histories])
total_val_mae = np.concatenate([history.history['val_mean_absolute_error'] for history in histories])
total_msle = np.concatenate([history.history['mean_squared_logarithmic_error'] for history in histories])
total_val_msle = np.concatenate([history.history['val_mean_squared_logarithmic_error'] for history in histories])
total_cosine = np.concatenate([history.history['cosine_similarity'] for history in histories])
total_val_cosine = np.concatenate([history.history['val_cosine_similarity'] for history in histories])
total_sparseLoss = np.concatenate([history.history['sparseLoss'] for history in histories])
total_val_sparseLoss = np.concatenate([history.history['val_sparseLoss'] for history in histories])
total_totalLoss = np.concatenate([history.history['totalLoss'] for history in histories])
total_val_totalLoss = np.concatenate([history.history['val_totalLoss'] for history in histories])
total_meanDistanceFromRecoToTrue = np.concatenate([history.history['meanDistanceFromRecoToTrue'] for history in histories])
total_val_meanDistanceFromRecoToTrue = np.concatenate([history.history['val_meanDistanceFromRecoToTrue'] for history in histories])
total_meanDistanceFromTrueToReco = np.concatenate([history.history['meanDistanceFromTrueToReco'] for history in histories])
total_val_meanDistanceFromTrueToReco = np.concatenate([history.history['val_meanDistanceFromTrueToReco'] for history in histories])
nEpochs = [len(history.history['loss']) for history in histories]

maxY = max(np.max(total_loss), np.max(total_val_loss))

ax1.plot(total_sparseLoss, label='Training SL', color=twilight[5,:])
ax1.plot(total_val_sparseLoss, label='Validation SL', color=twilight[40-5,:])

ax1.plot(total_mse, label='Training MSE', color=twilight[7,:], linestyle='--')
ax1.plot(total_val_mse, label='Validation MSE', color=twilight[40-7,:] , linestyle='--')

ax1.plot(total_mae, label='Training MAE', color=twilight[9,:], linestyle='-.')
ax1.plot(total_val_mae, label='Validation MAE', color=twilight[40-9,:], linestyle='-.')

ax1.plot(total_msle, label='Training MSLE', color=twilight[11,:], linestyle=':')
ax1.plot(total_val_msle, label='Validation MSLE', color=twilight[40-11,:], linestyle=':')

# ax1.plot(total_cosine, label='Training Cosine', color=twilight[13,:], linestyle='-.')
# ax1.plot(total_val_cosine, label='Validation Cosine', color=twilight[40-13,:], linestyle='-.')

# ax1.plot(total_meanDistanceFromRecoToTrue, label=r'Training Reco $\to$ True', color=twilight[15,:], linestyle='--')
# ax1.plot(total_val_meanDistanceFromRecoToTrue, label=r'Validation Reco $\to$ True', color=twilight[40-15,:], linestyle='--')

# ax1.plot(total_meanDistanceFromTrueToReco, label=r'Training True $\to$ Reco', color=twilight[17,:], linestyle='-.')
# ax1.plot(total_val_meanDistanceFromTrueToReco, label=r'Validation True $\to$ Reco', color=twilight[40-17,:], linestyle='-.')

ax1.vlines(np.cumsum(nEpochs)-1, 0, maxY, color='k', linestyle=':', alpha=0.5)

# ax2.plot(history.history['accuracy'], label='Training Accuracy', color=twilight[9,:], linestyle=':')
# ax2.plot(history.history['val_accuracy'], label='Validation Accuracy', color=twilight[40-9,:], linestyle=':')
# ax1.plot([], [], label='Training Accuracy', color=twilight[9,:], linestyle=':')
# ax1.plot([], [], label='Validation Accuracy', color=twilight[40-9,:], linestyle=':')

ax1.set_xlabel('Epoch')

ax1.set_ylabel(r'Loss \& Error Metrics')
# ax2.set_ylabel('Accuracy Metrics')

ax1.set_yscale('log')
# ax2.set_yscale('log')

ax1.set_xlim(0, len(total_loss)-1)
# ax2.set_xlim(0, len(history.history['loss'])-1)
ax1.set_ylim(0, maxY)
# ax2.set_ylim(ymin=0, ymax=1)

ax1.grid()
# ax2.grid()

# ax1.set_title('Training history')
ax1.legend(bbox_to_anchor=(1.25, 1), loc='upper left')
plt.savefig('../figures/training.pdf', bbox_inches='tight')
plt.show()
# Out:
# /var/folders/mv/_50rblmd16xfrbsjpr4x2z0c0000gn/T/ipykernel_62470/4002263105.py:66: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax1.set_ylim(0, maxY)

# %%
saveModel = False
loadModel = False
saveHistory = False
loadHistory = False

# fileName = 'models/model_{}_{}.h5'.format(plotRecoName, {True:'withErrors', False:'noErrors'}[makeErrors])
fileName = 'models/model_200multievent_20x20x20_5kFold_30epochs_primaryLabels_updatedLabels.h5'
if saveModel:
    model.save(fileName)
    print('Saved model to', fileName)
if loadModel:
    meanDistanceToTrueFromReco = meanDistanceFromRecoToTrue
    meanDistanceToRecoFromTrue = meanDistanceFromTrueToReco
    # model = tf.keras.models.load_model(fileName, custom_objects={'sparseLoss': sparseLoss, 
    #                                                              'meanDistanceFromRecoToTrue': meanDistanceFromRecoToTrue,
    #                                                              'meanDistanceFromTrueToReco': meanDistanceFromTrueToReco})
    model = tf.keras.models.load_model(fileName, custom_objects={'sparseLoss': sparseLoss,
                                                                 'meanDistanceToTrueFromReco': meanDistanceToTrueFromReco,
                                                                 'meanDistanceToRecoFromTrue': meanDistanceToRecoFromTrue})
    print('Loaded model from', fileName)
if saveHistory:
    historiesSave = []
    for history in histories:
        historiesSave.append({key: history.history[key] for key in history.history.keys()})
    with open(fileName.split('.')[0]+'_history.pkl', 'wb') as file_pi:
        pkl.dump(historiesSave, file_pi)
if loadHistory:
    with open(fileName.split('.')[0]+'_history.pkl', 'rb') as file_pi:
        historiesLoad = pkl.load(file_pi)

# %%
nBins = 50
xmax = 200
# xmax = None
lw = 2
colors = [twilight[5,:], twilight[40-5,:], twilight[12,:], twilight[40-12,:]]
density = True
plots = [True, False]
epsInit = 15
optimize = True
minEntries = 15
deltaEps = 0.1

meanDistanceFromTrueToReco_test = []
meanDistanceFromRecoToTrue_test = []
meanDistanceFromTrueToReco_train = []
meanDistanceFromRecoToTrue_train = []
distancesFromTrueToReco_test = []
distancesFromRecoToTrue_test = []
distancesFromTrueToReco_train = []
distancesFromRecoToTrue_train = []

for i in tqdm.tqdm(range(len(X_test))):
    mean, distances = meanAndDistancesFromTrueToReco(Y_test[i], model.predict(X_test[i:i+1], verbose=0)[0], eps=epsInit, optimize=optimize, minEntries=minEntries, deltaEps=deltaEps)
    meanDistanceFromTrueToReco_test.append(mean)
    distancesFromTrueToReco_test.append(distances.numpy())

    mean, distances = meanAndDistancesFromRecoToTrue(Y_test[i], model.predict(X_test[i:i+1], verbose=0)[0], eps=epsInit, optimize=optimize, minEntries=minEntries, deltaEps=deltaEps)
    meanDistanceFromRecoToTrue_test.append(mean)
    distancesFromRecoToTrue_test.append(distances.numpy())
for i in tqdm.tqdm(range(len(X_train))):
    mean, distances = meanAndDistancesFromTrueToReco(Y_train[i], model.predict(X_train[i:i+1], verbose=0)[0], eps=epsInit, optimize=optimize, minEntries=minEntries, deltaEps=deltaEps)
    meanDistanceFromTrueToReco_train.append(mean)
    distancesFromTrueToReco_train.append(distances.numpy())

    mean, distances = meanAndDistancesFromRecoToTrue(Y_train[i], model.predict(X_train[i:i+1], verbose=0)[0], eps=epsInit, optimize=optimize, minEntries=minEntries, deltaEps=deltaEps)
    meanDistanceFromRecoToTrue_train.append(mean)
    distancesFromRecoToTrue_train.append(distances.numpy())

print(distancesFromRecoToTrue_test[0].shape)
print(distancesFromRecoToTrue_test[0])
print(distancesFromTrueToReco_test[0].shape)
print(distancesFromTrueToReco_test[0])

meanDistanceFromTrueToReco_test = np.array(meanDistanceFromTrueToReco_test)
meanDistanceFromRecoToTrue_test = np.array(meanDistanceFromRecoToTrue_test)
meanDistanceFromTrueToReco_train = np.array(meanDistanceFromTrueToReco_train)
meanDistanceFromRecoToTrue_train = np.array(meanDistanceFromRecoToTrue_train)

meanDistanceFromTrueToReco_test = meanDistanceFromTrueToReco_test[~np.isnan(meanDistanceFromTrueToReco_test)]
meanDistanceFromRecoToTrue_test = meanDistanceFromRecoToTrue_test[~np.isnan(meanDistanceFromRecoToTrue_test)]
meanDistanceFromTrueToReco_train = meanDistanceFromTrueToReco_train[~np.isnan(meanDistanceFromTrueToReco_train)]
meanDistanceFromRecoToTrue_train = meanDistanceFromRecoToTrue_train[~np.isnan(meanDistanceFromRecoToTrue_train)]

for i in range(len(distancesFromRecoToTrue_test)):
    distancesFromRecoToTrue_test[i] = distancesFromRecoToTrue_test[i][~np.isnan(distancesFromRecoToTrue_test[i])]
for i in range(len(distancesFromTrueToReco_test)):
    distancesFromTrueToReco_test[i] = distancesFromTrueToReco_test[i][~np.isnan(distancesFromTrueToReco_test[i])]
for i in range(len(distancesFromRecoToTrue_train)):
    distancesFromRecoToTrue_train[i] = distancesFromRecoToTrue_train[i][~np.isnan(distancesFromRecoToTrue_train[i])]
for i in range(len(distancesFromTrueToReco_train)):
    distancesFromTrueToReco_train[i] = distancesFromTrueToReco_train[i][~np.isnan(distancesFromTrueToReco_train[i])]

##################################################################################################################
##################################################################################################################
##################################################################################################################

if plots[0] and plots[1]:
    fig, ax = plt.subplots(1, 2, figsize=(11, 5))
elif plots[0] or plots[1]:
    fig, ax = plt.subplots(1, 1, figsize=(5, 5))
    ax = [ax, ax]

if plots[0]:
    if xmax is None:
        xmax = np.max([np.max(meanDistanceFromRecoToTrue_test), np.max(meanDistanceFromTrueToReco_test), np.max(meanDistanceFromTrueToReco_train), np.max(meanDistanceFromTrueToReco_train)])


    bins_TR_train, edges_TR_train, _ = ax[0].hist(meanDistanceFromTrueToReco_train, bins=nBins, range=(0, xmax), histtype='step', color=colors[2], linewidth=lw, density=density)
    bins_RT_train, edges_RT_train, _ = ax[0].hist(meanDistanceFromRecoToTrue_train, bins=nBins, range=(0, xmax), histtype='step', color=colors[3], linewidth=lw, density=density)
    bins_TR_test, edges_TR_test, _ = ax[0].hist(meanDistanceFromTrueToReco_test, bins=nBins, range=(0, xmax), histtype='step', color=colors[0], linewidth=lw, density=density)
    bins_RT_test, edges_RT_test, _ = ax[0].hist(meanDistanceFromRecoToTrue_test, bins=nBins, range=(0, xmax), histtype='step', color=colors[1], linewidth=lw, density=density)

    bins_TR_train_step = np.insert(bins_TR_train.repeat(2), [0, len(bins_TR_train)*2], 0)
    bins_RT_train_step = np.insert(bins_RT_train.repeat(2), [0, len(bins_RT_train)*2], 0)
    bins_TR_test_step = np.insert(bins_TR_test.repeat(2), [0, len(bins_TR_test)*2], 0)
    bins_RT_test_step = np.insert(bins_RT_test.repeat(2), [0, len(bins_RT_test)*2], 0)

    edges_TR_train_step = np.array(edges_TR_train).repeat(2)
    edges_RT_train_step = np.array(edges_RT_train).repeat(2)
    edges_TR_test_step = np.array(edges_TR_test).repeat(2)
    edges_RT_test_step = np.array(edges_RT_test).repeat(2)

    path_TR_train = Path(np.array([edges_TR_train_step, bins_TR_train_step]).T)
    path_RT_train = Path(np.array([edges_RT_train_step, bins_RT_train_step]).T)
    path_TR_test = Path(np.array([edges_TR_test_step, bins_TR_test_step]).T)
    path_RT_test = Path(np.array([edges_RT_test_step, bins_RT_test_step]).T)

    patch_TR_train = PathPatch(path_TR_train, facecolor='None', edgecolor=colors[2], alpha=1, hatch=r'\\', label=r'Train True $\to$ Reco')
    patch_RT_train = PathPatch(path_RT_train, facecolor='None', edgecolor=colors[3], alpha=1, hatch=r'\\', label=r'Train Reco $\to$ True')
    patch_TR_test = PathPatch(path_TR_test, facecolor='None', edgecolor=colors[0], alpha=1, hatch='//', label=r'Test True $\to$ Reco')
    patch_RT_test = PathPatch(path_RT_test, facecolor='None', edgecolor=colors[1], alpha=1, hatch='//', label=r'Test Reco $\to$ True')

    ax[0].add_patch(patch_TR_train)
    ax[0].add_patch(patch_RT_train)
    ax[0].add_patch(patch_TR_test)
    ax[0].add_patch(patch_RT_test)

    ax[0].set_yscale('log')
    ax[0].set_xlabel('Mean Distance [mm]')
    ax[0].set_ylabel('Density')
    ax[0].set_xlim(0, xmax)
    ax[0].legend()
    ax[0].grid()

##################################################################################################################
##################################################################################################################
##################################################################################################################

if plots[1]:
    if xmax is None:
        xmax = np.max([np.max(np.concatenate(distancesFromRecoToTrue_train)), np.max(np.concatenate(distancesFromTrueToReco_train)), np.max(np.concatenate(distancesFromRecoToTrue_test)), np.max(np.concatenate(distancesFromTrueToReco_test))])

    bins_TR_train, edges_TR_train, _ = ax[1].hist(np.concatenate(distancesFromTrueToReco_train), bins=nBins, range=(0, xmax), histtype='step', color=colors[2], linewidth=lw, density=density)
    bins_RT_train, edges_RT_train, _ = ax[1].hist(np.concatenate(distancesFromRecoToTrue_train), bins=nBins, range=(0, xmax), histtype='step', color=colors[3], linewidth=lw, density=density)
    bins_TR_test, edges_TR_test, _ = ax[1].hist(np.concatenate(distancesFromTrueToReco_test), bins=nBins, range=(0, xmax), histtype='step', color=colors[0], linewidth=lw, density=density)
    bins_RT_test, edges_RT_test, _ = ax[1].hist(np.concatenate(distancesFromRecoToTrue_test), bins=nBins, range=(0, xmax), histtype='step', color=colors[1], linewidth=lw, density=density)

    bins_TR_train_step = np.insert(bins_TR_train.repeat(2), [0, len(bins_TR_train)*2], 0)
    bins_RT_train_step = np.insert(bins_RT_train.repeat(2), [0, len(bins_RT_train)*2], 0)
    bins_TR_test_step = np.insert(bins_TR_test.repeat(2), [0, len(bins_TR_test)*2], 0)
    bins_RT_test_step = np.insert(bins_RT_test.repeat(2), [0, len(bins_RT_test)*2], 0)

    edges_TR_train_step = np.array(edges_TR_train).repeat(2)
    edges_RT_train_step = np.array(edges_RT_train).repeat(2)
    edges_TR_test_step = np.array(edges_TR_test).repeat(2)
    edges_RT_test_step = np.array(edges_RT_test).repeat(2)

    path_TR_train = Path(np.array([edges_TR_train_step, bins_TR_train_step]).T)
    path_RT_train = Path(np.array([edges_RT_train_step, bins_RT_train_step]).T)
    path_TR_test = Path(np.array([edges_TR_test_step, bins_TR_test_step]).T)
    path_RT_test = Path(np.array([edges_RT_test_step, bins_RT_test_step]).T)

    patch_TR_train = PathPatch(path_TR_train, facecolor='None', edgecolor=colors[2], alpha=1, hatch=r'\\', label=r'Train: True $\to$ Reco')
    patch_RT_train = PathPatch(path_RT_train, facecolor='None', edgecolor=colors[3], alpha=1, hatch=r'\\', label=r'Train: Reco $\to$ True')
    patch_TR_test = PathPatch(path_TR_test, facecolor='None', edgecolor=colors[0], alpha=1, hatch='//', label=r'Test: True $\to$ Reco')
    patch_RT_test = PathPatch(path_RT_test, facecolor='None', edgecolor=colors[1], alpha=1, hatch='//', label=r'Test: Reco $\to$ True')

    ax[1].add_patch(patch_TR_train)
    ax[1].add_patch(patch_RT_train)
    ax[1].add_patch(patch_TR_test)
    ax[1].add_patch(patch_RT_test)

    ax[1].set_yscale('log')
    ax[1].set_xlabel('Distance [mm]')
    ax[1].set_ylabel('Density')
    ax[1].set_xlim(0, xmax)
    ax[1].legend()
    ax[1].grid()

plt.savefig('../figures/meanDistances.pdf', bbox_inches='tight')
plt.show()
# Out:
# 100%|██████████| 20/20 [00:01<00:00, 11.86it/s]
# 100%|██████████| 165/165 [00:13<00:00, 12.43it/s]
# (7,)
# [  0.      121.        0.        0.      171.11984 121.      121.     ]
# (9,)
# [0. 0. 0. 0. 0. 0. 0. 0. 0.]

# %%
# %matplotlib qt
# %matplotlib inline

inds = range(len(X_test))
# inds = [2]
epsInit = 12 # 0.2
minNshown = 15

nCols = 4
nRows = 5
fig, axs = plt.subplots(nRows, nCols, figsize=(16, 18), subplot_kw={'projection': '3d'})

scale = 1000

globalColorNorm = cm.colors.Normalize(vmin=5, vmax=12)

xPlot, yPlot, xInd = X_test, Y_test, X_test_indices
# xPlot, yPlot, xInd = X_train, Y_train, X_train_indices

xEdges = np.linspace(-DETECTOR_SIZE_MM[0]/2/scale, DETECTOR_SIZE_MM[0]/2/scale, gridSize[0] + 1)
yEdges = np.linspace(-DETECTOR_SIZE_MM[1]/2/scale, DETECTOR_SIZE_MM[1]/2/scale, gridSize[1] + 1)
zEdges = np.linspace(-DETECTOR_SIZE_MM[2]/2/scale, DETECTOR_SIZE_MM[2]/2/scale, gridSize[2] + 1)
yEdges, xEdges, zEdges = np.meshgrid(xEdges, yEdges, zEdges)

for ind in tqdm.tqdm(inds):
    trueGrid = yPlot[ind]
    # trueGrid = zoom(Y_test[ind], [
    #     gridSize_input[0]/gridSize_output[0], 
    #     gridSize_input[1]/gridSize_output[1], 
    #     gridSize_input[2]/gridSize_output[2]])
    predGrid = model.predict(xPlot[ind].reshape(1, 
                                            gridSize_input[0], 
                                            gridSize_input[1], 
                                            gridSize_input[2], 
                                            6)).reshape(gridSize_output)
    # predGrid = zoom(predGrid, [
    #     gridSize_input[0]/gridSize_output[0], 
    #     gridSize_input[1]/gridSize_output[1], 
    #     gridSize_input[2]/gridSize_output[2]])
    # truePos = np.array(dfs_hits[ind]['initialPosition'].to_list())

    eps = epsInit
    while True:
        nonZeroInd = np.where(predGrid.flatten()>eps)
        if len(nonZeroInd[0]) >= minNshown:
            break
        elif eps < 0:
            break
        eps -= 0.1

    # scatter = axs[ind//nCols, ind%nCols].scatter(grid_pos[nonZeroInd,0]/scale, 
    #                                              grid_pos[nonZeroInd,1]/scale, 
    #                                              grid_pos[nonZeroInd,2]/scale, 
    #                                              c=predGrid.flatten()[nonZeroInd], cmap=cm.viridis, s=100, alpha=0.2, marker='s', norm=globalColorNorm)
    colors = cm.viridis(globalColorNorm(predGrid))
    voxels = axs[ind//nCols, ind%nCols].voxels(xEdges,
                                               yEdges,
                                               zEdges,
                                               predGrid>eps,
                                               facecolors=colors,
                                               edgecolors=np.clip(colors*2-0.5, 0, 1),
                                               linewidth=0.5,
                                               alpha=0.8)
    # plt.colorbar(scatter)
    
    # nonZeroInd = np.where(trueGrid.flatten()>0)
    # axs[ind//nCols, ind%nCols].scatter(grid_pos[nonZeroInd,0]/scale, 
    #                                    grid_pos[nonZeroInd,1]/scale, 
    #                                    grid_pos[nonZeroInd,2]/scale, c='k', cmap=cm.viridis, s=30, alpha=0.8, marker='o')
    axs[ind//nCols, ind%nCols].voxels(xEdges,
                                      yEdges,
                                      zEdges,
                                      trueGrid>0,
                                      facecolors='k',
                                      edgecolors='k',
                                      linewidth=0.5,
                                      alpha=0.0)
    primaryTrue = np.array(dfs_primary[xInd[ind]]['position'].to_list())
    axs[ind//nCols, ind%nCols].scatter(primaryTrue[:,0]/scale,
                                       primaryTrue[:,1]/scale,
                                       primaryTrue[:,2]/scale,
                                       c='k', cmap=cm.viridis, s=30, alpha=0.1)

    # ax.scatter(truePos[:,0], truePos[:,1], truePos[:,2], c='g', cmap=cm.viridis, s=100, alpha=1)

    axs[ind//nCols, ind%nCols].set_xlim(-DETECTOR_SIZE_MM[0]/2/scale, DETECTOR_SIZE_MM[0]/2/scale)
    axs[ind//nCols, ind%nCols].set_ylim(-DETECTOR_SIZE_MM[1]/2/scale, DETECTOR_SIZE_MM[1]/2/scale)
    axs[ind//nCols, ind%nCols].set_zlim(-DETECTOR_SIZE_MM[2]/2/scale, DETECTOR_SIZE_MM[2]/2/scale)

    axs[ind//nCols, ind%nCols].set_xlabel(r'$x$ [m]', labelpad=7)
    axs[ind//nCols, ind%nCols].set_ylabel(r'$y$ [m]')
    axs[ind//nCols, ind%nCols].set_zlabel(r'$z$ [m]', labelpad=0)

axNew = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axNew.set_visible(False)
cbar = plt.colorbar(cm.ScalarMappable(norm=globalColorNorm, cmap=cm.viridis), ax=axNew, orientation='horizontal', label='Predicted Weight', alpha=0.2, pad=0.1, aspect=40, shrink=0.8, extend='both')
cbar.ax.xaxis.set_label_position('top')
cbar.ax.xaxis.set_ticks_position('top')
cbar.ax.set_position([0.11, 0.1, 0.8, 0.9])

axExtend = fig.add_axes([1.1, 0.1, 0.1, 0.8])
axExtend.set_visible(True)

fig.tight_layout()
plt.savefig('../figures/allTestEvents.pdf', bbox_inches='tight')
plt.show()
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 20ms/step
# /var/folders/mv/_50rblmd16xfrbsjpr4x2z0c0000gn/T/ipykernel_62470/4165574376.py:79: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   axs[ind//nCols, ind%nCols].scatter(primaryTrue[:,0]/scale,
#   5%|▌         | 1/20 [00:00<00:03,  6.33it/s]
# 1/1 [==============================] - 0s 22ms/step
#  10%|█         | 2/20 [00:00<00:02,  6.06it/s]
# 1/1 [==============================] - 0s 19ms/step
#  15%|█▌        | 3/20 [00:00<00:02,  6.00it/s]
# 1/1 [==============================] - 0s 20ms/step
#  20%|██        | 4/20 [00:00<00:02,  6.02it/s]
# 1/1 [==============================] - 0s 21ms/step
#  25%|██▌       | 5/20 [00:00<00:02,  6.05it/s]
# 1/1 [==============================] - 0s 19ms/step
#  30%|███       | 6/20 [00:00<00:02,  6.02it/s]
# 1/1 [==============================] - 0s 21ms/step
#  35%|███▌      | 7/20 [00:01<00:02,  5.99it/s]
# 1/1 [==============================] - 0s 20ms/step
#  40%|████      | 8/20 [00:01<00:02,  5.96it/s]
# 1/1 [==============================] - 0s 21ms/step
#  45%|████▌     | 9/20 [00:01<00:01,  5.97it/s]
# 1/1 [==============================] - 0s 20ms/step
#  50%|█████     | 10/20 [00:01<00:01,  5.95it/s]
# 1/1 [==============================] - 0s 20ms/step
#  55%|█████▌    | 11/20 [00:01<00:01,  5.94it/s]
# 1/1 [==============================] - 0s 21ms/step
#  60%|██████    | 12/20 [00:02<00:01,  5.87it/s]
# 1/1 [==============================] - 0s 19ms/step
#  65%|██████▌   | 13/20 [00:02<00:01,  5.99it/s]
# 1/1 [==============================] - 0s 19ms/step
#  70%|███████   | 14/20 [00:02<00:00,  6.03it/s]
# 1/1 [==============================] - 0s 20ms/step
#  75%|███████▌  | 15/20 [00:02<00:00,  6.00it/s]
# 1/1 [==============================] - 0s 23ms/step
#  80%|████████  | 16/20 [00:02<00:00,  5.97it/s]
# 1/1 [==============================] - 0s 19ms/step
#  85%|████████▌ | 17/20 [00:02<00:00,  6.04it/s]
# 1/1 [==============================] - 0s 19ms/step
#  90%|█████████ | 18/20 [00:02<00:00,  6.11it/s]
# 1/1 [==============================] - 0s 19ms/step
#  95%|█████████▌| 19/20 [00:03<00:00,  6.02it/s]
# 1/1 [==============================] - 0s 20ms/step
# 100%|██████████| 20/20 [00:03<00:00,  6.00it/s]
# /var/folders/mv/_50rblmd16xfrbsjpr4x2z0c0000gn/T/ipykernel_62470/4165574376.py:104: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
